# %%
import  pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import re 
import warnings
warnings.filterwarnings("ignore")


# 크롤링한 데이터를 데이터 프레임으로 만들기 위해 준비
columns = ["검색어", "순번", "한자","품사","설명","링크"]
df = pd.DataFrame(columns=columns)
excutable_path = "../chromedriver.exe"
driver = webdriver.Chrome(executable_path=excutable_path)
base_url = 'https://stdict.korean.go.kr'

def urlmake(links):
    source = links
    driver.get(source)
    req = driver.page_source
    soup = BeautifulSoup(req, "html.parser") 
    return soup

def listmake(word):
    num = isNone(word.select_one('.t_blue1 > sup'))
    china = isNone(word.select_one('dt> span'))
    poumsa =  isNone(word.select_one('dt'))
    content = isNone(word.select_one('font'))
    link = word.select_one('a').attrs['href']
    return num,china,poumsa,content,base_url +link

def isNone(word):
    if word != None and word.text != '':
        if len(word) > 3:
            index = startAndLast(re.sub('[\t\n\s]','',word.text))
            return re.sub('[\t\n\s]','',word.text)[index[0]:index[1]]
        return re.sub('[\t\n\s]','',word.text)
    else:
        return "Nope"

def startAndLast(word):
    ok = True
    start_index = 0
    last_index = 0
    for i in range(len(word)):
        if ok and word[i] == '「':
            start_index = i
        if word[i] == '」':
            last_index = i+1
            return start_index,last_index

        
        
        
        
search_data =  input("검색어를 입력해주세요.")

url = 'https://stdict.korean.go.kr/search/searchResult.do?pageSize=10&searchKeyword=' + str(search_data)

num = 0

search_soup = urlmake(url)

title = search_soup.select_one('.t_blue2')
if title != None:
    title = title.text.strip()
    words = search_soup.select('.result > li')
    for word in words:
        print(f'{columns[0]} : {title}')
        for i in range(len(listmake(word))):
            print(f'{columns[i+1]} : {listmake(word)[i]}') 
        print('----------------------------------------------------------------------------------------------')
        row = [title,*listmake(word)]
        series = pd.Series(row, index=df.columns)
        df = df.append(series, ignore_index=True)
else:
    text = search_soup.select_one('.no_result>li>div')
    if text == None:
        print(search_soup.select_one('.no_result').text)
    else:
        print(text.text)
        print('https://opendic.korean.go.kr/search/searchResult?query='+search_data)
# Out:
# 검색어를 입력해주세요.발
# 검색어 : 발
# 순번 : 1
# 한자 : Nope
# 품사 : 「명사」
# 설명 : 사람이나동물의다리맨끝부분.
# 링크 : https://stdict.korean.go.kr/search/searchView.do?word_no=132767&searchKeywordTo=3
# ----------------------------------------------------------------------------------------------
# 검색어 : 발
# 순번 : 2
# 한자 : Nope
# 품사 : 「명사」
# 설명 : 나무나이테의굵기.
# 링크 : https://stdict.korean.go.kr/search/searchView.do?word_no=132544&searchKeywordTo=3
# ----------------------------------------------------------------------------------------------
# 검색어 : 발
# 순번 : 3
# 한자 : Nope
# 품사 : 「명사」
# 설명 : 가늘고긴대를줄로엮거나,줄따위를여러개나란히늘어뜨려만든물건.주로무엇을가리는데쓴다.
# 링크 : https://stdict.korean.go.kr/search/searchView.do?word_no=429933&searchKeywordTo=3
# ----------------------------------------------------------------------------------------------
# 검색어 : 발
# 순번 : 4
# 한자 : Nope
# 품사 : 「명사」
# 설명 : 새로생긴나쁜버릇이나관례.
# 링크 : https://stdict.korean.go.kr/search/searchView.do?word_no=132545&searchKeywordTo=3
# ----------------------------------------------------------------------------------------------
# 검색어 : 발
# 순번 : 5
# 한자 : Nope
# 품사 : 「명사」
# 설명 : 실이나국수따위의가늘고긴물체의가락.
# 링크 : https://stdict.korean.go.kr/search/searchView.do?word_no=132546&searchKeywordTo=3
# ----------------------------------------------------------------------------------------------
# 검색어 : 발
# 순번 : 6
# 한자 : Nope
# 품사 : 「명사」
# 설명 : 남의비밀을캐내어다른사람에게넌지시알려주는짓.=발쇠.
# 링크 : https://stdict.korean.go.kr/search/searchView.do?word_no=132547&searchKeywordTo=3
# ----------------------------------------------------------------------------------------------
# 검색어 : 발
# 순번 : 7
# 한자 : Nope
# 품사 : 「의존명사」
# 설명 : 길이의단위.한발은두팔을양옆으로펴서벌렸을때한쪽손끝에서다른쪽손끝까지의길이이다.
# 링크 : https://stdict.korean.go.kr/search/searchView.do?word_no=429934&searchKeywordTo=3
# ----------------------------------------------------------------------------------------------
# 검색어 : 발
# 순번 : 8
# 한자 : Nope
# 품사 : 「명사」
# 설명 : 『음악』→바라.
# 링크 : https://stdict.korean.go.kr/search/searchView.do?word_no=132548&searchKeywordTo=3
# ----------------------------------------------------------------------------------------------
# 검색어 : 발
# 순번 : 9
# 한자 : (發)
# 품사 : 「의존명사」
# 설명 : 총알,포탄,화살따위를세는단위.
# 링크 : https://stdict.korean.go.kr/search/searchView.do?word_no=430707&searchKeywordTo=3
# ----------------------------------------------------------------------------------------------
# 검색어 : 발
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9816/963131716.py in <module>
#      67     for word in words:
#      68         print(f'{columns[0]} : {title}')
# ---> 69         for i in range(len(listmake(word))):
#      70             print(f'{columns[i+1]} : {listmake(word)[i]}')
#      71         print('----------------------------------------------------------------------------------------------')
#
# ~\AppData\Local\Temp/ipykernel_9816/963131716.py in listmake(word)
#      24     num = isNone(word.select_one('.t_blue1 > sup'))
#      25     china = isNone(word.select_one('dt> span'))
# ---> 26     poumsa =  isNone(word.select_one('dt'))
#      27     content = isNone(word.select_one('font'))
#      28     link = word.select_one('a').attrs['href']
#
# ~\AppData\Local\Temp/ipykernel_9816/963131716.py in isNone(word)
#      33         if len(word) > 3:
#      34             index = startAndLast(re.sub('[\t\n\s]','',word.text))
# ---> 35             return re.sub('[\t\n\s]','',word.text)[index[0]:index[1]]
#      36         return re.sub('[\t\n\s]','',word.text)
#      37     else:
#
# TypeError: 'NoneType' object is not subscriptable

# %%
file = open('words.txt', 'rt', encoding ='utf8')
lines = file.readlines()
print(lines)
# Out:
# ['학원\n', '학교\n', '역사\n', '수학\n', '소설']

# %%
f = open("words.txt", 'r', encoding = 'utf8')
lines = f.readlines()
for line in lines:
    line = line.strip()  
    print(line)
f.close()
# Out:
# 학원
# 학교
# 역사
# 수학
# 소설

# %%
df
# Out:
#   검색어 순번    한자    품사                                                 설명  \
# 0  소설  1  (小舌)  「명사」                                    하찮거나쓸모없는변설(辯舌).
# 1  소설  2  (小雪)  「명사」  이십사절기의하나.입동과대설사이에들며,이때태양의황경(黃經)은240도가된다.11월22일...
# 2  소설  3  (小說)  「명사」  『문학』사실또는작가의상상력에바탕을두고허구적으로이야기를꾸며나간산문체의문학양식.일정한구...
# 3  소설  4  (所說)  「명사」                                             설명하는바.
# 4  소설  5  (昭雪)  「명사」                             원통한죄나억울한누명따위를밝혀씻음.≒소석.
# 5  소설  6  (素雪)  「명사」                                           하얀눈.=백설.
# 6  소설  7  (掃雪)  「명사」                                  쌓인눈을치움.또는그런일.=제설.
# 7  소설  8  (疏泄)  「명사」                             『한의』뭉쳐있는기운을풀어서소통시키는기능.
# 8  소설  9  (騷說)  「명사」                                         시끄럽게떠도는소문.
#
#                                                   링크
# 0  https://stdict.korean.go.kr/search/searchView....
# 1  https://stdict.korean.go.kr/search/searchView....
# 2  https://stdict.korean.go.kr/search/searchView....
# 3  https://stdict.korean.go.kr/search/searchView....
# 4  https://stdict.korean.go.kr/search/searchView....
# 5  https://stdict.korean.go.kr/search/searchView....
# 6  https://stdict.korean.go.kr/search/searchView....
# 7  https://stdict.korean.go.kr/search/searchView....
# 8  https://stdict.korean.go.kr/search/searchView....

# %%
df.to_csv('소설2.csv',index=False, encoding ='cp949')
