# %% [markdown]
# Copyright (c) 2019 [윤기태]
#
# https://github.com/yoonkt200/python-data-analysis
#
# [MIT License](https://github.com/yoonkt200/python-data-analysis/blob/master/LICENSE.txt)

# %% [markdown]
# # (가제) 파이썬 데이터 분석

# %% [markdown]
# -----

# %% [markdown]
# # 2.2) 트위터 API로 연관 키워드 분석하기

# %% [markdown]
# ### 바로가기

# %% [markdown]
# - [<Step1. API 호출> : 트위터 API로 데이터 가져오기](#<Step1.-API-호출>-:-트위터-API로-데이터-가져오기)
#     - [API 데이터로 데이터 프레임 생성하기]
# - [<Step2. 추출> : 키워드 추출](#<Step2.-추출>-:-키워드-추출)
#     - [텍스트 데이터 전처리]
#     - [nltk, konlpy를 이용한 키워드 추출]
# - [<Step3. 분석> : 연관 분석을 이용한 키워드 분석](#<Step3.-분석>-:-연관-분석을-이용한-키워드-분석)
#     - [연관 키워드 추출하기]
#     - [단어 빈도 추출하기]
# - [<Step4. 시각화> : 연관 키워드 네트워크 시각화](#<Step4.-시각화>-:-연관-키워드-네트워크-시각화)
#     - [연관 키워드 네트워크 시각화]

# %% [markdown]
# -----

# %%
# -*- coding: utf-8 -*-

# 주피터 노트북을 실행한 브라우저에서 바로 그림을 볼 수 있게끔 만드는 것
#브라우저 내부(inline)에 바로 그려지도록 해주는 코드
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # <Step1. API 호출> : 트위터 API로 데이터 가져오기

# %% [markdown]
# ### [API 데이터로 데이터 프레임 생성하기]
# - API 사용법 참고 : https://github.com/yoonkt200/python-data-analysis/blob/master/chapter_text/(%EC%B0%B8%EA%B3%A0)%20using-twitter-api.ipynb
# - 아래 코드 실행을 위해, anaconda prompt 혹은 Terminal에서 아래와 같은 패키지를 설치해 줍니다.
#     - (env_name) `pip install tweepy`
# - 혹은 아래의 코드로 라이브러리를 설치합니다.
# - [2022.02.04 ] tweepy 4 버전 설치시 api.search에서 에러 발생 => tweepy 3 버전으로 설치
# - pip install tweepy==3.10.0

# %%
#!pip install tweepy
# tweepy 3 버전으로 설치
# !pip install tweepy==3.10.0
# Out:
# Requirement already satisfied: tweepy==3.10.0 in c:\users\yj\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\yj\anaconda3\lib\site-packages (from tweepy==3.10.0) (1.3.1)
# Requirement already satisfied: six>=1.10.0 in c:\users\yj\anaconda3\lib\site-packages (from tweepy==3.10.0) (1.16.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\yj\anaconda3\lib\site-packages (from tweepy==3.10.0) (2.26.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\yj\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy==3.10.0) (3.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yj\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yj\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\yj\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yj\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (3.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\yj\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (1.7.1)

# %% [markdown]
# -----

# %% [markdown]
# ##### 트위터 API 가져오기
# - 트위터의 키워드 크롤링 기능을 사용하기 위해 트위터 앱에서 발급받은 KEY와 TOKEN 정보를 입력
# - 총 4가지 정보를 입력하여 코드 실행
# - tweepy의 OAuthHandler() 클래스가 자동으로 개인정보 인증 완료

# %%
import tweepy

# 트위터 API 개발자 계정 신청 : https://developer.twitter.com/en/apply-for-account
# 트위터 Apps 관리 및 생성 : https://developer.twitter.com/en/apps

# 발급 완료된 키 입력
CONSUMER_KEY = "bF7ZmUgxM1ErWKMSAZL6b4CqI"
CONSUMER_SECRET = "lEefoafW8sVm4k3WXkAJlGBYJLnDfqIFfv0WKac4RthU2y5VHG"
ACCESS_TOKEN_KEY = "1486554047452565506-ItSR4coXMdd9DiGLFBiTeAoWtDdj1s"
ACCESS_TOKEN_SECRET = "GMv0jWwknIdn2l1lyFfBWE9cfvyCkemcBEtk0f9QshckV"

# 개인정보 인증을 요청하는 Handler
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)

# 인증 요청을 수행
auth.set_access_token(ACCESS_TOKEN_KEY, ACCESS_TOKEN_SECRET)

# twitter API를 사용하기 위한 준비
api = tweepy.API(auth)

# %%
# tweepy 버전 출력
tweepy.__version__
# Out:
# '3.10.0'

# %% [markdown]
# -----

# %% [markdown]
# #### '손흥민' 키워드 검색

# %%
# Twitter Developer Platform의 Data dictionary 참조
# https://developer.twitter.com/en/docs/twitter-api/v1/data-dictionary/object-model/tweet

# twitter API를 사용하여 '손흥민' 이 포함된 트윗들을 크롤링한 뒤, 'user_mentions'와 'hashtags' 속성값 추출
keyword = "손흥민"

# 특정 키워드 크롤링은  search() 함수 수행
tweets = api.search(keyword)

# entities() 함수로 특정 속성의 메타데이터에 접근하여 정보 추출
for tweet in tweets:
    print(tweet.text)
    print(tweet.entities['user_mentions'])
    print(tweet.entities['hashtags'])
    print(tweet.created_at) # 트윗이 생성된 UTC 시간, 예) "2022-02-04 01:47:09"
# Out:
# RT @Spurs_KR: [손흥민 선수 득점 경기 H/L] 손흥민 21/22시즌 프리미어리그 9호골 (vs 사우스햄튼)
#
# #THFC #COYS #토트넘 #손흥민 https://t.co/tx64kIJayP
# [{'screen_name': 'Spurs_KR', 'name': 'Tottenham Hotspur 🇰🇷', 'id': 1341708258818584576, 'id_str': '1341708258818584576', 'indices': [3, 12]}]
# [{'text': 'THFC', 'indices': [68, 73]}, {'text': 'COYS', 'indices': [74, 79]}, {'text': '토트넘', 'indices': [80, 84]}, {'text': '손흥민', 'indices': [85, 89]}]
# 2022-02-10 01:27:28
# RT @ssonsal__0708: 손흥민 골장면이나 다시보자 https://t.co/f2Le9m0Ur6
# [{'screen_name': 'ssonsal__0708', 'name': '쏜살', 'id': 1382327710035316742, 'id_str': '1382327710035316742', 'indices': [3, 17]}]
# []
# 2022-02-10 01:27:01
# RT @Spurs_KR: [손흥민 선수 득점 경기 H/L] 손흥민 21/22시즌 프리미어리그 9호골 (vs 사우스햄튼)
#
# #THFC #COYS #토트넘 #손흥민 https://t.co/tx64kIJayP
# [{'screen_name': 'Spurs_KR', 'name': 'Tottenham Hotspur 🇰🇷', 'id': 1341708258818584576, 'id_str': '1341708258818584576', 'indices': [3, 12]}]
# [{'text': 'THFC', 'indices': [68, 73]}, {'text': 'COYS', 'indices': [74, 79]}, {'text': '토트넘', 'indices': [80, 84]}, {'text': '손흥민', 'indices': [85, 89]}]
# 2022-02-10 01:25:43
# RT @Spurs_KR: [손흥민 선수 득점 경기 H/L] 손흥민 21/22시즌 프리미어리그 9호골 (vs 사우스햄튼)
#
# #THFC #COYS #토트넘 #손흥민 https://t.co/tx64kIJayP
# [{'screen_name': 'Spurs_KR', 'name': 'Tottenham Hotspur 🇰🇷', 'id': 1341708258818584576, 'id_str': '1341708258818584576', 'indices': [3, 12]}]
# [{'text': 'THFC', 'indices': [68, 73]}, {'text': 'COYS', 'indices': [74, 79]}, {'text': '토트넘', 'indices': [80, 84]}, {'text': '손흥민', 'indices': [85, 89]}]
# 2022-02-10 01:25:36
# RT @Spurs_KR: 손흥민 선수의 프리미어리그 시즌 9호골이 나옵니다!!
#
# #THFC #COYS #토트넘 #손흥민
#
# ⚪️ 2-1 🟡 (71') https://t.co/y22UeB2Rf4
# [{'screen_name': 'Spurs_KR', 'name': 'Tottenham Hotspur 🇰🇷', 'id': 1341708258818584576, 'id_str': '1341708258818584576', 'indices': [3, 12]}]
# [{'text': 'THFC', 'indices': [45, 50]}, {'text': 'COYS', 'indices': [51, 56]}, {'text': '토트넘', 'indices': [57, 61]}, {'text': '손흥민', 'indices': [62, 66]}]
# 2022-02-10 01:25:21
# RT @Uribulous: 연느랑 발리예바 나이차 16살이고
# 안정환 선수랑 손흥민 선수 나이차도 16살
# 축구 얘기할때 저 두 선수로 비교질 안하잖아요? 10년 이상의 시간이 지났는데 비교하는거 자체가 의미없다는걸 알기에?
#  왜 꼭 ❗️피겨❗️에만…
# [{'screen_name': 'Uribulous', 'name': 'COoL', 'id': 2456617718, 'id_str': '2456617718', 'indices': [3, 13]}]
# []
# 2022-02-10 01:22:41
# RT @Uribulous: 연느랑 발리예바 나이차 16살이고
# 안정환 선수랑 손흥민 선수 나이차도 16살
# 축구 얘기할때 저 두 선수로 비교질 안하잖아요? 10년 이상의 시간이 지났는데 비교하는거 자체가 의미없다는걸 알기에?
#  왜 꼭 ❗️피겨❗️에만…
# [{'screen_name': 'Uribulous', 'name': 'COoL', 'id': 2456617718, 'id_str': '2456617718', 'indices': [3, 13]}]
# []
# 2022-02-10 01:21:51
# RT @Spurs_KR: [손흥민 선수 득점 경기 H/L] 손흥민 21/22시즌 프리미어리그 9호골 (vs 사우스햄튼)
#
# #THFC #COYS #토트넘 #손흥민 https://t.co/tx64kIJayP
# [{'screen_name': 'Spurs_KR', 'name': 'Tottenham Hotspur 🇰🇷', 'id': 1341708258818584576, 'id_str': '1341708258818584576', 'indices': [3, 12]}]
# [{'text': 'THFC', 'indices': [68, 73]}, {'text': 'COYS', 'indices': [74, 79]}, {'text': '토트넘', 'indices': [80, 84]}, {'text': '손흥민', 'indices': [85, 89]}]
# 2022-02-10 01:19:36
# RT @Uribulous: 연느랑 발리예바 나이차 16살이고
# 안정환 선수랑 손흥민 선수 나이차도 16살
# 축구 얘기할때 저 두 선수로 비교질 안하잖아요? 10년 이상의 시간이 지났는데 비교하는거 자체가 의미없다는걸 알기에?
#  왜 꼭 ❗️피겨❗️에만…
# [{'screen_name': 'Uribulous', 'name': 'COoL', 'id': 2456617718, 'id_str': '2456617718', 'indices': [3, 13]}]
# []
# 2022-02-10 01:19:08
# RT @Uribulous: 연느랑 발리예바 나이차 16살이고
# 안정환 선수랑 손흥민 선수 나이차도 16살
# 축구 얘기할때 저 두 선수로 비교질 안하잖아요? 10년 이상의 시간이 지났는데 비교하는거 자체가 의미없다는걸 알기에?
#  왜 꼭 ❗️피겨❗️에만…
# [{'screen_name': 'Uribulous', 'name': 'COoL', 'id': 2456617718, 'id_str': '2456617718', 'indices': [3, 13]}]
# []
# 2022-02-10 01:18:59
# RT @Uribulous: 연느랑 발리예바 나이차 16살이고
# 안정환 선수랑 손흥민 선수 나이차도 16살
# 축구 얘기할때 저 두 선수로 비교질 안하잖아요? 10년 이상의 시간이 지났는데 비교하는거 자체가 의미없다는걸 알기에?
#  왜 꼭 ❗️피겨❗️에만…
# [{'screen_name': 'Uribulous', 'name': 'COoL', 'id': 2456617718, 'id_str': '2456617718', 'indices': [3, 13]}]
# []
# 2022-02-10 01:18:38
# [손흥민 선수 득점 경기 H/L] 손흥민 21/22시즌 프리미어리그 9호골 (vs 사우스햄튼): https://t.co/Y6Bcsp6V6E
# []
# []
# 2022-02-10 01:17:36
# 힘들게 힘들게 눈 떠서 TV켰다
# 비몽사몽에 손흥민 골 들어가는걸 봄 와우 ~!!
# 타이밍 지리고 ㅎㅎ
#
# 그리고 ...똑같은 자리에서
# 똑같은 헤딩 두 번 맞고 지더라 ㅋㅋ
#
# 데자뷰인가? 아님 토트넘 수비는 ㅄ 인가? ㅋㅋ
# []
# []
# 2022-02-10 01:15:46
# RT @ssonsal__0708: 손흥민 골장면이나 다시보자 https://t.co/f2Le9m0Ur6
# [{'screen_name': 'ssonsal__0708', 'name': '쏜살', 'id': 1382327710035316742, 'id_str': '1382327710035316742', 'indices': [3, 17]}]
# []
# 2022-02-10 01:08:19
# RT @BJYX_Yogurt_: 옛날에 어디서 봤는데 우리나라 인구랑 중국 인구 비교했을 때 중국엔 손흥민이 28명 정도는 있어야한다고 했음
# [{'screen_name': 'BJYX_Yogurt_', 'name': '야꾸', 'id': 1277273368736043010, 'id_str': '1277273368736043010', 'indices': [3, 16]}]
# []
# 2022-02-10 01:07:40

# %%
tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x000001FD90C8A100>, _json={'created_at': 'Thu Feb 10 01:27:28 +0000 2022', 'id': 1491584568343756802, 'id_str': '1491584568343756802', 'text': 'RT @Spurs_KR: [손흥민 선수 득점 경기 H/L] 손흥민 21/22시즌 프리미어리그 9호골 (vs 사우스햄튼)\n\n#THFC #COYS #토트넘 #손흥민 https://t.co/tx64kIJayP', 'truncated': False, 'entities': {'hashtags': [{'text': 'THFC', 'indices': [68, 73]}, {'text': 'COYS', 'indices': [74, 79]}, {'text': '토트넘', 'indices': [80, 84]}, {'text': '손흥민', 'indices': [85, 89]}], 'symbols': [], 'user_mentions': [{'screen_name': 'Spurs_KR', 'name': 'Tottenham Hotspur 🇰🇷', 'id': 1341708258818584576, 'id_str': '1341708258818584576', 'indices': [3, 12]}], 'urls': [], 'media': [{'id': 1491563868300005377, 'id_str': '1491563868300005377', 'indices': [90, 113], 'media_url': 'http://pbs.twimg.com/media/FLMaG-iVEAYeqxa.png', 'media_url_https': 'https://pbs.twimg.com/media/FLMaG-iVEAYeqxa.png', 'url': 'https://t.co/tx64kIJayP', 'display_url': 'pic.twitter.com/tx64kIJayP', 'expanded_url': 'https://twitter.com/Spurs_KR/status/1491565117506408448/video/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'large': {'w': 1920, 'h': 1080, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}, 'source_status_id': 1491565117506408448, 'source_status_id_str': '1491565117506408448', 'source_user_id': 1341708258818584576, 'source_user_id_str': '1341708258818584576'}]}, 'extended_entities': {'media': [{'id': 1491563868300005377, 'id_str': '1491563868300005377', 'indices': [90, 113], 'media_url': 'http://pbs.twimg.com/media/FLMaG-iVEAYeqxa.png', 'media_url_https': 'https://pbs.twimg.com/media/FLMaG-iVEAYeqxa.png', 'url': 'https://t.co/tx64kIJayP', 'display_url': 'pic.twitter.com/tx64kIJayP', 'expanded_url': 'https://twitter.com/Spurs_KR/status/1491565117506408448/video/1', 'type': 'video', 'sizes': {'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'large': {'w': 1920, 'h': 1080, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}, 'source_status_id': 1491565117506408448, 'source_status_id_str': '1491565117506408448', 'source_user_id': 1341708258818584576, 'source_user_id_str': '1341708258818584576', 'video_info': {'aspect_ratio': [16, 9], 'duration_millis': 64319, 'variants': [{'content_type': 'application/x-mpegURL', 'url': 'https://video.twimg.com/amplify_video/1491563868300005377/pl/VWBRA765MsgiuJq-.m3u8?tag=14&container=fmp4'}, {'bitrate': 288000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1491563868300005377/vid/480x270/Xx_7gQ3ka9zFxxYN.mp4?tag=14'}, {'bitrate': 2176000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1491563868300005377/vid/1280x720/JklVSDvTef9MsKcg.mp4?tag=14'}, {'bitrate': 832000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1491563868300005377/vid/640x360/NpE0CZxzVG3G33ps.mp4?tag=14'}]}, 'additional_media_info': {'title': '', 'description': '', 'call_to_actions': {'visit_site': {'url': 'https://youtu.be/ZjnFXupAasU'}}, 'embeddable': True, 'monetizable': False, 'source_user': {'id': 1341708258818584576, 'id_str': '1341708258818584576', 'name': 'Tottenham Hotspur 🇰🇷', 'screen_name': 'Spurs_KR', 'location': 'London', 'description': '🇰🇷 토트넘 핫스퍼 오피셜 한국 트위터 계정 @Spurs_KR 🇰🇷 \n\n@SpursOfficial @Spurs_THA @Spurs_India @Spurs_ES @Spurs_MAS @Spurs_ID #COYS', 'url': 'https://t.co/LLTTy8WzYm', 'entities': {'url': {'urls': [{'url': 'https://t.co/LLTTy8WzYm', 'expanded_url': 'http://www.tottenhamhotspur.com/kr', 'display_url': 'tottenhamhotspur.com/kr', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count':
normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1483971803144155141/rumzDr2v_normal.jpg', 'profile_banner_ ...
#  Status(_api=<tweepy.api.API object at 0x000001FD90C8A100>, _json={'created_at': 'Thu Feb 10 01:07:40 +0000 2022', 'id': 1491579588945666051, 'id_str': '1491579588945666051', 'text': 'RT @BJYX_Yogurt_: 옛날에 어디서 봤는데 우리나라 인구랑 중국 인구 비교했을 때 중국엔 손흥민이 28명 정도는 있어야한다고 했음', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'BJYX_Yogurt_', 'name': '야꾸', 'id': 1277273368736043010, 'id_str': '1277273368736043010', 'indices': [3, 16]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 894651811948150784, 'id_str': '894651811948150784', 'name': '푸둣간⁶⁶🌻', 'screen_name': '6aKFtZvbkcZQVR8', 'location': '', 'description': '🐻🌻 귀여운 아이.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 306, 'friends_count': 1162, 'listed_count': 1, 'created_at': 'Mon Aug 07 20:09:48 +0000 2017', 'favourites_count': 3736, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 339622, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/925766736514707457/7XBrC8s6_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/925766736514707457/7XBrC8s6_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/894651811948150784/1643214252', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Feb 08 02:32:05 +0000 2022', 'id': 1490876055271645184, 'id_str': '1490876055271645184', 'text': '옛날에 어디서 봤는데 우리나라 인구랑 중국 인구 비교했을 때 중국엔 손흥민이 28명 정도는 있어야한다고 했음 https://t.co/K6FHa95HOw', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/K6FHa95HOw', 'expanded_url': 'https://twitter.com/not_rvdfan/status/1490682244239065089', 'display_url': 'twitter.com/not_rvdfan/sta…', 'indices': [61, 84]}]}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1277273368736043010, 'id_str': '1277273368736043010', 'name': '야꾸', 'screen_name': 'BJYX_Yogurt_', 'location': '', 'description': '왕샤오는 우리들을 기만하지 마라!! 결혼으로 보상해라!!💚💍❤️', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 80, 'friends_count': 75, 'listed_count': 0, 'created_at': 'Sun Jun 28 16:11:23 +0000 2020', 'favourites_count': 7111, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 7194, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1490836783688724481/xDQ9KZTj_norma ...

# %% [markdown]
# -----

# %% [markdown]
# ##### 데이터 프레임 형태로 수집

# %%
# 크롤링된 데이터를 저장할 데이터 프레임 생성
columns = ['created', 'tweet_text']
df = pd.DataFrame(columns=columns)

# 크롤링을 수행할 갯수를 입력
max_tweets = 1000

# Cursor 객체를 사용하여 크롤링 수행
# Cursor()로 keyword의 값에 해당하는 정보를  items()으로 지정한 갯수만큼 크롤링
searched_tweets = [status for status in tweepy.Cursor(api.search, q=keyword).items(max_tweets)]

# ‘손흥민’이 포함된 1000개의 트윗들에서, ‘text’, ‘created_at’ 정보를 데이터 프레임으로 저장
for tweet in searched_tweets:
    tweet_json = tweet._json
    tweet_text = tweet_json['text']
    created = tweet_json['created_at']
    row = [created, tweet_text]
    series = pd.Series(row, index=df.columns) #  created, tweet_text로 시리즈를 생성
    df = df.append(series, ignore_index=True) # 생성된 시리즈를 데이터프레임에 추가

# %%
# 데이터 프레임 상위 5개 출력
df.head()
# Out:
#                           created  \
# 0  Thu Feb 10 01:27:28 +0000 2022
# 1  Thu Feb 10 01:27:01 +0000 2022
# 2  Thu Feb 10 01:25:43 +0000 2022
# 3  Thu Feb 10 01:25:36 +0000 2022
# 4  Thu Feb 10 01:25:21 +0000 2022
#
#                                           tweet_text
# 0  RT @Spurs_KR: [손흥민 선수 득점 경기 H/L] 손흥민 21/22시즌 프...
# 1  RT @ssonsal__0708: 손흥민 골장면이나 다시보자 https://t.co...
# 2  RT @Spurs_KR: [손흥민 선수 득점 경기 H/L] 손흥민 21/22시즌 프...
# 3  RT @Spurs_KR: [손흥민 선수 득점 경기 H/L] 손흥민 21/22시즌 프...
# 4  RT @Spurs_KR: 손흥민 선수의 프리미어리그 시즌 9호골이 나옵니다!!\n\...

# %%
# 데이터 프레임을 csv 로 저장
# df.to_csv("tweet_temp.csv", index=False)

# %% [markdown]
# -----

# %% [markdown]
# # <Step2. 추출> : 키워드 추출

# %% [markdown]
# ### [텍스트 데이터 전처리]
# - 한글 문자열을 기준으로 키워드 추출 수행
# - tweet_text 데이터에서 한글 문자열만을 추출하여 ko_text 생성

# %%
#df = pd.read_csv("tweet_temp.csv")
#df.head()

# %%
# 정규표현 라이브러리
import re

# 텍스트 정제 함수 : 한글 및 띄어쓰기 이외의 문자는 전부 제거
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+') # 한글의 정규표현식
    result = hangul.sub('', text)
    return result

# %%
# 텍스트 정제 함수text_cleaning()를 ‘tweet_text’ 피처에 이를 적용, 한글과 띄어쓰기만 추출하여 ko_text 피처 생성
df['ko_text'] = df['tweet_text'].apply(lambda x: text_cleaning(x))
df.head()
# Out:
#                           created  \
# 0  Thu Feb 10 01:27:28 +0000 2022
# 1  Thu Feb 10 01:27:01 +0000 2022
# 2  Thu Feb 10 01:25:43 +0000 2022
# 3  Thu Feb 10 01:25:36 +0000 2022
# 4  Thu Feb 10 01:25:21 +0000 2022
#
#                                           tweet_text  \
# 0  RT @Spurs_KR: [손흥민 선수 득점 경기 H/L] 손흥민 21/22시즌 프...
# 1  RT @ssonsal__0708: 손흥민 골장면이나 다시보자 https://t.co...
# 2  RT @Spurs_KR: [손흥민 선수 득점 경기 H/L] 손흥민 21/22시즌 프...
# 3  RT @Spurs_KR: [손흥민 선수 득점 경기 H/L] 손흥민 21/22시즌 프...
# 4  RT @Spurs_KR: 손흥민 선수의 프리미어리그 시즌 9호골이 나옵니다!!\n\...
#
#                                              ko_text
# 0    손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민
# 1                                    손흥민 골장면이나 다시보자
# 2    손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민
# 3    손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민
# 4            손흥민 선수의 프리미어리그 시즌 호골이 나옵니다  토트넘 손흥민

# %% [markdown]
# -----

# %% [markdown]
# ### [konlpy를 이용한 키워드 추출]
# - 명사만 추출한 후 불용어 및 한글자 키워드 제거

# %%
from konlpy.tag import Okt
from collections import Counter

# 불용어 사전의 텍스트 문서 읽어 stopwords 리스트 생성
# 한국어 약식 불용어사전 예시 파일, 출처 - (https://www.ranks.nl/stopwords/korean)
korean_stopwords_path = "../data/korean_stopwords.txt"
with open(korean_stopwords_path, encoding='utf8') as f:
    stopwords = f.readlines()
stopwords = [x.strip() for x in stopwords] # strip()으로 공백 및 줄바꿈 제거

# 품사 중 명사만 추출하여 한글자 키워드 및 불용어 제거
# Okt(Open Korean Text)는 트위터에서 만든 오픈소스 한국어 처리기인 twitter-korean-text를 이어받아 만들고 있는 프로젝트

def get_nouns(x):
    # 명사만 추출
    nouns_tagger = Okt() # Okt()클래스 선언
    nouns = nouns_tagger.nouns(x)
    
    # 한글자 키워드 제거
    nouns = [noun for noun in nouns if len(noun) > 1]
    
    # 불용어를 제거
    nouns = [noun for noun in nouns if noun not in stopwords]
    
    return nouns

# %%
stopwords
# Out:
# ['아',
#  '휴',
#  '아이구',
#  '아이쿠',
#  '아이고',
#  '어',
#  '나',
#  '우리',
#  '저희',
#  '따라',
#  '의해',
#  '을',
#  '를',
#  '에',
#  '의',
#  '가',
#  '으로',
#  '로',
#  '에게',
#  '뿐이다',
#  '의거하여',
#  '근거하여',
#  '입각하여',
#  '기준으로',
#  '예하면',
#  '예를 들면',
#  '예를 들자면',
#  '저',
#  '소인',
#  '소생',
#  '저희',
#  '지말고',
#  '하지마',
#  '하지마라',
#  '다른',
#  '물론',
#  '또한',
#  '그리고',
#  '비길수 없다',
#  '해서는 안된다',
#  '뿐만 아니라',
#  '만이 아니다',
#  '만은 아니다',
#  '막론하고',
#  '관계없이',
#  '그치지 않다',
#  '그러나',
#  '그런데',
#  '하지만',
#  '든간에',
#  '논하지 않다',
#  '따지지 않다',
#  '설사',
#  '비록',
#  '더라도',
#  '아니면',
#  '만 못하다',
#  '하는 편이 낫다',
#  '불문하고',
#  '향하여',
#  '향해서',
#  '향하다',
#  '쪽으로',
#  '틈타',
#  '이용하여',
#  '타다',
#  '오르다',
#  '제외하고',
#  '이 외에',
#  '이 밖에',
#  '하여야',
#  '비로소',
#  '한다면 몰라도',
#  '외에도',
#  '이곳',
#  '여기',
#  '부터',
#  '기점으로',
#  '따라서',
#  '할 생각이다',
#  '하려고하다',
#  '이리하여',
#  '그리하여',
#  '그렇게 함으로써',
#  '하지만',
#  '일때',
#  '할때',
#  '앞에서',
#  '중에서',
#  '보는데서',
#  '으로써',
#  '로써',
#  '까지',
#  '해야한다',
#  '일것이다',
#  '반드시',
#  '할줄알다',
#  '할수있다',
#  '할수있어',
#  '임에 틀림없다',
#  '한다면',
#  '등',
#  '등등',
#  '제',
#  '겨우',
#  '단지',
#  '다만',
#  '할뿐',
#  '딩동',
#  '댕그',
#  '대해서',
#  '대하여',
#  '대하면',
#  '훨씬',
#  '얼마나',
#  '얼마만큼',
#  '얼마큼',
#  '남짓',
#  '여',
#  '얼마간',
#  '약간',
#  '다소',
#  '좀',
#  '조금',
#  '다수',
#  '몇',
#  '얼마',
#  '지만',
#  '하물며',
#  '또한',
#  '그러나',
#  '그렇지만',
#  '하지만',
#  '이외에도',
#  '대해 말하자면',
#  '뿐이다',
#  '다음에',
#  '반대로',
#  '반대로 말하자면',
#  '이와 반대로',
#  '바꾸어서 말하면',
#  '바꾸어서 한다면',
#  '만약',
#  '그렇지않으면',
#  '까악',
#  '툭',
#  '딱',
#  '삐걱거리다',
#  '보드득',
#  '비걱거리다',
#  '꽈당',
#  '응당',
#  '해야한다',
#  '에 가서',
#  '각',
#  '각각',
#  '여러분',
#  '각종',
#  '각자',
#  '제각기',
#  '하도록하다',
#  '와',
#  '과',
#  '그러므로',
#  '그래서',
#  '고로',
#  '한 까닭에',
#  '하기 때문에',
#  '거니와',
#  '이지만',
#  '대하여',
#  '관하여',
#  '관한',
#  '과연',
#  '실로',
#  '아니나다를가',
#  '생각한대로',
#  '진짜로',
#  '한적이있다',
#  '하곤하였다',
#  '하',
#  '하하',
#  '허허',
#  '아하',
#  '거바',
#  '와',
#  '오',
#  '왜',
#  '어째서',
#  '무엇때문에',
#  '어찌',
#  '하겠는가',
#  '무슨',
#  '어디',
#  '어느곳',
#  '더군다나',
#  '하물며',
#  '더욱이는',
#  '어느때',
#  '언제',
#  '야',
#  '이봐',
#  '어이',
#  '여보시오',
#  '흐흐',
#  '흥',
#  '휴',
#  '헉헉',
#  '헐떡헐떡',
#  '영차',
#  '여차',
#  '어기여차',
#  '끙끙',
#  '아야',
#  '앗',
#  '아야',
#  '콸콸',
#  '졸졸',
#  '좍좍',
#  '뚝뚝',
#  '주룩주룩',
#  '솨',
#  '우르르',
#  '그래도',
#  '또',
#  '그리고',
#  '바꾸어말하면',
#  '바꾸어말하자면',
#  '혹은',
#  '혹시',
#  '답다',
#  '및',
#  '그에 따르는',
#  '때가 되어',
#  '즉',
#  '지든지',
#  '설령',
#  '가령',
#  '하더라도',
#  '할지라도',
#  '일지라도',
#  '지든지',
#  '몇',
#  '거의',
#  '하마터면',
#  '인젠',
#  '이젠',
#  '된바에야',
#  '된이상',
#  '만큼\t어찌됏든',
#  '그위에',
#  '게다가',
#  '점에서 보아',
#  '비추어 보아',
#  '고려하면',
#  '하게될것이다',
#  '일것이다',
#  '비교적',
#  '좀',
#  '보다더',
#  '비하면',
#  '시키다',
#  '하게하다',
#  '할만하다',
#  '의해서',
#  '연이서',
#  '이어서',
#  '잇따라',
#  '뒤따라',
#  '뒤이어',
#  '결국',
#  '의지하여',
#  '기대여',
#  '통하여',
#  '자마자',
#  '더욱더',
#  '불구하고',
#  '얼마든지',
#  '마음대로',
#  '주저하지 않고',
#  '곧',
#  '즉시',
#  '바로',
#  '당장',
#  '하자마자',
#  '밖에 안된다',
#  '하면된다',
#  '그래',
#  '그렇지',
#  '요컨대',
#  '다시 말하자면',
#  '바꿔 말하면',
#  '즉',
#  '구체적으로',
#  '말하자면',
#  '시작하여',
#  '시초에',
#  '이상',
#  '허',
#  '헉',
#  '허걱',
#  '바와같이',
#  '해도좋다',
#  '해도된다',
#  '게다가',
#  '더구나',
#  '하물며',
#  '와르르',
#  '팍',
#  '퍽',
#  '펄렁',
#  '동안',
#  '이래',
#  '하고있었다',
#  '이었다',
#  '에서',
#  '로부터',
#  '까지',
#  '예하면',
#  '했어요',
#  '해요',
#  '함께',
#  '같이',
#  '더불어',
#  '마저',
#  '마저도',
#  '양자',
#  '모두',
#  '습니다',
#  '가까스로',
#  '하려고하다',
#  '즈음하여',
#  '다른',
#  '다른 방면으로',
#  '해봐요',
#  '습니까',
#  '했어요',
#  '말할것도 없고',
#  '무릎쓰고',
#  '개의치않고',
#  '하는것만 못하다',
#  '하는것이 낫다',
#  '매',
#  '매번',
#  '들',
#  '모',
#  '어느것',
#  '어느',
#  '로써',
#  '갖고말하자면',
#  '어디',
#  '어느쪽',
#  '어느것',
#  '어느해',
#  '어느 년도',
#  '라 해도',
#  '언젠가',
#  '어떤것',
#  '어느것',
#  '저기',
#  '저쪽',
#  '저것',
#  '그때',
#  '그럼',
#  '그러면',
#  '요만한걸',
#  '그래',
#  '그때',
#  '저것만큼',
#  '그저',
#  '이르기까지',
#  '할 줄 안다',
#  '할 힘이 있다',
#  '너',
#  '너희',
#  '당신',
#  '어찌',
#  '설마',
#  '차라리',
#  '할지언정',
#  '할지라도',
#  '할망정',
#  '할지언정',
#  '구토하다',
#  '게우다',
#  '토하다',
#  '메쓰겁다',
#  '옆사람',
#  '퉤',
#  '쳇',
#  '의거하여',
#  '근거하여',
#  '의해',
#  '따라',
#  '힘입어',
#  '그',
#  '다음',
#  '버금',
#  '두번째로',
#  '기타',
#  '첫번째로',
#  '나머지는',
#  '그중에서',
#  '견지에서',
#  '형식으로 쓰여',
#  '입장에서',
#  '위해서',
#  '단지',
#  '의해되다',
#  '하도록시키다',
#  '뿐만아니라',
#  '반대로',
#  '전후',
#  '전자',
#  '앞의것',
#  '잠시',
#  '잠깐',
#  '하면서',
#  '그렇지만',
#  '다음에',
#  '그러한즉',
#  '그런즉',
#  '남들',
#  '아무거나',
#  '어찌하든지',
#  '같다',
#  '비슷하다',
#  '예컨대',
#  '이럴정도로',
#  '어떻게',
#  '만약',
#  '만일',
#  '위에서 서술한바와같이',
#  '인 듯하다',
#  '하지 않는다면',
#  '만약에',
#  '무엇',
#  '무슨',
#  '어느',
#  '어떤',
#  '아래윗',
#  '조차',
#  '한데',
#  '그럼에도 불구하고',
#  '여전히',
#  '심지어',
#  '까지도',
#  '조차도',
#  '하지 않도록',
#  '않기 위하여',
#  '때',
#  '시각',
#  '무렵',
#  '시간',
#  '동안',
#  '어때',
#  '어떠한',
#  '하여금',
#  '네',
#  '예',
#  '우선',
#  '누구',
#  '누가 알겠는가',
#  '아무도',
#  '줄은모른다',
#  '줄은 몰랏다',
#  '하는 김에',
#  '겸사겸사',
#  '하는바',
#  '그런 까닭에',
#  '한 이유는',
#  '그러니',
#  '그러니까',
#  '때문에',
#  '그',
#  '너희',
#  '그들',
#  '너희들',
#  '타인',
#  '것',
#  '것들',
#  '너',
#  '위하여',
#  '공동으로',
#  '동시에',
#  '하기 위하여',
#  '어찌하여',
#  '무엇때문에',
#  '붕붕',
#  '윙윙',
#  '나',
#  '우리',
#  '엉엉',
#  '휘익',
#  '윙윙',
#  '오호',
#  '아하',
#  '어쨋든',
#  '만 못하다\t하기보다는',
#  '차라리',
#  '하는 편이 낫다',
#  '흐흐',
#  '놀라다',
#  '상대적으로 말하자면',
#  '마치',
#  '아니라면',
#  '쉿',
#  '그렇지 않으면',
#  '그렇지 않다면',
#  '안 그러면',
#  '아니었다면',
#  '하든지',
#  '아니면',
#  '이라면',
#  '좋아',
#  '알았어',
#  '하는것도',
#  '그만이다',
#  '어쩔수 없다',
#  '하나',
#  '일',
#  '일반적으로',
#  '일단',
#  '한켠으로는',
#  '오자마자',
#  '이렇게되면',
#  '이와같다면',
#  '전부',
#  '한마디',
#  '한항목',
#  '근거로',
#  '하기에',
#  '아울러',
#  '하지 않도록',
#  '않기 위해서',
#  '이르기까지',
#  '이 되다',
#  '로 인하여',
#  '까닭으로',
#  '이유만으로',
#  '이로 인하여',
#  '그래서',
#  '이 때문에',
#  '그러므로',
#  '그런 까닭에',
#  '알 수 있다',
#  '결론을 낼 수 있다',
#  '으로 인하여',
#  '있다',
#  '어떤것',
#  '관계가 있다',
#  '관련이 있다',
#  '연관되다',
#  '어떤것들',
#  '에 대해',
#  '이리하여',
#  '그리하여',
#  '여부',
#  '하기보다는',
#  '하느니',
#  '하면 할수록',
#  '운운',
#  '이러이러하다',
#  '하구나',
#  '하도다',
#  '다시말하면',
#  '다음으로',
#  '에 있다',
#  '에 달려 있다',
#  '우리',
#  '우리들',
#  '오히려',
#  '하기는한데',
#  '어떻게',
#  '어떻해',
#  '어찌됏어',
#  '어때',
#  '어째서',
#  '본대로',
#  '자',
#  '이',
#  '이쪽',
#  '여기',
#  '이것',
#  '이번',
#  '이렇게말하자면',
#  '이런',
#  '이러한',
#  '이와 같은',
#  '요만큼',
#  '요만한 것',
#  '얼마 안 되는 것',
#  '이만큼',
#  '이 정도의',
#  '이렇게 많은 것',
#  '이와 같다',
#  '이때',
#  '이렇구나',
#  '것과 같이',
#  '끼익',
#  '삐걱',
#  '따위',
#  '와 같은 사람들',
#  '부류의 사람들',
#  '왜냐하면',
#  '중의하나',
#  '오직',
#  '오로지',
#  '에 한하다',
#  '하기만 하면',
#  '도착하다',
#  '까지 미치다',
#  '도달하다',
#  '정도에 이르다',
#  '할 지경이다',
#  '결과에 이르다',
#  '관해서는',
#  '여러분',
#  '하고 있다',
#  '한 후',
#  '혼자',
#  '자기',
#  '자기집',
#  '자신',
#  '우에 종합한것과같이',
#  '총적으로 보면',
#  '총적으로 말하면',
#  '총적으로',
#  '대로 하다',
#  '으로서',
#  '참',
#  '그만이다',
#  '할 따름이다',
#  '쿵',
#  '탕탕',
#  '쾅쾅',
#  '둥둥',
#  '봐',
#  '봐라',
#  '아이야',
#  '아니',
#  '와아',
#  '응',
#  '아이',
#  '참나',
#  '년',
#  '월',
#  '일',
#  '령',
#  '영',
#  '일',
#  '이',
#  '삼',
#  '사',
#  '오',
#  '육',
#  '륙',
#  '칠',
#  '팔',
#  '구',
#  '이천육',
#  '이천칠',
#  '이천팔',
#  '이천구',
#  '하나',
#  '둘',
#  '셋',
#  '넷',
#  '다섯',
#  '여섯',
#  '일곱',
#  '여덟',
#  '아홉',
#  '령',
#  '영']

# %%
# ‘ko_text’ 피처에 get_nouns() 함수를 적용하여 불용어 및 한글자를 제거한 명사 추출하여 'nouns' 피처 생성
df['nouns'] = df['ko_text'].apply(lambda x: get_nouns(x))
print(df.shape) # 행과 열의 갯수를 튜플로 반환
df.head()
# Out:
# (1000, 4)
#                           created  \
# 0  Thu Feb 10 01:27:28 +0000 2022
# 1  Thu Feb 10 01:27:01 +0000 2022
# 2  Thu Feb 10 01:25:43 +0000 2022
# 3  Thu Feb 10 01:25:36 +0000 2022
# 4  Thu Feb 10 01:25:21 +0000 2022
#
#                                           tweet_text  \
# 0  RT @Spurs_KR: [손흥민 선수 득점 경기 H/L] 손흥민 21/22시즌 프...
# 1  RT @ssonsal__0708: 손흥민 골장면이나 다시보자 https://t.co...
# 2  RT @Spurs_KR: [손흥민 선수 득점 경기 H/L] 손흥민 21/22시즌 프...
# 3  RT @Spurs_KR: [손흥민 선수 득점 경기 H/L] 손흥민 21/22시즌 프...
# 4  RT @Spurs_KR: 손흥민 선수의 프리미어리그 시즌 9호골이 나옵니다!!\n\...
#
#                                              ko_text  \
# 0    손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민
# 1                                    손흥민 골장면이나 다시보자
# 2    손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민
# 3    손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민
# 4            손흥민 선수의 프리미어리그 시즌 호골이 나옵니다  토트넘 손흥민
#
#                                                nouns
# 0  [손흥민, 선수, 득점, 경기, 손흥민, 시즌, 프리미어리그, 호골, 사우스햄튼, ...
# 1                                      [손흥민, 장면, 다시]
# 2  [손흥민, 선수, 득점, 경기, 손흥민, 시즌, 프리미어리그, 호골, 사우스햄튼, ...
# 3  [손흥민, 선수, 득점, 경기, 손흥민, 시즌, 프리미어리그, 호골, 사우스햄튼, ...
# 4                [손흥민, 선수, 프리미어리그, 시즌, 호골, 토트넘, 손흥민]

# %% [markdown]
# -----

# %% [markdown]
# # <Step3. 분석> : 연관 분석을 이용한 키워드 분석

# %% [markdown]
# ### [연관 키워드 추출하기]

# %% [markdown]
# ### [연관 규칙]
# - https://ratsgo.github.io/machine%20learning/2017/04/08/apriori/
# - 연관규칙 (아프리오리, Apriori 알고리즘) https://blog.naver.com/zzz90zzz/221807210555
# - 연관규칙은 비지도학습으로 대규모 거래 데이터로 부터 함께 구매될 규칙을 도출하여 고객이 특정 상품 구매시 이와 연관성이 높은 상품을 추천하는 것
# - Apriori 알고리즘 : 간단한 성능 측정치를 이용해 거대한 DB에서 데이터간의 연관성을 찾는 알고리즘
# ### [ 연관규칙에서 사용하는 3가지 통계척도 ]
# - 1. 지지도 (support)  : 특정 아이템이 데이터에서 발생하는 빈도
# - 2. 신뢰도 (confidence) : 두 아이템의 연관규칙이 유용한 규칙일 가능성의 척도
# - 3. 향상도 (lift) : 두 아이템의 연관 규칙이 우연인지 아닌지를 나타내는 척도
#
# - 아래 코드 실행을 위해, anaconda prompt 혹은 Terminal에서 아래와 같은 패키지들을 설치
#     - (env_name) `pip install apriori apyori`
# - 혹은 아래의 코드로 라이브러리를 설치

# %%
# !pip install apriori apyori
# Out:
# Requirement already satisfied: apriori in c:\users\yj\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: apyori in c:\users\yj\anaconda3\lib\site-packages (1.1.2)

# %% [markdown]
# ##### 연관 분석 연습

# %%
##### 연관 분석 연습 1
from apyori import apriori

# 장바구니 형태의 데이터(트랜잭션 데이터)를 생성
transactions = [
    ['손흥민', '시소코'],
    ['손흥민', '케인'],
    ['손흥민', '케인', '포체티노']
]

# 연관 분석을 수행
results = list(apriori(transactions))
for result in results:
    print(result)
# Out:
# RelationRecord(items=frozenset({'손흥민'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'시소코'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'시소코'}), confidence=0.3333333333333333, lift=1.0)])
# RelationRecord(items=frozenset({'케인'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'케인'}), confidence=0.6666666666666666, lift=1.0)])
# RelationRecord(items=frozenset({'포체티노'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'포체티노'}), confidence=0.3333333333333333, lift=1.0)])
# RelationRecord(items=frozenset({'시소코', '손흥민'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'시소코', '손흥민'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'시소코'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'시소코'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'케인', '손흥민'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'케인', '손흥민'}), confidence=0.6666666666666666, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'케인'}), confidence=0.6666666666666666, lift=1.0), OrderedStatistic(items_base=frozenset({'케인'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'포체티노', '손흥민'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'포체티노', '손흥민'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'포체티노'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'포체티노'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'포체티노', '케인'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'포체티노', '케인'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'케인'}), items_add=frozenset({'포체티노'}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({'포체티노'}), items_add=frozenset({'케인'}), confidence=1.0, lift=1.5)])
# RelationRecord(items=frozenset({'포체티노', '케인', '손흥민'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'포체티노', '케인', '손흥민'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'포체티노', '케인'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'케인'}), items_add=frozenset({'포체티노', '손흥민'}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({'포체티노'}), items_add=frozenset({'케인', '손흥민'}), confidence=1.0, lift=1.5), OrderedStatistic(items_base=frozenset({'케인', '손흥민'}), items_add=frozenset({'포체티노'}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({'포체티노', '손흥민'}), items_add=frozenset({'케인'}), confidence=1.0, lift=1.5), OrderedStatistic(items_base=frozenset({'포체티노', '케인'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])

# %%
##### 연관 분석 연습 2
# 지지도 0.5, 신뢰도 0.6, 향상도 1.0 이상이면서 (손흥민, 케인) 처럼 규칙의 크기가 2 이하인 규칙을 추출
list(apriori(transactions,
             min_support=0.5,
             min_confidence=0.6,
             min_lift=1.0,
             max_length=2))
# Out:
# [RelationRecord(items=frozenset({'손흥민'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'케인'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'케인'}), confidence=0.6666666666666666, lift=1.0)]),
#  RelationRecord(items=frozenset({'케인', '손흥민'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'케인', '손흥민'}), confidence=0.6666666666666666, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'케인'}), confidence=0.6666666666666666, lift=1.0), OrderedStatistic(items_base=frozenset({'케인'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])]

# %% [markdown]
# -----

# %% [markdown]
# ##### 트위터 연관 키워드 분석

# %%
# 트랜잭션 데이터를 추출
transactions = df['nouns'].tolist()
#transactions = [transaction for transaction in transactions if transaction] # 공백 문자열을 방지
print(transactions)
# Out:
# [['손흥민', '선수', '득점', '경기', '손흥민', '시즌', '프리미어리그', '호골', '사우스햄튼', '토트넘', '손흥민'], ['손흥민', '장면', '다시'], ['손흥민', '선수', '득점', '경기', '손흥민', '시즌', '프리미어리그', '호골', '사우스햄튼', '토트넘', '손흥민'], ['손흥민', '선수', '득점', '경기', '손흥민', '시즌', '프리미어리그', '호골', '사우스햄튼', '토트넘', '손흥민'], ['손흥민', '선수', '프리미어리그', '시즌', '호골', '토트넘', '손흥민'], ['연느', '발리', '나이', '살이', '안정환', '선수', '손흥민', '선수', '나이', '차도', '축구', '얘기', '선수', '비교', '비교', '자체', '의미', '피겨'], ['연느', '발리', '나이', '살이', '안정환', '선수', '손흥민', '선수', '나이', '차도', '축구', '얘기', '선수', '비교', '비교', '자체', '의미', '피겨'], ['손흥민', '선수', '득점', '경기', '손흥민', '시즌', '프리미어리그', '호골', '사우스햄튼', '토트넘', '손흥민'], ['연느', '발리', '나이', '살이', '안정환', '선수', '손흥민', '선수', '나이', '차도', '축구', '얘기', '선수', '비교', '비교', '자체', '의미', '피겨'], ['연느', '발리', '나이', '살이', '안정환', '선수', '손흥민', '선수', '나이', '차도', '축구', '얘기', '선수', '비교', '비교', '자체', '의미', '피겨'], ['연느', '발리', '나이', '살이', '안정환', '선수', '손흥민', '선수', '나이', '차도', '축구', '얘기', '선수', '비교', '비교', '자체', '의미', '피겨'], ['손흥민', '선수', '득점', '경기', '손흥민', '시즌', '프리미어리그', '호골', '사우스햄튼'], ['비몽', '손흥민', '와우', '타이밍', '지리', '자리', '헤딩', '데자뷰', '토트넘', '수비'], ['손흥민', '장면', '다시'], ['옛날', '우리나라', '인구', '중국', '인구', '비교', '중국', '손흥민', '정도'], ['손흥민', '감각'], ['도착', '토트넘', '손흥민'], ['토트넘', '손흥민', '활약', '출처', '네이버'], ['손흥민', '선수', '득점', '경기', '손흥민', '시즌', '프리미어리그', '호골', '사우스햄튼', '토트넘', '손흥민'], ['손흥민', '선수', '득점', '경기', '손흥민', '시즌', '프리미어리그', '호골', '사우스햄튼'], ['손흥민', '장면', '다시'], ['손흥민', '선수', '득점', '경기', '손흥민', '시즌', '프리미어리그', '호골', '사우스햄튼', '토트넘', '손흥민'], ['손흥민', '콘테', '감동', '손흥민', '역전', '출처', '네이버'], ['연느', '발리', '나이', '살이', '안정환', '선수', '손흥민', '선수', '나이', '차도', '축구', '얘기', '선수', '비교', '비교', '자체', '의미', '피겨'], ['빛바랜', '평점', '손흥민', '실망', '결과'], ['손흥민', '선수', '득점', '경기', '손흥민', '시즌', '프리미어리그', '호골', '사우스햄튼', '토트넘', '손흥민'], 
ordered_statistics=[OrderedStatistic(items_base=frozenset({'가슴'}), items_add=frozenset({'출장'}), confidence=0.9863013698630136, lift=13.510977669356352), OrderedStatistic(items_base=frozenset({'출장'}), items_add=frozenset({'가슴'}), confidence=0.9863013698630136, lift=13.510977669356352)]), RelationRecord(items=frozenset({'발리', '나이'}), support=0.114, ordered_statistics=[OrderedStatistic(items_base=frozenset({'나이'}), items_add=frozenset({'발리'}), confidence=1.0, lift=8.771929824561402), OrderedStatistic(items_base=frozenset({'발리'}), items_add=frozenset({'나이'}), confidence=1.0, lift=8.771929824561402)]), RelationRecord(items=frozenset({'비교', '나이'}), support=0.114, ordered_statistics=[OrderedStatistic(items_base=frozenset({'나이'}), items_add=frozenset({'비교'}), confidence=1.0, lift=7.092198581560284), OrderedStatistic(items_base=frozenset({'비교'}), items_add=frozenset({'나이'}), confidence=0.8085106382978724, lift=7.092198581560284)]), RelationRecord(items=frozenset({'살이', '나이'}), support=0.114, ordered_statistics=[OrderedStatistic(items_base=frozenset({'나이'}), items_add=frozenset({'살이'}), confidence=1.0, lift=6.849315068493151), OrderedStatistic(items_base=frozenset({'살이'}), items_add=frozenset({'나이'}), confidence=0.7808219178082193, lift=6.849315068493151)]), RelationRecord(items=frozenset({'안정환', '나이'}), support=0.114, ordered_statistics=[OrderedStatistic(items_base=frozenset({'나이'}), items_add=frozenset({'안정환'}), confidence=1.0, lift=8.695652173913043), OrderedStatistic(items_base=frozenset({'안정환'}), items_add=frozenset({'나이'}), confidence=0.9913043478260869, lift=8.695652173913043)]), RelationRecord(items=frozenset({'얘기', '나이'}), support=0.114, ordered_statistics=[OrderedStatistic(items_base=frozenset({'나이'}), items_add=frozenset({'얘기'}), confidence=1.0, lift=8.620689655172413), OrderedStatistic(items_base=frozenset({'얘기'}), items_add=frozenset({'나이'}), confidence=0.9827586206896551, lift=8.620689655172413)]), RelationRecord(items=frozenset({'연느', '나이'}), support=0.114, ordered_statistics=[OrderedStatistic(items_base=frozenset({'나이'}), items_add=frozenset({'연느'}), confidence=1.0, lift=8.695652173913043), OrderedStatistic(items_base=frozenset({'연느'}), items_add=frozenset({'나이'}), confidence=0.9913043478260869, lift=8.695652173913043)]), RelationRecord(items=frozenset({'의미', '나이'}), support=0.114, ordered_statistics=[OrderedStatistic(items_base=frozenset({'나이'}), items_add=frozenset({'의미'}), confidence=1.0, lift=8.771929824561402), OrderedStatistic(items_base=frozenset({'의미'}), items_add=frozenset({'나이'}), confidence=1.0, lift=8.771929824561402)]), RelationRecord(items=frozenset({'자체', '나이'}), support=0.114, ordered_statistics=[OrderedStatistic(items_base=frozenset({'나이'}), items_add=frozenset({'자체'}), confidence=1.0, lift=8.547008547008547), OrderedStatistic(items_base=frozenset({'자체'}), items_add=frozenset({'나이'}), confidence=0.9743589743589743, lift=8.547008547008547)]), RelationRecord(items=frozenset({'차도', '나이'}), support=0.114, ordered_statistics=[OrderedStatistic(items_base=frozenset({'나이'}), items_add=frozenset({'차도'}), confidence=1.0, lift=8.771929824561402), OrderedStatistic(items_base=frozenset({'차도'}), items_add=frozenset({'나이'}), confidence=1.0, lift=8.771929824561402)]), RelationRecord(items=frozenset({'축구', '나이'}), support=0.114, ordered_statistics=[OrderedStatistic(items_base=frozenset({'나이'}), items_add=frozenset({'축구'}), confidence=1.0, lift=7.142857142857142), OrderedStatistic(items_base=frozenset({'축구'}), items_add=frozenset({'나이'}), confidence=0.8142857142857143, lift=7.142857142857142)]), RelationRecord(items=fr ...

# %%
# 데이터 프레임 형태로 정리
columns = ['source', 'target', 'support']
network_df = pd.DataFrame(columns=columns)

# 규칙의 조건절을 source, 결과절을 target, 지지도를 support 라는 데이터 프레임의 피처로 변환
for result in results:
    if len(result.items) == 2:
        items = [x for x in result.items]
        row = [items[0], items[1], result.support]
        series = pd.Series(row, index=network_df.columns)
        network_df = network_df.append(series, ignore_index=True)

network_df.head()
# Out:
#   source target  support
# 0     만남     가슴    0.072
# 1     가슴     출장    0.072
# 2     발리     나이    0.114
# 3     비교     나이    0.114
# 4     살이     나이    0.114

# %% [markdown]
# -----

# %% [markdown]
# ### [단어 빈도 추출하기]

# %% [markdown]
# ##### 말뭉치 추출

# %%
# 말뭉치를 추출합
tweet_corpus = "".join(df['ko_text'].tolist())
print(tweet_corpus)
# Out:
#   손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민   손흥민 골장면이나 다시보자   손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민   손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민   손흥민 선수의 프리미어리그 시즌 호골이 나옵니다  토트넘 손흥민      연느랑 발리예바 나이차 살이고안정환 선수랑 손흥민 선수 나이차도 살축구 얘기할때 저 두 선수로 비교질 안하잖아요 년 이상의 시간이 지났는데 비교하는거 자체가 의미없다는걸 알기에  왜 꼭 피겨에만  연느랑 발리예바 나이차 살이고안정환 선수랑 손흥민 선수 나이차도 살축구 얘기할때 저 두 선수로 비교질 안하잖아요 년 이상의 시간이 지났는데 비교하는거 자체가 의미없다는걸 알기에  왜 꼭 피겨에만  손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민   연느랑 발리예바 나이차 살이고안정환 선수랑 손흥민 선수 나이차도 살축구 얘기할때 저 두 선수로 비교질 안하잖아요 년 이상의 시간이 지났는데 비교하는거 자체가 의미없다는걸 알기에  왜 꼭 피겨에만  연느랑 발리예바 나이차 살이고안정환 선수랑 손흥민 선수 나이차도 살축구 얘기할때 저 두 선수로 비교질 안하잖아요 년 이상의 시간이 지났는데 비교하는거 자체가 의미없다는걸 알기에  왜 꼭 피겨에만  연느랑 발리예바 나이차 살이고안정환 선수랑 손흥민 선수 나이차도 살축구 얘기할때 저 두 선수로 비교질 안하잖아요 년 이상의 시간이 지났는데 비교하는거 자체가 의미없다는걸 알기에  왜 꼭 피겨에만손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼 힘들게 힘들게 눈 떠서 켰다 비몽사몽에 손흥민 골 들어가는걸 봄 와우 타이밍 지리고 ㅎㅎ그리고 똑같은 자리에서 똑같은 헤딩 두 번 맞고 지더라 ㅋㅋ데자뷰인가 아님 토트넘 수비는 ㅄ 인가 ㅋㅋ  손흥민 골장면이나 다시보자   옛날에 어디서 봤는데 우리나라 인구랑 중국 인구 비교했을 때 중국엔 손흥민이 명 정도는 있어야한다고 했음아니 손흥민 골감각 미쳤네  쏘니 도착  토트넘 손흥민   토트넘  햄튼 손흥민 활약상 출처    네이버   손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민 손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼    손흥민 골장면이나 다시보자   손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민  손흥민이 돌아왔다 콘테도 감동한 손흥민의 역전골 출처    네이버   연느랑 발리예바 나이차 살이고안정환 선수랑 손흥민 선수 나이차도 살축구 얘기할때 저 두 선수로 비교질 안하잖아요 년 이상의 시간이 지났는데 비교하는거 자체가 의미없다는걸 알기에  왜 꼭 피겨에만빛바랜 골평점 점 손흥민 많이 실망스러운 결과   손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민 실제영상  손흥민 리그 호골 자책골 유도  토트넘  사우샘프턴     연느랑 발리예바 나이차 살이고안정환 선수랑 손흥민 선수 나이차도 살축구 얘기할때 저 두 선수로 비교질 안하잖아요 년 이상의 시간이 지났는데 비교하는거 자체가 의미없다는걸 알기에  왜 꼭 피겨에만  사우스햄튼 상대로 토트넘 홋스퍼 스타디움을 도착한 손흥민 선수  토트넘 손흥민       손흥민                            손흥민        손흥민  연느랑 발리예바 나이차 살이고안정환 선수랑 손흥민 선수 나이차도 살축구 얘기할때 저 두 선수로 비교질 안하잖아요 년 이상의 시간이 지났는데 비교하는거 자체가 의미없다는걸 알기에  왜 꼭 피겨에만저사진만 보면손흥민이 떠오르는건나뿐인가ㅋㅋㅋㅋ   연느랑 발리예바 나이차 살이고안정환 선수랑 손흥민 선수 나이차도 살축구 얘기할때 저 두 선수로 비교질 안하잖아요 년 이상의 시간이 지났는데 비교하는거 자체가 의미없다는걸 알기에  왜 꼭 피겨에만  쏘니 도착  토트넘 손흥민   손흥민 골장면이나 다시보자 손흥민이 골 넣으면 뭐하나 최악의 경기력결과의 토트넘  다음 스포츠   손흥민 선수의 프리미어리그 시즌 호골이 나옵니다  토트넘 손흥민      이번주의 쏘니캠   사우스햄튼전 손흥민    장면  토트넘 손흥민   워밍업 중인 우리 손흥민 선수   토트넘 손흥민    손흥민 골장면이나 다시보자   손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민   손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민   손흥민 골장면이나 다시보자   손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민   사우스햄튼 상대로 토트넘 홋스퍼 스타디움을 도착한 손흥민 선수  토트넘 손흥민   쏘니 도착  토트넘 손흥민   워밍업 중인 우리 손흥민 선수   토트넘 손흥민    손흥민 선수의 프리미어리그 시즌 호골이 나옵니다  토트넘 손흥민       찬우살이  만 기념 손흥민 만나고 왔습니다           아  손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민   사우스햄튼 상대로 토트넘 홋스퍼 스타디움을 도착한 손흥민 선수  토트넘 손흥민   손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민   월클 손흥민 스카이스포츠 선정 올 시즌   스포츠타임 출처  네이버 스포츠   손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민   손흥민 골장면이나 다시보자   월클 손흥민 스카이스포츠 선정 올 시즌   스포츠타임 출처  네이버 스포츠   연느랑 발리예바 나이차 살이고안정환 선수랑 손흥민 선수 나이차도 살축구 얘기할때 저 두 선수로 비교질 안하잖아요 년 이상의 시간이 지났는데 비교하는거 자체가 의미없다는걸 알기에  왜 꼭 피겨에만손흥민 사우스햄튼전 리그 호골 출처  파격과 순  블로그          손흥민      손흥민 복귀하자마자 골 박아줘도 지네  워밍업 중인 우리 손흥민 선수   토트넘 손흥민  와 손흥민 골 영상 ㄷㄷㄷㄷ  손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민   연느랑 발리예바 나이차 살이고안정환 선수랑 손흥민 선수 나이차도 살축구 얘기할때 저 두 선수로 비교질 안하잖아요 년 이상의 시간이 지났는데 비교하는거 자체가 의미없다는걸 알기에  왜 꼭 피겨에만손흥민 선수 득점 경기  손흥민 시즌 프리미어리그 호골  사우스햄튼  토트넘 손흥민 패배 속 빛난 손흥민 시즌 호골자책골 유도 손흥민 토트넘  박시인 기자    손흥민은 공식 대회에서 사우샘프턴을 상대로 가장 많은 득점골을 기록했다 토트넘 입단 이후 다른 팀을 상대할 때보다 다섯 골 이상 많은 기록이다 천적     손흥민은 공식 대회에서 사우샘프턴을 상대로 가장 많은 득점골을 기록했다 토트넘 입단 이후 다른 팀을 상대할 때보다 다섯 골 이상 많은 기록이다 천적     손흥민은 공식 대회에서 사우샘프턴을 상대로 가장 많은 득점골을 기록했다 토트넘 입단 이후 다른 팀을 상대할 때보다 다섯 골 이상 많은 기록이다 천적   손흥민은 공식 대회에서 사우샘프턴을 상대로 가장 많은 득점골을 기록했다 토트넘 입단 이후 다른 팀을 상대할 때보다 다섯 골 이상 많은 기록이다 천적 송소희 손흥민 언급 머리는 토트넘 가슴은  응원       손흥민 오늘의 경기 기록 타래 손흥민 시즌 호골  공동 위팀은 아쉽게  패배 ㅠㅠ 역전까지 좋았는데 한순간에 무너지네요 토트넘 챔피언스리그 가야 할 텐데이길 경기를 발목 잡히네요 사이트대화손흥민코스타합천군부안패피중랑영섹아나고가발사하대급모임추억사진유성영광서천카메라첫줄   연느랑 발리예바 나이차 살이고안정환 선수랑 손흥민 선수 나이차도 살축구 얘기할때 저 두 선수로 비교질 안하잖아요 년 이상의 시간이 지났는데 비교하는거 자체가 의미없다는걸 알기에  왜 꼭 피겨에만  연느랑 발리예바 나이차 살이고안정환 선수랑 손흥민 선수 나이차도 살축구 얘기할때 저 두 선수로 비교질 안하잖아요 년 이상의 시간이 지났는데 비교하는거 자체가 의미없다는걸 알기에  왜 꼭 피겨 ...

# %%
from konlpy.tag import Okt
from collections import Counter

# 명사 키워드를 추출, 빈도수 계산
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(tweet_corpus)
count = Counter(nouns)

# 한글자 키워드를 제거
remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
print(remove_char_counter)
# Out:
# Counter({'손흥민': 1157, '선수': 483, '토트넘': 315, '비교': 256, '나이': 228, '만남': 151, '살이': 146, '축구': 142, '이상': 119, '피겨': 119, '시간': 118, '얘기': 117, '자체': 117, '연느': 115, '안정환': 115, '발리': 114, '차도': 114, '의미': 114, '사우스햄튼': 102, '출장': 102, '중국': 100, '시즌': 75, '가슴': 73, '이번': 65, '호골': 59, '주
node_df = node_df[node_df['nodesize'] >= 50] # 시각화의 편의를 위해 ‘nodesize’ 50 이하는 제거합니다.
node_df.head()
# Out:
#     node  nodesize
# 0    손흥민      1157
# 1     선수       483
# 4     시즌        75
# 6     호골        59
# 7  사우스햄튼       102

# %% [markdown]
# -----

# %% [markdown]
# # <Step4. 시각화> : 연관 키워드 네트워크 시각화

# %% [markdown]
# ### [연관 키워드 네트워크 시각화]

# %% [markdown]
# - 아래 코드 실행을 위해, anaconda prompt 혹은 Terminal에서 아래와 같은 패키지를 설치해 줍니다.
#     - (env_name) `pip install networkx`
# - 혹은 아래의 코드로 라이브러리를 설치합니다.
# - networkx 버전 2.3 이하를 설치하는 경우, 아래 코드를 다음과 같이 바꿔주어야 합니다.
#     - `sizes = [G.nodes[node]['nodesize']*25 for node in G]` -> `sizes = [G.node[node]['nodesize']*25 for node in G]`

# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\users\yj\anaconda3\lib\site-packages (2.6.3)

# %% [markdown]
# ### [networkx 에러 대처 ]
# - [2022.02.04] 아래 코드 실행 시 random_state_index is incorrect 에러 발생
# - 주피터 노트북에서 networkx 라이브러리를 사용하려고 하는데 NetworkXError: random_state_index is incorrect 발생
# - decorator를 주피터에 실행하여 설치한 후 커널을 다시 시작해주면 깔끔하게 해결
# - 참조) https://velog.io/@seokunee/NetworkXError-randomstateindex-is-incorrect

# %%
# !pip install decorator==4.3
# Out:
# Requirement already satisfied: decorator==4.3 in c:\users\yj\anaconda3\lib\site-packages (4.3.0)

# %% [markdown]
# -----

# %%
import networkx as nx
plt.figure(figsize=(25,25))

# networkx 그래프 객체를 생성
G = nx.Graph()

# node_df의 키워드 빈도수를 데이터로 하여, 네트워크 그래프의 ‘노드’ 역할을 하는 원을 생성
for index, row in node_df.iterrows():
    G.add_node(row['node'], nodesize=row['nodesize'])
    
# network_df의 연관 분석 데이터를 기반으로, 네트워크 그래프의 ‘관계’ 역할을 하는 선을 생성
for index, row in network_df.iterrows():
    G.add_weighted_edges_from([(row['source'], row['target'], row['support'])])
    
# 그래프 디자인과 관련된 파라미터를 설정
pos = nx.spring_layout(G, k=0.6, iterations=50)
# nx.draw(G, pos=pos)
sizes = [G.nodes[node]['nodesize']*25 for node in G]
nx.draw(G, pos=pos, node_size=sizes)


# Windows 사용자는 AppleGothic 대신,'Malgun Gothic'. 그 외 OS는 OS에서 한글을 지원하는 기본 폰트를 입력
# nx.draw_networkx_labels(G, pos=pos, font_family='NanumGothic', font_size=25)
nx.draw_networkx_labels(G, pos=pos, font_family='Malgun Gothic', font_size=25)

# 그래프를 출력
ax = plt.gca()
plt.show()

# %%
G

# %%
node_df
# Out:
#       node  nodesize
# 0      손흥민      1157
# 1       선수       483
# 4       시즌        75
# 6       호골        59
# 7    사우스햄튼       102
# 8      토트넘       315
# 11      연느       115
# 12      발리       114
# 13      나이       228
# 14      살이       146
# 15     안정환       115
# 16      차도       114
# 17      축구       142
# 18      얘기       117
# 19      비교       256
# 20      이상       119
# 21      시간       118
# 22      자체       117
# 23      의미       114
# 24      피겨       119
# 36      중국       100
# 39      도착        57
# 64      이번        65
# 65      주의        58
# 94      가슴        73
# 309     자위        58
# 310     출장       102
# 311     만남       151
# 313     조건        55
