# %% [markdown]
# Copyright (c) 2019 [윤기태]
#
# https://github.com/yoonkt200/python-data-analysis
#
# [MIT License](https://github.com/yoonkt200/python-data-analysis/blob/master/LICENSE.txt)

# %% [markdown]
# # (가제) 파이썬 데이터 분석

# %% [markdown]
# -----

# %% [markdown]
# # 2.2) 트위터 API로 연관 키워드 분석하기

# %% [markdown]
# ### 바로가기

# %% [markdown]
# - [<Step1. API 호출> : 트위터 API로 데이터 가져오기](#<Step1.-API-호출>-:-트위터-API로-데이터-가져오기)
#     - [API 데이터로 데이터 프레임 생성하기]
# - [<Step2. 추출> : 키워드 추출](#<Step2.-추출>-:-키워드-추출)
#     - [텍스트 데이터 전처리]
#     - [nltk, konlpy를 이용한 키워드 추출]
# - [<Step3. 분석> : 연관 분석을 이용한 키워드 분석](#<Step3.-분석>-:-연관-분석을-이용한-키워드-분석)
#     - [연관 키워드 추출하기]
#     - [단어 빈도 추출하기]
# - [<Step4. 시각화> : 연관 키워드 네트워크 시각화](#<Step4.-시각화>-:-연관-키워드-네트워크-시각화)
#     - [연관 키워드 네트워크 시각화]

# %% [markdown]
# -----

# %%
# -*- coding: utf-8 -*-

# 주피터 노트북을 실행한 브라우저에서 바로 그림을 볼 수 있게끔 만드는 것
#브라우저 내부(inline)에 바로 그려지도록 해주는 코드
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # <Step1. API 호출> : 트위터 API로 데이터 가져오기

# %% [markdown]
# ### [API 데이터로 데이터 프레임 생성하기]
# - API 사용법 참고 : https://github.com/yoonkt200/python-data-analysis/blob/master/chapter_text/(%EC%B0%B8%EA%B3%A0)%20using-twitter-api.ipynb
# - 아래 코드 실행을 위해, anaconda prompt 혹은 Terminal에서 아래와 같은 패키지를 설치해 줍니다.
#     - (env_name) `pip install tweepy`
# - 혹은 아래의 코드로 라이브러리를 설치합니다.
# - [2022.02.04 ] tweepy 4 버전 설치시 api.search에서 에러 발생 => tweepy 3 버전으로 설치
# - pip install tweepy==3.10.0

# %%
#!pip install tweepy
# tweepy 3 버전으로 설치
# !pip install tweepy==3.10.0
# Out:
# Requirement already satisfied: tweepy==3.10.0 in c:\users\yj\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\yj\anaconda3\lib\site-packages (from tweepy==3.10.0) (1.3.1)
# Requirement already satisfied: six>=1.10.0 in c:\users\yj\anaconda3\lib\site-packages (from tweepy==3.10.0) (1.16.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\yj\anaconda3\lib\site-packages (from tweepy==3.10.0) (2.26.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\yj\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy==3.10.0) (3.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yj\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\yj\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yj\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yj\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (2021.10.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\yj\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (1.7.1)

# %% [markdown]
# -----

# %% [markdown]
# ##### 트위터 API 가져오기
# - 트위터의 키워드 크롤링 기능을 사용하기 위해 트위터 앱에서 발급받은 KEY와 TOKEN 정보를 입력
# - 총 4가지 정보를 입력하여 코드 실행
# - tweepy의 OAuthHandler() 클래스가 자동으로 개인정보 인증 완료

# %%
import tweepy

# 발급 완료된 키 입력
CONSUMER_KEY = "bF7ZmUgxM1ErWKMSAZL6b4CqI"
CONSUMER_SECRET = "lEefoafW8sVm4k3WXkAJlGBYJLnDfqIFfv0WKac4RthU2y5VHG"
ACCESS_TOKEN_KEY = "1486554047452565506-ItSR4coXMdd9DiGLFBiTeAoWtDdj1s"
ACCESS_TOKEN_SECRET = "GMv0jWwknIdn2l1lyFfBWE9cfvyCkemcBEtk0f9QshckV"

# 개인정보 인증을 요청하는 Handler
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)

# 인증 요청을 수행
auth.set_access_token(ACCESS_TOKEN_KEY, ACCESS_TOKEN_SECRET)

# twitter API를 사용하기 위한 준비
api = tweepy.API(auth)

# %%
# tweepy 버전 출력
tweepy.__version__
# Out:
# '3.10.0'

# %% [markdown]
# -----

# %% [markdown]
# #### '손흥민' 키워드 검색

# %%
# Twitter Developer Platform의 Data dictionary 참조
# https://developer.twitter.com/en/docs/twitter-api/v1/data-dictionary/object-model/tweet

# twitter API를 사용하여 '손흥민' 이 포함된 트윗들을 크롤링한 뒤, 'user_mentions'와 'hashtags' 속성값 추출
keyword = "패션"

# 특정 키워드 크롤링은  search() 함수 수행
tweets = api.search(keyword)

# entities() 함수로 특정 속성의 메타데이터에 접근하여 정보 추출
for tweet in tweets:
    print(tweet.text)
    print(tweet.entities['user_mentions'])
    print(tweet.entities['hashtags'])
    print(tweet.created_at) # 트윗이 생성된 UTC 시간, 예) "2022-02-04 01:47:09"
# Out:
# RT @BRILLER__613: 패션 에디터 박나나님 인스타 (1)
# https://t.co/zhZdFX0jcn https://t.co/2DYdXohwxf
# [{'screen_name': 'BRILLER__613', 'name': '브리이에', 'id': 1225314350367268864, 'id_str': '1225314350367268864', 'indices': [3, 16]}]
# []
# 2022-02-10 01:21:45
# RT @noze__baby: 리더즈 완전체 K-할머니 패션 #해치지않아
# #모니카 #허니제이 #아이키 #리헤이 #효진초이 #가비 #노제 #리정 https://t.co/PgVoOJn7QY
# [{'screen_name': 'noze__baby', 'name': '노제베이비🍼', 'id': 1466309620561969154, 'id_str': '1466309620561969154', 'indices': [3, 14]}]
# [{'text': '해치지않아', 'indices': [33, 39]}, {'text': '모니카', 'indices': [40, 44]}, {'text': '허니제이', 'indices': [45, 50]}, {'text': '아이키', 'indices': [51, 55]}, {'text': '리헤이', 'indices': [56, 60]}, {'text': '효진초이', 'indices': [61, 66]}, {'text': '가비', 'indices': [67, 70]}, {'text': '노제', 'indices': [71, 74]}, {'text': '리정', 'indices': [75, 78]}]
# 2022-02-10 01:21:33
# RT @noze__baby: 리더즈 완전체 K-할머니 패션 #해치지않아
# #모니카 #허니제이 #아이키 #리헤이 #효진초이 #가비 #노제 #리정 https://t.co/PgVoOJn7QY
# [{'screen_name': 'noze__baby', 'name': '노제베이비🍼', 'id': 1466309620561969154, 'id_str': '1466309620561969154', 'indices': [3, 14]}]
# [{'text': '해치지않아', 'indices': [33, 39]}, {'text': '모니카', 'indices': [40, 44]}, {'text': '허니제이', 'indices': [45, 50]}, {'text': '아이키', 'indices': [51, 55]}, {'text': '리헤이', 'indices': [56, 60]}, {'text': '효진초이', 'indices': [61, 66]}, {'text': '가비', 'indices': [67, 70]}, {'text': '노제', 'indices': [71, 74]}, {'text': '리정', 'indices': [75, 78]}]
# 2022-02-10 01:20:57
# RT @chtvn: 노제가 입으면 그게 패션이고 유행이다...🙊
# 꽃을 때려박은 시골룩에도 셔터 누르게 만드는 비주얼💕
#
# 풀버전 보러 가기👉 #tvN유튜브 #네이버TV
#
# [목] 저녁 8:40 tvN 본방송
# #tvN #해치지않아X스우파 #스우파
# #모니카…
# [{'screen_name': 'chtvn', 'name': 'tvN joy', 'id': 125209408, 'id_str': '125209408', 'indices': [3, 9]}]
# [{'text': 'tvN유튜브', 'indices': [78, 85]}, {'text': '네이버TV', 'indices': [86, 92]}, {'text': 'tvN', 'indices': [114, 118]}, {'text': '해치지않아X스우파', 'indices': [119, 129]}, {'text': '스우파', 'indices': [130, 134]}, {'text': '모니카', 'indices': [135, 139]}]
# 2022-02-10 01:20:52
# RT @chtvn: 노제가 입으면 그게 패션이고 유행이다...🙊
# 꽃을 때려박은 시골룩에도 셔터 누르게 만드는 비주얼💕
#
# 풀버전 보러 가기👉 #tvN유튜브 #네이버TV
#
# [목] 저녁 8:40 tvN 본방송
# #tvN #해치지않아X스우파 #스우파
# #모니카…
# [{'screen_name': 'chtvn', 'name': 'tvN joy', 'id': 125209408, 'id_str': '125209408', 'indices': [3, 9]}]
# [{'text': 'tvN유튜브', 'indices': [78, 85]}, {'text': '네이버TV', 'indices': [86, 92]}, {'text': 'tvN', 'indices': [114, 118]}, {'text': '해치지않아X스우파', 'indices': [119, 129]}, {'text': '스우파', 'indices': [130, 134]}, {'text': '모니카', 'indices': [135, 139]}]
# 2022-02-10 01:20:27
# #섹시
# #모델
# #패션
# #black
# #화보
# #블랙
# #collection
# #옴므
# #레이어드
# #아트
# #송지오
# #남성복
# #맞팔
# #model
# #컨펨포러리
# #컬랙션
# #백화점
# #프로필
# #소통
# #데일리룩
# #귀요미
# 0356Z1
# []
# [{'text': '섹시', 'indices': [0, 3]}, {'text': '모델', 'indices': [4, 7]}, {'text': '패션', 'indices': [8, 11]}, {'text': 'black', 'indices': [12, 18]}, {'text': '화보', 'indices': [19, 22]}, {'text': '블랙', 'indices': [23, 26]}, {'text': 'collection', 'indices': [27, 38]}, {'text': '옴므', 'indices': [39, 42]}, {'text': '레이어드', 'indices': [43, 48]}, {'text': '아트', 'indices': [49, 52]}, {'text': '송지오', 'indices': [53, 57]}, {'text': '남성복', 'indices': [58, 62]}, {'text': '맞팔', 'indices': [63, 66]}, {'text': 'model', 'indices': [67, 73]}, {'text': '컨펨포러리', 'indices': [74, 80]}, {'text': '컬랙션', 'indices': [81, 85]}, {'text': '백화점', 'indices': [86, 90]}, {'text': '프로필', 'indices': [91, 95]}, {'text': '소통', 'indices': [96, 99]}, {'text': '데일리룩', 'indices': [100, 105]}, {'text': '귀요미', 'indices': [106, 110]}]
# 2022-02-10 01:20:24
# RT @chtvn: 노제가 입으면 그게 패션이고 유행이다...🙊
# 꽃을 때려박은 시골룩에도 셔터 누르게 만드는 비주얼💕
#
# 풀버전 보러 가기👉 #tvN유튜브 #네이버TV
#
# [목] 저녁 8:40 tvN 본방송
# #tvN #해치지않아X스우파 #스우파
# #모니카…
# [{'screen_name': 'chtvn', 'name': 'tvN joy', 'id': 125209408, 'id_str': '125209408', 'indices': [3, 9]}]
# [{'text': 'tvN유튜브', 'indices': [78, 85]}, {'text': '네이버TV', 'indices': [86, 92]}, {'text': 'tvN', 'indices': [114, 118]}, {'text': '해치지않아X스우파', 'indices': [119, 129]}, {'text': '스우파', 'indices': [130, 134]}, {'text': '모니카', 'indices': [135, 139]}]
# 2022-02-10 01:20:22
# RT @chtvn: 노제가 입으면 그게 패션이고 유행이다...🙊
# 꽃을 때려박은 시골룩에도 셔터 누르게 만드는 비주얼💕
#
# 풀버전 보러 가기👉 #tvN유튜브 #네이버TV
#
# [목] 저녁 8:40 tvN 본방송
# #tvN #해치지않아X스우파 #스우파
# #모니카…
# [{'screen_name': 'chtvn', 'name': 'tvN joy', 'id': 125209408, 'id_str': '125209408', 'indices': [3, 9]}]
# [{'text': 'tvN유튜브', 'indices': [78, 85]}, {'text': '네이버TV', 'indices': [86, 92]}, {'text': 'tvN', 'indices': [114, 118]}, {'text': '해치지않아X스우파', 'indices': [119, 129]}, {'text': '스우파', 'indices': [130, 134]}, {'text': '모니카', 'indices': [135, 139]}]
# 2022-02-10 01:20:09
# RT @noze__baby: 리더즈 완전체 K-할머니 패션 #해치지않아
# #모니카 #허니제이 #아이키 #리헤이 #효진초이 #가비 #노제 #리정 https://t.co/PgVoOJn7QY
# [{'screen_name': 'noze__baby', 'name': '노제베이비🍼', 'id': 1466309620561969154, 'id_str': '1466309620561969154', 'indices': [3, 14]}]
# [{'text': '해치지않아', 'indices': [33, 39]}, {'text': '모니카', 'indices': [40, 44]}, {'text': '허니제이', 'indices': [45, 50]}, {'text': '아이키', 'indices': [51, 55]}, {'text': '리헤이', 'indices': [56, 60]}, {'text': '효진초이', 'indices': [61, 66]}, {'text': '가비', 'indices': [67, 70]}, {'text': '노제', 'indices': [71, 74]}, {'text': '리정', 'indices': [75, 78]}]
# 2022-02-10 01:20:06
# RT @MyLifeForRyujin: ITZY 있지 스튜디어룸 (스튜디어춤) 속  예지, 류진 니트, 귀걸이 패션 (출처 : 잡식이음식.. | 블로그) https://t.co/VCKcloZVJ2
# MY QUEEN RYUJIN 류진 + #RYUJIN…
# [{'screen_name': 'MyLifeForRyujin', 'name': 'SHIN RYUJIN IS MY QUEEN, MY LOVE, MY EVERYTHING', 'id': 1455392984766115844, 'id_str': '1455392984766115844', 'indices': [3, 19]}]
# [{'text': 'RYUJIN', 'indices': [131, 138]}]
# 2022-02-10 01:19:52
# ITZY 있지 스튜디어룸 (스튜디어춤) 속  예지, 류진 니트, 귀걸이 패션 (출처 : 잡식이음식.. | 블로그) https://t.co/VCKcloZVJ2
# MY QUEEN RYUJIN 류진 +… https://t.co/R8Adh7iqLn
# []
# []
# 2022-02-10 01:19:46
# RT @iPoNY194mseV6wE: @ALWAYS1204_JIN @BTS_twt 그저 빛🌟🌟
# 패션을 완성시키는 그야말로 빛-쥬얼🌟
# #방탄소년단진 #방탄진 #김석진 #석진 #진 #BTSJIN #SEOKJIN #JIN #Yours_Jin #SuperT…
# [{'screen_name': 'iPoNY194mseV6wE', 'name': 'JIN 너라는 기적¹²⁰⁴\u200b🍓🐹🥰', 'id': 1059378928316375040, 'id_str': '1059378928316375040', 'indices': [3, 19]}, {'screen_name': 'ALWAYS1204_JIN', 'name': '🍓마음을다해딸기찐🍓', 'id': 1334507277764726785, 'id_str': '1334507277764726785', 'indices': [21, 36]}, {'screen_name': 'BTS_twt', 'name': '방탄소년단', 'id': 335141638, 'id_str': '335141638', 'indices': [37, 45]}]
# [{'text': '방탄소년단진', 'indices': [74, 81]}, {'text': '방탄진', 'indices': [82, 86]}, {'text': '김석진', 'indices': [87, 91]}, {'text': '석진', 'indices': [92, 95]}, {'text': '진', 'indices': [96, 98]}, {'text': 'BTSJIN', 'indices': [99, 106]}, {'text': 'SEOKJIN', 'indices': [107, 115]}, {'text': 'JIN', 'indices': [116, 120]}, {'text': 'Yours_Jin', 'indices': [121, 131]}]
# 2022-02-10 01:19:35
# RT @chtvn: 노제가 입으면 그게 패션이고 유행이다...🙊
# 꽃을 때려박은 시골룩에도 셔터 누르게 만드는 비주얼💕
#
# 풀버전 보러 가기👉 #tvN유튜브 #네이버TV
#
# [목] 저녁 8:40 tvN 본방송
# #tvN #해치지않아X스우파 #스우파
# #모니카…
# [{'screen_name': 'chtvn', 'name': 'tvN joy', 'id': 125209408, 'id_str': '125209408', 'indices': [3, 9]}]
# [{'text': 'tvN유튜브', 'indices': [78, 85]}, {'text': '네이버TV', 'indices': [86, 92]}, {'text': 'tvN', 'indices': [114, 118]}, {'text': '해치지않아X스우파', 'indices': [119, 129]}, {'text': '스우파', 'indices': [130, 134]}, {'text': '모니카', 'indices': [135, 139]}]
# 2022-02-10 01:19:13
# RT @noze__baby: 리더즈 완전체 K-할머니 패션 #해치지않아
# #모니카 #허니제이 #아이키 #리헤이 #효진초이 #가비 #노제 #리정 https://t.co/PgVoOJn7QY
# [{'screen_name': 'noze__baby', 'name': '노제베이비🍼', 'id': 1466309620561969154, 'id_str': '1466309620561969154', 'indices': [3, 14]}]
# [{'text': '해치지않아', 'indices': [33, 39]}, {'text': '모니카', 'indices': [40, 44]}, {'text': '허니제이', 'indices': [45, 50]}, {'text': '아이키', 'indices': [51, 55]}, {'text': '리헤이', 'indices': [56, 60]}, {'text': '효진초이', 'indices': [61, 66]}, {'text': '가비', 'indices': [67, 70]}, {'text': '노제', 'indices': [71, 74]}, {'text': '리정', 'indices': [75, 78]}]
# 2022-02-10 01:18:34
# RT @121Y8N: 어쩐지 어디서 본 것 같다🤔역시 Y-3😄
# 탁구선수 강승윤의 패션스타일☺️😎
# @official_yoon_
# #강승윤 #YOON #KangSeungYoon #위너 #WINNER https://t.co/j86k5jLdeh
# [{'screen_name': '121Y8N', 'name': '121Y⑧N', 'id': 1073487179043590144, 'id_str': '1073487179043590144', 'indices': [3, 10]}, {'screen_name': 'official_yoon_', 'name': 'official_yoon_', 'id': 963273269917843456, 'id_str': '963273269917843456', 'indices': [54, 69]}]
# [{'text': '강승윤', 'indices': [71, 75]}, {'text': 'YOON', 'indices': [76, 81]}, {'text': 'KangSeungYoon', 'indices': [82, 96]}, {'text': '위너', 'indices': [97, 100]}, {'text': 'WINNER', 'indices': [101, 108]}]
# 2022-02-10 01:18:26

# %%
tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x00000218B82BB1F0>, _json={'created_at': 'Thu Feb 10 01:21:45 +0000 2022', 'id': 1491583130859610112, 'id_str': '1491583130859610112', 'text': 'RT @BRILLER__613: 패션 에디터 박나나님 인스타 (1)\nhttps://t.co/zhZdFX0jcn https://t.co/2DYdXohwxf', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'BRILLER__613', 'name': '브리이에', 'id': 1225314350367268864, 'id_str': '1225314350367268864', 'indices': [3, 16]}], 'urls': [{'url': 'https://t.co/zhZdFX0jcn', 'expanded_url': 'https://www.instagram.com/p/CZULkafpw6X/?utm_medium=copy_link', 'display_url': 'instagram.com/p/CZULkafpw6X/…', 'indices': [38, 61]}], 'media': [{'id': 1487418700542078977, 'id_str': '1487418700542078977', 'indices': [62, 85], 'media_url': 'http://pbs.twimg.com/media/FKRfbW4VcAEdqNd.jpg', 'media_url_https': 'https://pbs.twimg.com/media/
T @chtvn: 노제가 입으면 그게 패션이고 유행이다...🙊\n꽃을 때려박은 시골룩에도 셔터 누르게 만드는 비주얼💕\n\n풀버전 보러 가기👉 #tvN유튜브 #네이버TV\n\n[목] 저녁 8:40 tvN 본방송\n#tvN #해치지않아X스우파 #스우파\n#모니카…', 'truncated': False, 'entities': {'hashtags': [{'text': 'tvN유튜브', 'indices': [78, 85]}, {'text': '네이버TV', 'indices': [86, 92]}, {'text': 'tvN', 'indices': [114, 118]}, {'text': '해치지않아X스우파', 'indices': [119, 129]}, {'text': '스우파', 'indices': [130, 134]}, {'text': '모니카', 'indices': [135, 139]}], 'symbols': [], 'user_mentions': [{'screen_name': 'chtvn', 'name': 'tvN joy', 'id': 125209408, 'id_str': '125209408', 'indices': [3, 9]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1270919720313565191, 'id_str': '1270919720313565191', 'name': 'ElonJ', 'screen_name': 'ElonJ7', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1, 'friends_count': 212, 'listed_count': 0, 'created_at': 'Thu Jun 11 03:24:37 +0000 2020', 'favourites_count': 3643, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1009, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1270924729373736960/ymybcTvQ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270924729373736960/ymybcTvQ_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1270919720313565191/1639234987', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Feb 09 23:00:00 +0000 2022', 'id': 1491547459214008333, 'id_str': '1491547459214008333', 'text': '노제가 입으면 그게 패션이고 유행이다...🙊\n꽃을 때려박은 시골룩에도 셔터 누르게 만드는 비주얼💕\n\n풀버전 보러 가기👉 #tvN유튜브 #네이버TV\n\n[목] 저녁 8:40 tvN 본방송\n#tvN… https://t.co/QISYL42x7N', 'truncated': True, 'entities': {'hashtags': [{'text': 'tvN유튜브', 'indices': [67, 74]}, {'text': '네이버TV', 'indices': [75, 81]}, {'text': 'tvN', 'indices': [103, 107]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/QISYL42x7N', 'expanded_url': 'https://twitter.com/i/web/status/1491547459214008333', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [109, 132]}]}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 125209408, 'id_str': '125209408', 'name': 'tvN joy', 'screen_name': 'chtvn', 'location': 'Seoul, Korea', 'description': 'NO.1 K콘텐츠 채널, 즐거움엔 tvN', 'url': 'https://t.co/uzeyWG0GYd', 'entities': {'url': {'urls': [{'url': 'https://t.co/uzeyWG0GYd', 'expanded_url': 'http://www.chtvn.com', 'display_url': 'chtvn.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 208893,  ...
#  Status(_api=<tweepy.api.API object at 0x00000218B82BB1F0>, _json={'created_at': 'Thu Feb 10 01:20:24 +0000 2022', 'id': 1491582791359684608, 'id_str': '1491582791359684608', 'text': '#섹시\n#모델\n#패션\n#black\n#화보\n#블랙\n#collection\n#옴므\n#레이어드\n#아트\n#송지오\n#남성복\n#맞팔\n#model\n#컨펨포러리\n#컬랙션\n#백화점\n#프로필\n#소통\n#데일리룩\n#귀요미\n0356Z1', 'truncated': False, 'entities': {'hashtags': [{'text': '섹시', 'indices': [0, 3]}, {'text': '모델', 'indices': [4, 7]}, {'text': '패션', 'indices': [8, 11]}, {'text': 'black', 'indices': [12, 18]}, {'text': '화보', 'indices': [19, 22]}, {'text': '블랙', 'indices': [23, 26]}, {'text': 'collection', 'indices': [27, 38]}, {'text': '옴므', 'indices': [39, 42]}, {'text': '레이어드', 'indices': [43, 48]}, {'text': '아트', 'indices': [49, 52]}, {'text': '송지오', 'indices': [53, 57]}, {'text': '남성복', 'indices': [58, 62]}, {'text': '맞팔', 'indices': [63, 66]}, {'text': 'model', 'indices': [67, 73]}, {'text': '컨펨포러리', 'indices': [74, 80]}, {'text': '컬랙션', 'indices': [81, 85]}, {'text': '백화점', 'indices': [86, 90]}, {'text': '프로필', 'indices': [91, 95]}, {'text': '소통', 'indices': [96, 99]}, {'text': '데일리룩', 'indices': [100, 105]}, {'text': '귀요미', 'indices': [106, 110]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'und', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1438904705225150465, 'id_str': '1438904705225150465', 'name': 'Odette', 'screen_name': 'Odette22388705', 'location': '대한민국', 'description': '', 'url': 'https://t.co/aFvJfLSM5K', 'entities': {'url': {'urls': [{'url': 'https://t.co/aFvJfLSM5K', 'expanded_url': 'http://aaaaaaaa.com', 'display_url': 'aaaaaaaa.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 5, 'friends_count': 982, 'listed_count': 0, 'created_at': 'Fri Sep 17 16:36:44 +0000 2021', 'favourites_count': 190, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 10654, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1491219264098824192/SgT6Fzb-_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1491219264098824192/SgT6Fzb-_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1438904705225150465/1639980435', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'und'}, created_at=datetime.datetime(2022, 2, 10, 1, 20, 24), id=1491582791359684608, id_str='1491582791359684608', text='#섹시\n#모델\n#패션\n#black\n#화보\n#블랙\n#collection\n#옴므\n#레이어드\n#아트\n#송지오\n#남성복\n#맞팔\n#model\n#컨펨포러리\n#컬랙션\n#백화점\n#프로필\n#소통\n#데일리룩\n#귀요미\n0356Z1', truncated=False, entities={'hashtags': [{'text': '섹시', 'indices': [0, 3]}, {'text': '모델', 'indices': [4, 7]}, {'text': '패션', 'indices': [8, 11]}, {'text': 'black', 'indices': [12, 18]}, {'text': '화보', 'indices': [19, 22]}, {'text': '블랙', 'indices': [23, 26]}, {'text': 'collection', 'indices': [27, 38]}, {'text': '옴므', 'indices': [39, 42]}, {'text': '레이어드', 'indices': [43, 48]}, {'text': '아트', 'ind ...
#  Status(_api=<tweepy.api.API object at 0x00000218B82BB1F0>, _json={'created_at': 'Thu Feb 10 01:20:22 +0000 2022', 'id': 1491582782744973316, 'id_str': '1491582782744973316', 'text': 'RT @chtvn: 노제가 입으면 그게 패션이고 유행이다...🙊\n꽃을 때려박은 시골룩에도 셔터 누르게 만드는 비주얼💕\n\n풀버전 보러 가기👉 #tvN유튜브 #네이버TV\n\n[목] 저녁 8:40 tvN 본방송\n#tvN #해치지않아X스우파 #스우파\n#모니카…', 'truncated': False, 'entities': {'hashtags': [{'text': 'tvN유튜브', 'indices': [78, 85]}, {'text': '네이버TV', 'indices': [86, 92]}, {'text': 'tvN', 'indices': [114, 118]}, {'text': '해치지않아X스우파', 'indices': [119, 129]}, {'text': '스우파', 'indices': [130, 134]}, {'text': '모니카', 'indices': [135, 139]}], 'symbols': [], 'user_mentions': [{'screen_name': 'chtvn', 'name': 'tvN joy', 'id': 125209408, 'id_str': '125209408', 'indices': [3, 9]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2734580600, 'id_str': '2734580600', 'name': 'YiChen-Li♋🐍', 'screen_name': 'm071402', 'location': 'TAIWAN,NANTOU,CAOTUN', 'description': '14.06.1999🐠\n21.02.1994🐿\n12.02.1996🐱', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 20, 'friends_count': 147, 'listed_count': 1, 'created_at': 'Fri Aug 15 14:29:06 +0000 2014', 'favourites_count': 36148, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 28980, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1400476944026673154/Iv7RHtTE_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1400476944026673154/Iv7RHtTE_normal.jpg', 'profile_link_color': '981CEB', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Feb 09 23:00:00 +0000 2022', 'id': 1491547459214008333, 'id_str': '1491547459214008333', 'text': '노제가 입으면 그게 패션이고 유행이다...🙊\n꽃을 때려박은 시골룩에도 셔터 누르게 만드는 비주얼�
 'display_url': 'twitter.com/i/web/status/1…', 'indices': [111, 134]}]}, metadata={'result_type': 'recent', 'iso_language_code': 'ko'}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x ...
#  Status(_api=<tweepy.api.API object at 0x00000218B82BB1F0>, _json={'created_at': 'Thu Feb 10 01:19:35 +0000 2022', 'id': 1491582586665246727, 'id_str': '1491582586665246727', 'text': 'RT @iPoNY194mseV6wE: @ALWAYS1204_JIN @BTS_twt 그저 빛🌟🌟\n패션을 완성시키는 그야말로 빛-쥬얼🌟\n#방탄소년단진 #방탄진 #김석진 #석진 #진 #BTSJIN #SEOKJIN #JIN #Yours_Jin #SuperT…', 'truncated': False, 'entities': {'hashtags': [{'text': '방탄소년단진', 'indices': [74, 81]}, {'text': '방탄진', 'indices': [82, 86]}, {'text': '김석진', 'indices': [87, 91]}, {'text': '석진', 'indices': [92, 95]}, {'text': '진', 'indices': [96, 98]}, {'text': 'BTSJIN', 'indices': [99, 106]}, {'text': 'SEOKJIN', 'indices': [107, 115]}, {'text': 'JIN', 'indices': [116, 120]}, {'text': 'Yours_Jin', 'indices': [121, 131]}], 'symbols': [], 'user_mentions': [{'screen_name': 'iPoNY194mseV6wE', 'name': 'JIN 너라는 기적¹²⁰⁴\u200b🍓🐹🥰', 'id': 1059378928316375040, 'id_str': '1059378928316375040', 'indices': [3, 19]}, {'screen_name': 'ALWAYS1204_JIN', 'name': '🍓마음을다해딸기찐🍓', 'id': 1334507277764726785, 'id_str': '1334507277764726785', 'indices': [21, 36]}, {'screen_name': 'BTS_twt', 'name': '방탄소년단', 'id': 335141638, 'id_str': '335141638', 'indices': [37, 45]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ko'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1392172309566398465, 'id_str': '1392172309566398465', 'name': 'mvstrg2', 'screen_name': 'vstrg02', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 18, 'friends_count': 27, 'listed_count': 0, 'created_at': 'Tue May 11 17:38:53 +0000 2021', 'favourites_count': 18833, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 35945, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Feb 09 16:04:13 +0000 2022', 'id': 1491442824549904384, 'id_str': '1491442824549904384', 'text': '@ALWAYS1204_JIN @BTS_twt 그저 빛🌟🌟\n패션을 완성시키는 그야말로 빛-쥬얼🌟\n#방탄소년단진 #방탄진 #김석진 #석진 #진 #BTSJIN #SEOKJIN #JIN #Yours_Jin… https://t.co/lLSKY8sM2R', 'truncated': True, 'entities': {'hashtags': [{'text': '방탄소년단진', 'indices': [53, 60]}, {'text': '방탄진', 'indices': [61, 65]}, {'text': '김석진', 'indices': [66, 70]}, {'text': '석진', 'indices': [71, 74]}, {'text': '진', 'indices': [75, 77]}, {'text': 'BTSJIN', 'indices': [78, 85]}, {'text': 'SEOKJIN', 'indices': [86, 94]}, {'text': 'JIN', 'indices': [95, 99]}, {'text': 'Yours_Jin', 'indices': [100, 110]}], 'symbols': [], 'user_mentions': [{'screen_name': 'ALWAYS1204_JIN', 'name': '🍓마음을다해딸기찐🍓', 'id': 1334507277764726785, 'id_str': '1334507277764726785', 'indices': [0, 15]}, {'screen_name': 'BTS_twt', 'name': '방탄소년단', 'id': 335141638, 'id_str': '335141638', 'indices': [16, 24]}], 'urls': [{'url': 'https://t.co/lLSKY8sM2R', 'expanded_url': 'https://twitter.com/i/web/status/1491442824549904384', 'display_url': ' ...
#  Status(_api=<tweepy.api.API object at 0x00000218B82BB1F0>, _json={'created_at': 'Thu Feb 10 01
 'h': 680, 'resize': 'fit'}}, 'source_status_id': 1491489992555651074, 'source_status_id_str': '1491489992555651074', 'source_user_id': 1073487179043590144, 'source_user_id_str': '1073487179043590144'}]}, 'extended_entities': {'media': [{'id': 1491489946313453568, 'id_str': '1491489946313453568', 'indices': [109, 132], 'media_url': 'http://pbs.twimg.com/media/FLLWNDQUcAAqF4V.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FLLWNDQUcAAqF4V.jpg', 'url': 'https://t.co/j86k5jLdeh', 'display_url': 'pic.twitter.com/j86k5jLdeh', 'expanded_url': 'https://twitter.com/121Y8N/status/1491489992555651074/photo/1', 'type': 'photo', 'sizes': {'large': {'w': 780, 'h': 1170, 'resize': 'fit'}, 'medium': {'w': 780, 'h': 1170, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 453, 'h': 680, 'resize': 'fit'}}, 'source_status_id': 1491489992555651074, 'source_status_id_str': '1491489992555651074', 'source_user_id': 1073487179043590144, 'source_user_id_str': '1073487179043590144'}, {'id': 1491489946313523200, 'id_str': '1491489946313523200', 'indices': [109, 132], 'media_url': 'http://pbs.twimg.com/media/FLLWNDQVgAAEmsJ.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FLLWNDQVgAAEmsJ.jpg', 'url': 'https://t.co/j86k5jLdeh', 'display_url': 'pic.twitter.com/j86k5jLdeh', 'expanded_url': 'https://twitter.com/121Y8N/status/1491489992555651074/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 453, 'h': 680, 'resize': 'fit'}, 'large': {'w': 780, 'h': 1170, 'resize': 'fit'}, 'medium': {'w': 780, 'h': 1170, 'resize': 'fit'}}, 'source_status_id': 1491489992555651074, 'source_status_id_str': '1491489992555651074', 'source_user_id': 1073487179043590144, 'source_user_id_str': '1073487179043590144'}, {'id': 1491489946309324800, 'id_str': '1491489946309324800', 'indices': [109, 132], 'media_url': 'http://pbs.twimg.com/media/FLLWNDPVcAAfqPt.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FLLWNDPVcAAfqPt.jpg', 'url': 'https://t.co/j86k5jLdeh', 'display_url': 'pic.twitter.com/j86k5jLdeh', 'expanded_url': 'https://twitter.com/121Y8N/status/1491489992555651074/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 741, 'h': 1114, 'resize': 'fit'}, 'large': {'w': 741, 'h': 1114, 'resize': 'fit'}, 'small': {'w': 452, 'h': 680, 'resize': 'fit'}}, 'source_status_id': 1491489992555651074, 'source_status_id_str': '1491489992555651074', 'source_user_id': 1073487179043590144, 'source_user_id_str' ...

# %% [markdown]
# -----

# %% [markdown]
# ##### 데이터 프레임 형태로 수집

# %%
# 크롤링된 데이터를 저장할 데이터 프레임 생성
columns = ['created', 'tweet_text']
df = pd.DataFrame(columns=columns)

# 크롤링을 수행할 갯수를 입력
max_tweets = 100

# Cursor 객체를 사용하여 크롤링 수행
# Cursor()로 keyword의 값에 해당하는 정보를  items()으로 지정한 갯수만큼 크롤링
searched_tweets = [status for status in tweepy.Cursor(api.search, q=keyword).items(max_tweets)]

# ‘손흥민’이 포함된 1000개의 트윗들에서, ‘text’, ‘created_at’ 정보를 데이터 프레임으로 저장
for tweet in searched_tweets:
    tweet_json = tweet._json
    tweet_text = tweet_json['text']
    created = tweet_json['created_at']
    row = [created, tweet_text]
    series = pd.Series(row, index=df.columns) #  created, tweet_text로 시리즈를 생성
    df = df.append(series, ignore_index=True) # 생성된 시리즈를 데이터프레임에 추가

# %%
# 데이터 프레임 상위 5개 출력
df.head()
# Out:
#                           created  \
# 0  Thu Feb 10 01:21:45 +0000 2022
# 1  Thu Feb 10 01:21:33 +0000 2022
# 2  Thu Feb 10 01:20:57 +0000 2022
# 3  Thu Feb 10 01:20:52 +0000 2022
# 4  Thu Feb 10 01:20:27 +0000 2022
#
#                                           tweet_text
# 0  RT @BRILLER__613: 패션 에디터 박나나님 인스타 (1)\nhttps:/...
# 1  RT @noze__baby: 리더즈 완전체 K-할머니 패션 #해치지않아\n#모니카 ...
# 2  RT @noze__baby: 리더즈 완전체 K-할머니 패션 #해치지않아\n#모니카 ...
# 3  RT @chtvn: 노제가 입으면 그게 패션이고 유행이다...🙊\n꽃을 때려박은 시...
# 4  RT @chtvn: 노제가 입으면 그게 패션이고 유행이다...🙊\n꽃을 때려박은 시...

# %%
# 데이터 프레임을 csv 로 저장
# df.to_csv("tweet_temp.csv", index=False)

# %% [markdown]
# -----

# %% [markdown]
# # <Step2. 추출> : 키워드 추출

# %% [markdown]
# ### [텍스트 데이터 전처리]
# - 한글 문자열을 기준으로 키워드 추출 수행
# - tweet_text 데이터에서 한글 문자열만을 추출하여 ko_text 생성

# %%
#df = pd.read_csv("tweet_temp.csv")
#df.head()

# %%
# 정규표현 라이브러리
import re

# 텍스트 정제 함수 : 한글 및 띄어쓰기 이외의 문자는 전부 제거
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+') # 한글의 정규표현식
    result = hangul.sub('', text)
    return result

# %%
# 텍스트 정제 함수text_cleaning()를 ‘tweet_text’ 피처에 이를 적용, 한글과 띄어쓰기만 추출하여 ko_text 피처 생성
df['ko_text'] = df['tweet_text'].apply(lambda x: text_cleaning(x))
df.head()
# Out:
#                           created  \
# 0  Thu Feb 10 01:21:45 +0000 2022
# 1  Thu Feb 10 01:21:33 +0000 2022
# 2  Thu Feb 10 01:20:57 +0000 2022
# 3  Thu Feb 10 01:20:52 +0000 2022
# 4  Thu Feb 10 01:20:27 +0000 2022
#
#                                           tweet_text  \
# 0  RT @BRILLER__613: 패션 에디터 박나나님 인스타 (1)\nhttps:/...
# 1  RT @noze__baby: 리더즈 완전체 K-할머니 패션 #해치지않아\n#모니카 ...
# 2  RT @noze__baby: 리더즈 완전체 K-할머니 패션 #해치지않아\n#모니카 ...
# 3  RT @chtvn: 노제가 입으면 그게 패션이고 유행이다...🙊\n꽃을 때려박은 시...
# 4  RT @chtvn: 노제가 입으면 그게 패션이고 유행이다...🙊\n꽃을 때려박은 시...
#
#                                              ko_text
# 0                                  패션 에디터 박나나님 인스타
# 1    리더즈 완전체 할머니 패션 해치지않아모니카 허니제이 아이키 리헤이 효진초이 가비...
# 2    리더즈 완전체 할머니 패션 해치지않아모니카 허니제이 아이키 리헤이 효진초이 가비...
# 3    노제가 입으면 그게 패션이고 유행이다꽃을 때려박은 시골룩에도 셔터 누르게 만드는...
# 4    노제가 입으면 그게 패션이고 유행이다꽃을 때려박은 시골룩에도 셔터 누르게 만드는...

# %% [markdown]
# -----

# %% [markdown]
# ### [konlpy를 이용한 키워드 추출]
# - 명사만 추출한 후 불용어 및 한글자 키워드 제거

# %%
from konlpy.tag import Okt
from collections import Counter

# 불용어 사전의 텍스트 문서 읽어 stopwords 리스트 생성
# 한국어 약식 불용어사전 예시 파일, 출처 - (https://www.ranks.nl/stopwords/korean)
korean_stopwords_path = "../data/korean_stopwords.txt"
with open(korean_stopwords_path, encoding='utf8') as f:
    stopwords = f.readlines()
stopwords = [x.strip() for x in stopwords] # strip()으로 공백 및 줄바꿈 제거

# 품사 중 명사만 추출하여 한글자 키워드 및 불용어 제거
# Okt(Open Korean Text)는 트위터에서 만든 오픈소스 한국어 처리기인 twitter-korean-text를 이어받아 만들고 있는 프로젝트

def get_nouns(x):
    # 명사만 추출
    nouns_tagger = Okt() # Okt()클래스 선언
    nouns = nouns_tagger.nouns(x)
    
    # 한글자 키워드 제거
    nouns = [noun for noun in nouns if len(noun) > 1]
    
    # 불용어를 제거
    nouns = [noun for noun in nouns if noun not in stopwords]
    
    return nouns

# %%
stopwords
# Out:
# ['아',
#  '휴',
#  '아이구',
#  '아이쿠',
#  '아이고',
#  '어',
#  '나',
#  '우리',
#  '저희',
#  '따라',
#  '의해',
#  '을',
#  '를',
#  '에',
#  '의',
#  '가',
#  '으로',
#  '로',
#  '에게',
#  '뿐이다',
#  '의거하여',
#  '근거하여',
#  '입각하여',
#  '기준으로',
#  '예하면',
#  '예를 들면',
#  '예를 들자면',
#  '저',
#  '소인',
#  '소생',
#  '저희',
#  '지말고',
#  '하지마',
#  '하지마라',
#  '다른',
#  '물론',
#  '또한',
#  '그리고',
#  '비길수 없다',
#  '해서는 안된다',
#  '뿐만 아니라',
#  '만이 아니다',
#  '만은 아니다',
#  '막론하고',
#  '관계없이',
#  '그치지 않다',
#  '그러나',
#  '그런데',
#  '하지만',
#  '든간에',
#  '논하지 않다',
#  '따지지 않다',
#  '설사',
#  '비록',
#  '더라도',
#  '아니면',
#  '만 못하다',
#  '하는 편이 낫다',
#  '불문하고',
#  '향하여',
#  '향해서',
#  '향하다',
#  '쪽으로',
#  '틈타',
#  '이용하여',
#  '타다',
#  '오르다',
#  '제외하고',
#  '이 외에',
#  '이 밖에',
#  '하여야',
#  '비로소',
#  '한다면 몰라도',
#  '외에도',
#  '이곳',
#  '여기',
#  '부터',
#  '기점으로',
#  '따라서',
#  '할 생각이다',
#  '하려고하다',
#  '이리하여',
#  '그리하여',
#  '그렇게 함으로써',
#  '하지만',
#  '일때',
#  '할때',
#  '앞에서',
#  '중에서',
#  '보는데서',
#  '으로써',
#  '로써',
#  '까지',
#  '해야한다',
#  '일것이다',
#  '반드시',
#  '할줄알다',
#  '할수있다',
#  '할수있어',
#  '임에 틀림없다',
#  '한다면',
#  '등',
#  '등등',
#  '제',
#  '겨우',
#  '단지',
#  '다만',
#  '할뿐',
#  '딩동',
#  '댕그',
#  '대해서',
#  '대하여',
#  '대하면',
#  '훨씬',
#  '얼마나',
#  '얼마만큼',
#  '얼마큼',
#  '남짓',
#  '여',
#  '얼마간',
#  '약간',
#  '다소',
#  '좀',
#  '조금',
#  '다수',
#  '몇',
#  '얼마',
#  '지만',
#  '하물며',
#  '또한',
#  '그러나',
#  '그렇지만',
#  '하지만',
#  '이외에도',
#  '대해 말하자면',
#  '뿐이다',
#  '다음에',
#  '반대로',
#  '반대로 말하자면',
#  '이와 반대로',
#  '바꾸어서 말하면',
#  '바꾸어서 한다면',
#  '만약',
#  '그렇지않으면',
#  '까악',
#  '툭',
#  '딱',
#  '삐걱거리다',
#  '보드득',
#  '비걱거리다',
#  '꽈당',
#  '응당',
#  '해야한다',
#  '에 가서',
#  '각',
#  '각각',
#  '여러분',
#  '각종',
#  '각자',
#  '제각기',
#  '하도록하다',
#  '와',
#  '과',
#  '그러므로',
#  '그래서',
#  '고로',
#  '한 까닭에',
#  '하기 때문에',
#  '거니와',
#  '이지만',
#  '대하여',
#  '관하여',
#  '관한',
#  '과연',
#  '실로',
#  '아니나다를가',
#  '생각한대로',
#  '진짜로',
#  '한적이있다',
#  '하곤하였다',
#  '하',
#  '하하',
#  '허허',
#  '아하',
#  '거바',
#  '와',
#  '오',
#  '왜',
#  '어째서',
#  '무엇때문에',
#  '어찌',
#  '하겠는가',
#  '무슨',
#  '어디',
#  '어느곳',
#  '더군다나',
#  '하물며',
#  '더욱이는',
#  '어느때',
#  '언제',
#  '야',
#  '이봐',
#  '어이',
#  '여보시오',
#  '흐흐',
#  '흥',
#  '휴',
#  '헉헉',
#  '헐떡헐떡',
#  '영차',
#  '여차',
#  '어기여차',
#  '끙끙',
#  '아야',
#  '앗',
#  '아야',
#  '콸콸',
#  '졸졸',
#  '좍좍',
#  '뚝뚝',
#  '주룩주룩',
#  '솨',
#  '우르르',
#  '그래도',
#  '또',
#  '그리고',
#  '바꾸어말하면',
#  '바꾸어말하자면',
#  '혹은',
#  '혹시',
#  '답다',
#  '및',
#  '그에 따르는',
#  '때가 되어',
#  '즉',
#  '지든지',
#  '설령',
#  '가령',
#  '하더라도',
#  '할지라도',
#  '일지라도',
#  '지든지',
#  '몇',
#  '거의',
#  '하마터면',
#  '인젠',
#  '이젠',
#  '된바에야',
#  '된이상',
#  '만큼\t어찌됏든',
#  '그위에',
#  '게다가',
#  '점에서 보아',
#  '비추어 보아',
#  '고려하면',
#  '하게될것이다',
#  '일것이다',
#  '비교적',
#  '좀',
#  '보다더',
#  '비하면',
#  '시키다',
#  '하게하다',
#  '할만하다',
#  '의해서',
#  '연이서',
#  '이어서',
#  '잇따라',
#  '뒤따라',
#  '뒤이어',
#  '결국',
#  '의지하여',
#  '기대여',
#  '통하여',
#  '자마자',
#  '더욱더',
#  '불구하고',
#  '얼마든지',
#  '마음대로',
#  '주저하지 않고',
#  '곧',
#  '즉시',
#  '바로',
#  '당장',
#  '하자마자',
#  '밖에 안된다',
#  '하면된다',
#  '그래',
#  '그렇지',
#  '요컨대',
#  '다시 말하자면',
#  '바꿔 말하면',
#  '즉',
#  '구체적으로',
#  '말하자면',
#  '시작하여',
#  '시초에',
#  '이상',
#  '허',
#  '헉',
#  '허걱',
#  '바와같이',
#  '해도좋다',
#  '해도된다',
#  '게다가',
#  '더구나',
#  '하물며',
#  '와르르',
#  '팍',
#  '퍽',
#  '펄렁',
#  '동안',
#  '이래',
#  '하고있었다',
#  '이었다',
#  '에서',
#  '로부터',
#  '까지',
#  '예하면',
#  '했어요',
#  '해요',
#  '함께',
#  '같이',
#  '더불어',
#  '마저',
#  '마저도',
#  '양자',
#  '모두',
#  '습니다',
#  '가까스로',
#  '하려고하다',
#  '즈음하여',
#  '다른',
#  '다른 방면으로',
#  '해봐요',
#  '습니까',
#  '했어요',
#  '말할것도 없고',
#  '무릎쓰고',
#  '개의치않고',
#  '하는것만 못하다',
#  '하는것이 낫다',
#  '매',
#  '매번',
#  '들',
#  '모',
#  '어느것',
#  '어느',
#  '로써',
#  '갖고말하자면',
#  '어디',
#  '어느쪽',
#  '어느것',
#  '어느해',
#  '어느 년도',
#  '라 해도',
#  '언젠가',
#  '어떤것',
#  '어느것',
#  '저기',
#  '저쪽',
#  '저것',
#  '그때',
#  '그럼',
#  '그러면',
#  '요만한걸',
#  '그래',
#  '그때',
#  '저것만큼',
#  '그저',
#  '이르기까지',
#  '할 줄 안다',
#  '할 힘이 있다',
#  '너',
#  '너희',
#  '당신',
#  '어찌',
#  '설마',
#  '차라리',
#  '할지언정',
#  '할지라도',
#  '할망정',
#  '할지언정',
#  '구토하다',
#  '게우다',
#  '토하다',
#  '메쓰겁다',
#  '옆사람',
#  '퉤',
#  '쳇',
#  '의거하여',
#  '근거하여',
#  '의해',
#  '따라',
#  '힘입어',
#  '그',
#  '다음',
#  '버금',
#  '두번째로',
#  '기타',
#  '첫번째로',
#  '나머지는',
#  '그중에서',
#  '견지에서',
#  '형식으로 쓰여',
#  '입장에서',
#  '위해서',
#  '단지',
#  '의해되다',
#  '하도록시키다',
#  '뿐만아니라',
#  '반대로',
#  '전후',
#  '전자',
#  '앞의것',
#  '잠시',
#  '잠깐',
#  '하면서',
#  '그렇지만',
#  '다음에',
#  '그러한즉',
#  '그런즉',
#  '남들',
#  '아무거나',
#  '어찌하든지',
#  '같다',
#  '비슷하다',
#  '예컨대',
#  '이럴정도로',
#  '어떻게',
#  '만약',
#  '만일',
#  '위에서 서술한바와같이',
#  '인 듯하다',
#  '하지 않는다면',
#  '만약에',
#  '무엇',
#  '무슨',
#  '어느',
#  '어떤',
#  '아래윗',
#  '조차',
#  '한데',
#  '그럼에도 불구하고',
#  '여전히',
#  '심지어',
#  '까지도',
#  '조차도',
#  '하지 않도록',
#  '않기 위하여',
#  '때',
#  '시각',
#  '무렵',
#  '시간',
#  '동안',
#  '어때',
#  '어떠한',
#  '하여금',
#  '네',
#  '예',
#  '우선',
#  '누구',
#  '누가 알겠는가',
#  '아무도',
#  '줄은모른다',
#  '줄은 몰랏다',
#  '하는 김에',
#  '겸사겸사',
#  '하는바',
#  '그런 까닭에',
#  '한 이유는',
#  '그러니',
#  '그러니까',
#  '때문에',
#  '그',
#  '너희',
#  '그들',
#  '너희들',
#  '타인',
#  '것',
#  '것들',
#  '너',
#  '위하여',
#  '공동으로',
#  '동시에',
#  '하기 위하여',
#  '어찌하여',
#  '무엇때문에',
#  '붕붕',
#  '윙윙',
#  '나',
#  '우리',
#  '엉엉',
#  '휘익',
#  '윙윙',
#  '오호',
#  '아하',
#  '어쨋든',
#  '만 못하다\t하기보다는',
#  '차라리',
#  '하는 편이 낫다',
#  '흐흐',
#  '놀라다',
#  '상대적으로 말하자면',
#  '마치',
#  '아니라면',
#  '쉿',
#  '그렇지 않으면',
#  '그렇지 않다면',
#  '안 그러면',
#  '아니었다면',
#  '하든지',
#  '아니면',
#  '이라면',
#  '좋아',
#  '알았어',
#  '하는것도',
#  '그만이다',
#  '어쩔수 없다',
#  '하나',
#  '일',
#  '일반적으로',
#  '일단',
#  '한켠으로는',
#  '오자마자',
#  '이렇게되면',
#  '이와같다면',
#  '전부',
#  '한마디',
#  '한항목',
#  '근거로',
#  '하기에',
#  '아울러',
#  '하지 않도록',
#  '않기 위해서',
#  '이르기까지',
#  '이 되다',
#  '로 인하여',
#  '까닭으로',
#  '이유만으로',
#  '이로 인하여',
#  '그래서',
#  '이 때문에',
#  '그러므로',
#  '그런 까닭에',
#  '알 수 있다',
#  '결론을 낼 수 있다',
#  '으로 인하여',
#  '있다',
#  '어떤것',
#  '관계가 있다',
#  '관련이 있다',
#  '연관되다',
#  '어떤것들',
#  '에 대해',
#  '이리하여',
#  '그리하여',
#  '여부',
#  '하기보다는',
#  '하느니',
#  '하면 할수록',
#  '운운',
#  '이러이러하다',
#  '하구나',
#  '하도다',
#  '다시말하면',
#  '다음으로',
#  '에 있다',
#  '에 달려 있다',
#  '우리',
#  '우리들',
#  '오히려',
#  '하기는한데',
#  '어떻게',
#  '어떻해',
#  '어찌됏어',
#  '어때',
#  '어째서',
#  '본대로',
#  '자',
#  '이',
#  '이쪽',
#  '여기',
#  '이것',
#  '이번',
#  '이렇게말하자면',
#  '이런',
#  '이러한',
#  '이와 같은',
#  '요만큼',
#  '요만한 것',
#  '얼마 안 되는 것',
#  '이만큼',
#  '이 정도의',
#  '이렇게 많은 것',
#  '이와 같다',
#  '이때',
#  '이렇구나',
#  '것과 같이',
#  '끼익',
#  '삐걱',
#  '따위',
#  '와 같은 사람들',
#  '부류의 사람들',
#  '왜냐하면',
#  '중의하나',
#  '오직',
#  '오로지',
#  '에 한하다',
#  '하기만 하면',
#  '도착하다',
#  '까지 미치다',
#  '도달하다',
#  '정도에 이르다',
#  '할 지경이다',
#  '결과에 이르다',
#  '관해서는',
#  '여러분',
#  '하고 있다',
#  '한 후',
#  '혼자',
#  '자기',
#  '자기집',
#  '자신',
#  '우에 종합한것과같이',
#  '총적으로 보면',
#  '총적으로 말하면',
#  '총적으로',
#  '대로 하다',
#  '으로서',
#  '참',
#  '그만이다',
#  '할 따름이다',
#  '쿵',
#  '탕탕',
#  '쾅쾅',
#  '둥둥',
#  '봐',
#  '봐라',
#  '아이야',
#  '아니',
#  '와아',
#  '응',
#  '아이',
#  '참나',
#  '년',
#  '월',
#  '일',
#  '령',
#  '영',
#  '일',
#  '이',
#  '삼',
#  '사',
#  '오',
#  '육',
#  '륙',
#  '칠',
#  '팔',
#  '구',
#  '이천육',
#  '이천칠',
#  '이천팔',
#  '이천구',
#  '하나',
#  '둘',
#  '셋',
#  '넷',
#  '다섯',
#  '여섯',
#  '일곱',
#  '여덟',
#  '아홉',
#  '령',
#  '영']

# %%
# ‘ko_text’ 피처에 get_nouns() 함수를 적용하여 불용어 및 한글자를 제거한 명사 추출하여 'nouns' 피처 생성
df['nouns'] = df['ko_text'].apply(lambda x: get_nouns(x))
print(df.shape) # 행과 열의 갯수를 튜플로 반환
df.head()
# Out:
# (100, 4)
#                           created  \
# 0  Thu Feb 10 01:21:45 +0000 2022
# 1  Thu Feb 10 01:21:33 +0000 2022
# 2  Thu Feb 10 01:20:57 +0000 2022
# 3  Thu Feb 10 01:20:52 +0000 2022
# 4  Thu Feb 10 01:20:27 +0000 2022
#
#                                           tweet_text  \
# 0  RT @BRILLER__613: 패션 에디터 박나나님 인스타 (1)\nhttps:/...
# 1  RT @noze__baby: 리더즈 완전체 K-할머니 패션 #해치지않아\n#모니카 ...
# 2  RT @noze__baby: 리더즈 완전체 K-할머니 패션 #해치지않아\n#모니카 ...
# 3  RT @chtvn: 노제가 입으면 그게 패션이고 유행이다...🙊\n꽃을 때려박은 시...
# 4  RT @chtvn: 노제가 입으면 그게 패션이고 유행이다...🙊\n꽃을 때려박은 시...
#
#                                              ko_text  \
# 0                                  패션 에디터 박나나님 인스타
# 1    리더즈 완전체 할머니 패션 해치지않아모니카 허니제이 아이키 리헤이 효진초이 가비...
# 2    리더즈 완전체 할머니 패션 해치지않아모니카 허니제이 아이키 리헤이 효진초이 가비...
# 3    노제가 입으면 그게 패션이고 유행이다꽃을 때려박은 시골룩에도 셔터 누르게 만드는...
# 4    노제가 입으면 그게 패션이고 유행이다꽃을 때려박은 시골룩에도 셔터 누르게 만드는...
#
#                                                nouns
# 0                                 [패션, 에디터, 나나, 인스타]
# 1  [리더, 완전체, 할머니, 패션, 해치, 모니카, 허니, 제이, 리헤이, 효진, 초...
# 2  [리더, 완전체, 할머니, 패션, 해치, 모니카, 허니, 제이, 리헤이, 효진, 초...
# 3  [노제, 그게, 패션, 유행, 시골, 셔터, 비주, 얼풀, 버전, 가기, 유튜브, ...
# 4  [노제, 그게, 패션, 유행, 시골, 셔터, 비주, 얼풀, 버전, 가기, 유튜브, ...

# %% [markdown]
# -----

# %% [markdown]
# # <Step3. 분석> : 연관 분석을 이용한 키워드 분석

# %% [markdown]
# ### [연관 키워드 추출하기]

# %% [markdown]
# ### [연관 규칙]
# - https://ratsgo.github.io/machine%20learning/2017/04/08/apriori/
# - 연관규칙 (아프리오리, Apriori 알고리즘) https://blog.naver.com/zzz90zzz/221807210555
# - 연관규칙은 비지도학습으로 대규모 거래 데이터로 부터 함께 구매될 규칙을 도출하여 고객이 특정 상품 구매시 이와 연관성이 높은 상품을 추천하는 것
# - Apriori 알고리즘 : 간단한 성능 측정치를 이용해 거대한 DB에서 데이터간의 연관성을 찾는 알고리즘
# ### [ 연관규칙에서 사용하는 3가지 통계척도 ]
# - 1. 지지도 (support)  : 특정 아이템이 데이터에서 발생하는 빈도
# - 2. 신뢰도 (confidence) : 두 아이템의 연관규칙이 유용한 규칙일 가능성의 척도
# - 3. 향상도 (lift) : 두 아이템의 연관 규칙이 우연인지 아닌지를 나타내는 척도
#
# - 아래 코드 실행을 위해, anaconda prompt 혹은 Terminal에서 아래와 같은 패키지들을 설치
#     - (env_name) `pip install apriori apyori`
# - 혹은 아래의 코드로 라이브러리를 설치

# %%
# !pip install apriori apyori
# Out:
# Requirement already satisfied: apriori in c:\users\yj\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: apyori in c:\users\yj\anaconda3\lib\site-packages (1.1.2)

# %% [markdown]
# ##### 연관 분석 연습

# %%
##### 연관 분석 연습 1
from apyori import apriori

# 장바구니 형태의 데이터(트랜잭션 데이터)를 생성
transactions = [
    ['손흥민', '시소코'],
    ['손흥민', '케인'],
    ['손흥민', '케인', '포체티노']
]

# 연관 분석을 수행
results = list(apriori(transactions))
for result in results:
    print(result)
# Out:
# RelationRecord(items=frozenset({'손흥민'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'시소코'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'시소코'}), confidence=0.3333333333333333, lift=1.0)])
# RelationRecord(items=frozenset({'케인'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'케인'}), confidence=0.6666666666666666, lift=1.0)])
# RelationRecord(items=frozenset({'포체티노'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'포체티노'}), confidence=0.3333333333333333, lift=1.0)])
# RelationRecord(items=frozenset({'시소코', '손흥민'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'시소코', '손흥민'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'시소코'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'시소코'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'케인', '손흥민'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'케인', '손흥민'}), confidence=0.6666666666666666, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'케인'}), confidence=0.6666666666666666, lift=1.0), OrderedStatistic(items_base=frozenset({'케인'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'포체티노', '손흥민'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'손흥민', '포체티노'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'포체티노'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'포체티노'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'케인', '포체티노'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'케인', '포체티노'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'케인'}), items_add=frozenset({'포체티노'}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({'포체티노'}), items_add=frozenset({'케인'}), confidence=1.0, lift=1.5)])
# RelationRecord(items=frozenset({'포체티노', '케인', '손흥민'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'손흥민', '케인', '포체티노'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'케인', '포체티노'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'케인'}), items_add=frozenset({'손흥민', '포체티노'}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({'포체티노'}), items_add=frozenset({'케인', '손흥민'}), confidence=1.0, lift=1.5), OrderedStatistic(items_base=frozenset({'케인', '손흥민'}), items_add=frozenset({'포체티노'}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({'포체티노', '손흥민'}), items_add=frozenset({'케인'}), confidence=1.0, lift=1.5), OrderedStatistic(items_base=frozenset({'케인', '포체티노'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])

# %%
##### 연관 분석 연습 2
# 지지도 0.5, 신뢰도 0.6, 향상도 1.0 이상이면서 (손흥민, 케인) 처럼 규칙의 크기가 2 이하인 규칙을 추출
list(apriori(transactions,
             min_support=0.5,
             min_confidence=0.6,
             min_lift=1.0,
             max_length=2))
# Out:
# [RelationRecord(items=frozenset({'손흥민'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'케인'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'케인'}), confidence=0.6666666666666666, lift=1.0)]),
#  RelationRecord(items=frozenset({'케인', '손흥민'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'케인', '손흥민'}), confidence=0.6666666666666666, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'케인'}), confidence=0.6666666666666666, lift=1.0), OrderedStatistic(items_base=frozenset({'케인'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])]

# %% [markdown]
# -----

# %% [markdown]
# ##### 트위터 연관 키워드 분석

# %%
# 트랜잭션 데이터를 추출
transactions = df['nouns'].tolist()
#transactions = [transaction for transaction in transactions if transaction] # 공백 문자열을 방지
print(transactions)
# Out:
# [['패션', '에디터', '나나', '인스타'], ['리더', '완전체', '할머니', '패션', '해치', '모니카', '허니', '제이', '리헤이', '효진', '초이', '가비', '노제', '리정'], ['리더', '완전체', '할머니', '패션', '해치', '모니카', '허니', '제이', '리헤이', '효진', '초이', '가비', '노제', '리정'], ['노제', '그게', '패션', '유행', '시골', '셔터', '비주', '얼풀', '버전', '가기', '유튜브', '네이버', '저녁', '본방송', '해치', '아스', '우파', '우파', '모니카'], ['노제', '그게', '패션', '유행', '시골', '셔터', '비주', '얼풀', '버전', '가기', '유튜브', '네이버', '저녁', '본방송', '해치', '아스', '우파', '우파', '모니카'], ['섹시', '모델', '패션', '화보', '블랙', '옴므', '레이어', '드아트송', '지오', '남성', '맞
', '본방송', '해치', '아스', '우파', '우파', '모니카'], ['노제', '그게', '패션', '유행', '시골', '셔터', '비주', '얼풀', '버전', '가기', '유튜브', '네이버', '저녁', '본방송', '해치', '아스', '우파', '우파', '모니카'], ['패션', '잡화', '멜빵', '벨트', '리지', '버튼', '참가', '한장', '스트랩', '남녀', '공용', '주얼', '코디', '파트너', '활동', '수수료'], ['스타', '패션', '고글', '선글라스', '프리', '레져', '선글라스', '류진', '스트', '레이', '키즈', '리노', '여진', '뤠이젼', '정진운', '스카', '선글라스', '출처', '블로그'], ['어스', '출국', '출처', '어스', '출국', '직캠', '패션', '현장'], ['스타', '패션', '고글', '선글라스', '프리', '레져', '선글라스', '류진', '스트', '레이', '키즈', '리노', '여진', '뤠이젼', '정진운', '스카', '선글라스', '출처', '블로그'], ['민윤기', '올블랙', '공항', '패션', '취향', '저격'], ['선공', '시골', '패션', '소화', '노제', '얼굴', '제일', '해치', '아스', '우파'], ['슬옹', '아주', '옛날', '공항', '패션', '슬옹'], ['패션', '펜더', '프리미엄', '레더', '웨딩촬영', '솔리드', '스타일', '프로필', '촬영', '소품', '영국', '클립', '멜빵', '벨트', '파트너', '활동', '수수료'], ['패션', '여성', '가죽', '멜빵', '벨트', '가죽', '클립', '남성', '여성', '괄호', '멜빵', '너비', '파트너', '활동', '수수료'], ['어스', '출국', '출처', '어스', '출국', '직캠', '패션', '현장'], ['노제', '그게', '패션', '유행', '시골', '셔터', '비주', '얼풀', '버전', '가기', '유튜브', '네이버', '저녁', '본방송', '해치', '아스', '우파', '우파', '모니카'], ['토라', '아라시', '영향', '왜케좋', '가방', '베개', '향수', '향수', '관심', '냄새', '포즈', '배움', '스킨', '케어', '배움', '패션', '어드', '바이스', '핸드'], ['트친소', '친소', '패션', '정병', '여성', '여성', '킹덤', '자해', '담배', '스타', '기타등등', '전시'], ['남자', '멜빵', '벨트', '멜빵', '패션', '잡화', '솔리드', '브라운', '펜더', '파트너', '활동', '수수료'], ['포토', '공항', '패션', '출처', '헤럴드', '네이버', '연예', '블랙', '핑크',  ...

# %%
# 연관 분석을 수행
results = list(apriori(transactions,
                       min_support=0.05,
                       min_confidence=0.1,
                       min_lift=5,
                       max_length=2))
print(results)
# Out:
# [RelationRecord(items=frozenset({'그게', '가기'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'가기'}), items_add=frozenset({'그게'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'그게'}), items_add=frozenset({'가기'}), confidence=1.0, lift=5.0)]), RelationRecord(items=frozenset({'버전', '가기'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'가기'}), items_add=frozenset({'버전'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'버전'}), items_add=frozenset({'가기'}), confidence=1.0, lift=5.0)]), RelationRecord(items=frozenset({'본방송', '가기'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'가기'}), items_add=frozenset({'본방송'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'본방송'}), items_add=frozenset({'가기'}), confidence=1.0, lift=5.0)]), RelationRecord(items=frozenset({'비주', '가기'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'가기'}), items_add=frozenset({'비주'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'비주'}), items_add=frozenset({'가기'}), confidence=1.0, lift=5.0)]), RelationRecord(items=frozenset({'셔터', '가기'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'가기'}), items_add=frozenset({'셔터'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'셔터'}), items_add=frozenset({'가기'}), confidence=1.0, lift=5.0)]), RelationRecord(items=frozenset({'얼풀', '가기'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'가기'}), items_add=frozenset({'얼풀'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'얼풀'}), items_add=frozenset({'가기'}), confidence=1.0, lift=5.0)]), RelationRecord(items=frozenset({'유튜브', '가기'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'가기'}), items_add=frozenset({'유튜브'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'유튜브'}), items_add=frozenset({'가기'}), confidence=1.0, lift=5.0)]), RelationRecord(items=frozenset({'유행', '가기'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'가기'}), items_add=frozenset({'유행'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'유행'}), items_add=frozenset({'가기'}), confidence=1.0, lift=5.0)]), RelationRecord(items=frozenset({'저녁', '가기'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'가기'}), items_add=frozenset({'저녁'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'저녁'}), items_add=frozenset({'가기'}), confidence=1.0, lift=5.0)]), RelationRecord(items=frozenset({'가비', '리더'}), support=0.1, ordered_statistics=[OrderedStatistic(items_base=frozenset({'가비'}), items_add=frozenset({'리더'}), confidence=1.0, lift=10.0), OrderedStatistic(items_base=frozenset({'리더'}), items_add=frozenset({'가비'}), confidence=1.0, lift=10.0)]), RelationRecord(items=frozenset({'리정', '가비'}), support=0.1, ordered_statistics=[OrderedStatistic(items_base=frozenset({'가비'}), items_add=frozenset({'리정'}), confidence=1.0, lift=10.0), OrderedStatistic(items_base=frozenset({'리정'}), items_add=frozenset({'가비'}), confidence=1.0, lift=10.0)]), RelationRecord(items=frozenset({'리헤이', '가비'}), support=0.1, ordered_statistics=[OrderedStatistic(items_base=frozenset({'가비'}), items_add=frozenset({'리헤이'}), confidence=1.0, lift=10.0), OrderedStatistic(items_base=frozenset({'리헤이'}), items_add=frozenset({'가비'}), confidence=1.0, lift=10.0)]), RelationRecord(items=frozenset({'완전체', '가비'}), support=0.1, ordered_statistics=[OrderedStatistic(items_base=frozenset({'가비'}), items_add=frozenset({'완전체'}), confidence=1.0, lift=10.0), OrderedStatistic(items_base=frozenset({'완전체'}), items_add=frozenset({'가비'}), confidence=1.0, lift=10.0)]), RelationRecord(items=frozenset({'제이', '가비'}), support=0.1, ordered_statistics=[OrderedStatistic(items_base=frozenset({'가비'}), items_add=frozenset({'제이'}), confidence=1.0, lift=10.0), OrderedStatistic(items_base=frozenset({'제이'}), items_add=frozense ...

# %%
# 데이터 프레임 형태로 정리
columns = ['source', 'target', 'support']
network_df = pd.DataFrame(columns=columns)

# 규칙의 조건절을 source, 결과절을 target, 지지도를 support 라는 데이터 프레임의 피처로 변환
for result in results:
    if len(result.items) == 2:
        items = [x for x in result.items]
        row = [items[0], items[1], result.support]
        series = pd.Series(row, index=network_df.columns)
        network_df = network_df.append(series, ignore_index=True)

network_df.head()
# Out:
#   source target  support
# 0     그게     가기      0.2
# 1     버전     가기      0.2
# 2    본방송     가기      0.2
# 3     비주     가기      0.2
# 4     셔터     가기      0.2

# %% [markdown]
# -----

# %% [markdown]
# ### [단어 빈도 추출하기]

# %% [markdown]
# ##### 말뭉치 추출

# %%
# 말뭉치를 추출합
tweet_corpus = "".join(df['ko_text'].tolist())
print(tweet_corpus)
# Out:
#   패션 에디터 박나나님 인스타    리더즈 완전체 할머니 패션 해치지않아모니카 허니제이 아이키 리헤이 효진초이 가비 노제 리정   리더즈 완전체 할머니 패션 해치지않아모니카 허니제이 아이키 리헤이 효진초이 가비 노제 리정   노제가 입으면 그게 패션이고 유행이다꽃을 때려박은 시골룩에도 셔터 누르게 만드는 비주얼풀버전 보러 가기 유튜브 네이버목 저녁   본방송 해치지않아스우파 스우파모니카  노제가 입으면 그게 패션이고 유행이다꽃을 때려박은 시골룩에도 셔터 누르게 만드는 비주얼풀버전 보러 가기 유튜브 네이버목 저녁   본방송 해치지않아스우파 스우파모니카섹시모델패션화보블랙옴므레이어드아트송지오남성복맞팔컨펨포러리컬랙션백화점프로필소통데일리룩귀요미  노제가 입으면 그게 패션이고 유행이다꽃을 때려박은 시골룩에도 셔터 누르게 만드는 비주�
요리 도전 하세요퀸즈영이마켓 퀸즈패리스  패션 패션의류   어쩐지 어디서 본 것 같다역시 탁구선수 강승윤의 패션스타일 강승윤   위너  치와와 소형견 세련된 패션 강아지 슈즈 신발 말티즈 부츠 호  파트너스 활동으로 수수료를 받을수 있어요 카이 춤카이 화보카이 인스타카이 콘서트카이 구찌카이 음색카이 직캠카이 엑소카이 컴백종인 춤종인 화보종인 움짤종인 고화질종인 콘서트종인 직캠종인 공항패션김종인 사랑해김종인 인 신용있는 레플리카는 역시  홍콩 급급미러급레플리카급가방급가방레플리카가방급레플리카연예인가방공항패션공항연애인가방 ...

# %%
from konlpy.tag import Okt
from collections import Counter

# 명사 키워드를 추출, 빈도수 계산
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(tweet_corpus)
count = Counter(nouns)

# 한글자 키워드를 제거
remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
print(remove_char_counter)
# Out:
# Counter({'패션': 102, '우파': 42, '해치': 32, '노제': 32, '모니카': 30, '시골': 22, '네이버': 22, '아스': 22, '그게': 20, '유행': 20, '셔터': 20, '비주': 20, '얼풀': 20, '버전': 20, '가기': 20, '유튜브': 20, '저녁': 20, '본방송': 20, '어스': 20, '출국': 20, '출처': 18, '공항': 12, '직캠': 12, '리더': 10, '완전체': 10, '할머니': 10, '허니': 10, '제이': 10, '아이': 10, '리헤이': 10, '효진': 10, '초이': 10, '가비': 10, '리정': 10, '강승윤': 10, '현장': 10, '스타일': 9, '은우': 9, '파트너': 9, '활동': 9, '카이': 9, '류진': 8, '멜빵': 8, '수수료': 8, '가방': 7, '종인': 7, '블랙': 6, '블로그': 6, '역시': 6, '선글라스': 6, '신발': 6, '어쩐지': 5, '탁구선수': 5, '위너': 5, '섹시': 4, '화보': 4, '스튜': 4, '디어': 4, '예지': 4, '니트': 4, '귀걸이': 4, '전신': 4, '지심': 4, '벨트': 4, '스타': 4, '여성': 4, '핑크': 4, '나물': 4, '강아지': 4, '플리': 4, '명품': 4, '남성': 3, '프로필': 3, '아기': 3, '오늘': 3, '사랑': 3, '로제': 3, '배역': 3, '진영': 3, '인기': 3, '욕심': 3, '요리': 3, '말티즈': 3, '양말': 3, '인스타': 2, '모델': 2, '옴므': 2, '레이어': 2, '드아트송': 2, '지오': 2, '맞팔': 2, '컨펨포러리컬랙': 2, '백화점': 2, '소통': 2, '일리': 2, '귀요미': 2, '잡식': 2, '음식': 2, '완성': 2, '선공': 2, '소화': 2, '얼굴': 2, '제일': 2, '스튜디오': 2, '리아': 2, '스웨터': 2, '정보': 2, '뷰티': 2, '크리스토프': 2, '타르': 2, '고양이': 2, '잡화': 2, '고글': 2, '프리': 2, '레져': 2, '스트': 2, '레이': 2, '키즈': 2, '리노': 2, '여진': 2, '뤠이젼': 2, '정진운': 2, '스카': 2, '민윤기': 2, '올블랙': 2, '취향': 2, '저격': 2, '슬옹': 2, '펜더': 2, '솔리드': 2, '클립': 2, '가죽': 2, '향수': 2, '배움': 2, '연예': 2, '생일': 2, '안
# ##### 단어 빈도 점수 추가

# %%
# 키워드와 키워드 빈도 점수를 ‘node’, ‘nodesize’ 라는 데이터 프레임의 피처로 생성
node_df = pd.DataFrame(remove_char_counter.items(), columns=['node', 'nodesize'])
node_df = node_df[node_df['nodesize'] >= 20] # 시각화의 편의를 위해 ‘nodesize’ 50 이하는 제거합니다.
node_df.head()
# Out:
#    node  nodesize
# 0    패션       102
# 7    해치        32
# 8   모니카        30
# 16   노제        32
# 18   그게        20

# %% [markdown]
# -----

# %% [markdown]
# # <Step4. 시각화> : 연관 키워드 네트워크 시각화

# %% [markdown]
# ### [연관 키워드 네트워크 시각화]

# %% [markdown]
# - 아래 코드 실행을 위해, anaconda prompt 혹은 Terminal에서 아래와 같은 패키지를 설치해 줍니다.
#     - (env_name) `pip install networkx`
# - 혹은 아래의 코드로 라이브러리를 설치합니다.
# - networkx 버전 2.3 이하를 설치하는 경우, 아래 코드를 다음과 같이 바꿔주어야 합니다.
#     - `sizes = [G.nodes[node]['nodesize']*25 for node in G]` -> `sizes = [G.node[node]['nodesize']*25 for node in G]`

# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\users\yj\anaconda3\lib\site-packages (2.6.3)

# %%
# !pip install decorator==4.3
# Out:
# Requirement already satisfied: decorator==4.3 in c:\users\yj\anaconda3\lib\site-packages (4.3.0)

# %% [markdown]
# -----

# %%
import networkx as nx
plt.figure(figsize=(20,20))

# networkx 그래프 객체를 생성
G = nx.Graph()

# node_df의 키워드 빈도수를 데이터로 하여, 네트워크 그래프의 ‘노드’ 역할을 하는 원을 생성
for index, row in node_df.iterrows():
    G.add_node(row['node'], nodesize=row['nodesize'])
    
# network_df의 연관 분석 데이터를 기반으로, 네트워크 그래프의 ‘관계’ 역할을 하는 선을 생성
for index, row in network_df.iterrows():
    G.add_weighted_edges_from([(row['source'], row['target'], row['support'])])
    
# 그래프 디자인과 관련된 파라미터를 설정
pos = nx.spring_layout(G, k=0.6, iterations=50)
# nx.draw(G, pos=pos)
sizes = [G.nodes[node]['nodesize']*25 for node in G]
nx.draw(G, pos=pos, node_size=sizes)


# Windows 사용자는 AppleGothic 대신,'Malgun Gothic'. 그 외 OS는 OS에서 한글을 지원하는 기본 폰트를 입력
# nx.draw_networkx_labels(G, pos=pos, font_family='NanumGothic', font_size=25)
nx.draw_networkx_labels(G, pos=pos, font_path='../Library/EliceDigitalBaeum_Bold.ttf', font_size=25)

# 그래프를 출력
ax = plt.gca()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1212/311926087.py in <module>
#      16 pos = nx.spring_layout(G, k=0.6, iterations=50)
#      17 # nx.draw(G, pos=pos)
# ---> 18 sizes = [G.nodes[node]['nodesize']*25 for node in G]
#      19 nx.draw(G, pos=pos, node_size=sizes)
#      20
#
# ~\AppData\Local\Temp/ipykernel_1212/311926087.py in <listcomp>(.0)
#      16 pos = nx.spring_layout(G, k=0.6, iterations=50)
#      17 # nx.draw(G, pos=pos)
# ---> 18 sizes = [G.nodes[node]['nodesize']*25 for node in G]
#      19 nx.draw(G, pos=pos, node_size=sizes)
#      20
#
# KeyError: 'nodesize'
