# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
response = requests.get("http://www.naver.com")

# %%
html = response.text
html
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>  <link rel="stylesheet" href="https://pm.pstatic.net/dist/css/nmain.20220106.css"> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_210318.css"> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"/>  <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <script>window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent,useIeJSFlag="1";window.nmain.isIE="0"===useIeJSFlag,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function e(){}return e.prototype=n,new e})</script> <script>var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")})),window.ndpsdk=window.ndpsdk||{cmd:[],polyfill:{cmd:[]}},window.ndpsdk.cmd.push((function(){window.ndpsdk.setHostMeta("theme",darkmode?"dark":"light")}))</script>  <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script>  <script> window.nmain.gv = {  isLogin: false,\nuseId: null,   daInfo: {"ANIMAL":{"menu":"ANIMAL","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000161","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_animal_1","tb":"ANIMAL_1","unit":"SU10567","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000162","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_animal_2","tb":"ANIMAL_1","unit":"SU10568","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"BUSINESS":{"menu":"BUSINESS","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000165","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_business_1","tb":"BUSINES ...

# %%
soup = BeautifulSoup(html, 'html.parser')
word = soup.select_one('#NM_set_home_btn')

print(word.text)
# Out:
# 네이버를 시작페이지로

# %%
word.attrs['href']
# Out:
# 'https://help.naver.com/support/welcomePage/guide.help'

# %%
word.attrs['class']
# Out:
# ['link_set']

# %%
word.attrs['data-clk']
# Out:
# 'top.mkhome'

# %%
today = soup.select_one('.title')
today
# Out:
# <strong class="title">오늘 읽을만한 글</strong>

# %%
print(today.text)
# Out:
# 오늘 읽을만한 글

# %%
title = soup.select('.title')
for one in title:
    print(one.text)
# Out:
# 오늘 읽을만한 글
# 박진영 모닝루틴  20년째 실천 중인 시크릿 건강 식단  아침식사  집사부일체 60회 61회
# 스걸파 '스트릿댄스걸스파이터' 턴즈, 눈물의 우승...클루씨 5위 (6회 리뷰 + 최종 순위)
# 콜라비요리 아삭한 콜라비깍두기 담그는법 양념 손질
# 간단한반찬 물미역과 초고추장 제철음식 생미역으로 겨울 밑반찬 만들기
# [탄생비화]그에게도 젊은 시절이 있다 ‘셜록 홈즈: 챕터 원’ 셜록
# 영화 <블랙 위도우> 불법 다운로드로 인해 디즈니 7000억 이상 손해를 입었다.
# 블레이드앤소울2 굴락의 시련 던전 공략 블소2 새해 근황
# 대형견 종류 세인트버나드 알아볼께요
# 나이에 한번! 직업에 두 번 놀라운 자기소개?! ㅣ나는솔로 EP.26ㅣSBSPLUSㅣ매주 수요일 밤 10시 30분 방송
# 제주도 호텔 애프터눈티 | 그랜드하얏트 제주 드림타워 라운지 38
# 20대 초반(03~98년생) 정신 차려야 하는 이유
# 제네시스 G90 풀체인지 실물 목격, 출시정보 정리 RS4
# 태국 한달살기, 치앙마이 여행 올드타운 Graph 카페
# "이래서 선택합니다" 그랜저에 245만 원을 추가해야 하는 이유
# 윗배, 아랫배 체지방 빼는 여자 복근운동 루틴
# 수입차보다 부식 발생수 2~4배 많은 국산차, 내구품질 개선 이뤄질까?
# 2021 자라 세일 오프라인 쇼핑 후기 및 품목 추천 리뷰
# [Serie A] 동점골로 복귀 신고를 제대로하는 키에사!
# 중국이 아직 미국을 따라잡을 수 없는 이유 I: 발목 잡는 과거
# 박신혜 최태준 새해 1월 교회 결혼식  이 둘처럼 경건한 채플st 인기웨딩홀 찾고 있다면?
# 코스트코 빵 종류 다 찍어왔드아~
# 20개월 해외여행 못 가면서 사라진 습관들
# 소소한 여행 썰] 내가 탄 비행기의 승무원이 모두 연예인?? (feat. 비행기 타고 가요)
# 팰리세이드 페이스리프트 실내 포착…일체형 디스플레이 적용
# "무조건 벌금 12만원입니다" 이건 너무한거 아니냐는 시민들의 말에 내세운 대책은?
# 이모의 생일 선물 보석 십자수, 한달 만에 완성!!
# [유혹 엔딩] 이이담을 향한 김강우의 끈질긴 유혹! | JTBC 220106 방송
# 현대차가 알뜰폰 사업하는 이유
# 아이폰폴더블 아이폰플립 출시 확률 높아졌다
# 아우디 S6, 연초부터 파격 할인 ‘최대 1500만원’
# 합성 아님 ㄷㄷ 브래드 피트·안젤리나 졸리 딸 근황
# 추워서 보일러 세게 틀어놓고 잤는데 강아지 사라졌길래 집안 뒤지다 발견한 '의외의 장소'
# 김밥맛있게싸는법 꼬마김밥 김 앞뒤
# 나의 아저씨 명대사 아이유 이선균 엔딩 결말 #3
# 간편 점심도시락 ~ 샐러드 다이어트 남편도시락 채식식단
# 수상한 컨테이너 밑에서 발견된 100억원 돈뭉치!
# SK의 길을 가는 한화
# 저 이러고 잔대요 ㅋㅋㅋ
# 테라스가 있는 반지하 공간의 미니멀 인테리어
# 포항 스페이스워크 & 영일대 해수욕장, 영일교 걷기!
# 주방 인테리어 수전, 사각싱크볼 비교ㅣ물튀김, 그래서 튄다는거야? 안튄다는거야? 두 종류 실사용 후기 (더죤테크 수전과 사각씽크볼 조합)
# 엄마가 말을 예쁘게 하면...
# 10개월아기 한달 생활비
# 매일매일 색다른 도시락요리, 직장인 남편 점심 간편도시락 주간밥상
# 입대 앞둔 공명이 놀리기 합류한 장꾸 손님 지창욱의 등장 ^ㅁ^ ㅋㅋ | tvN 220106 방송
# 행복으로 가는 길이 너무 멀게 느껴질 때
# 제주 신라호텔 제꼈다... 더 인기였던 호텔 검색어는?
# 역대 가장 로맨틱한 정조… “최대한 담백하게 그리고 싶었죠”
# 겨울 패션의 완성은 코트! 얼죽코들을 위한 겨울 코트 스타일링 모음
# 살림잇템 - 나를 행복하게 해주는 살림살이 가전제품편:)
# 출장 때문에 여친에게 반려견 부탁했는데…털 묶어놓은 현장에 '이별 통보' 고민하는 남친
# 아파트 거실이 '북카페'로 대변신!? 53평 아파트 인테리어
# 성장기 어린이의 숙면을 위한 음식 6가지!
# 슈퍼맨이 돌아왔다 414회 티저 - 찐건나블리네 | KBS 방송
# 공지사항
# Creators
# Partners
# Developers
# 웨일 브라우저
# 프로젝트 꽃

# %%
## 실습 1 삼성 뉴스 검색 제목 url 주소
samsung = requests.get("https://search.naver.com/search.naver?where=news&sm=tab_jum&query=%EC%82%BC%EC%84%B1")

# %%
shtml=samsung.text

# %%
samsungSoup = BeautifulSoup(shtml,'html.parser')
samsungLink = samsungSoup.select('.news_tit')

# %%
for sec in samsungLink:
    print(sec.attrs['title'] + '\n' + sec.attrs['href'])
# Out:
# 삼성전자 작년 연간 매출 279조원…사상 최대치 기록(종합)
# http://yna.kr/AKR20220107035700003?did=1195m
# 삼성전자 작년 연간 매출 279조원…사상 최대 기록
# https://www.hani.co.kr/arti/economy/economy_general/1026389.html
# 삼성전자, 작년 매출 ‘사상 최고’ 새 역사…‘300조 시대’ 청신호
# http://news.heraldcorp.com/view.php?ud=20220107000068
# 삼성전자, 작년 4분기 매출 76조·영업익 13.8조
# http://www.newsis.com/view/?id=NISX20220107_0001716245&cID=13001&pID=13000
# OLED TV 초고화질 전쟁 점화… 삼성 QD vs LG EX
# https://biz.chosun.com/it-science/ict/2022/01/07/TQTK2SLTYFGGDLSWR3KTHBAUVE/?utm_source=naver&utm_medium=original&utm_campaign=biz
# 삼성전자 지난해 매출 279조원 사상 최대 실적
# https://www.khan.co.kr/economy/economy-general/article/202201070913001
# 삼성전자 '반도체의 힘'…작년 역대 최대 매출 '278조원' 전망
# https://www.news1.kr/articles/?4546753
# [속보] 삼성전자 작년 영업이익 51조5700억원…전년 대비 43.3%↑
# http://news.mk.co.kr/newsRead.php?no=19030&year=2022
# "조만간 좋은 결과"…삼성전자, 대형 M&A 예고
# http://news.mk.co.kr/newsRead.php?no=18187&year=2022
# [CES 2022]한종희, '삼성-LG' OLED 동맹설에 "가능성 열려있다"
# http://www.edaily.co.kr/news/newspath.asp?newsid=02063126632195096

# %% [markdown]
# ## 검색어에 따라 다른 결과 나타내기
# #### - 프로토콜, 도메인, 패스(경로) ,파라미터(서버의 추가적인 정보를 제공하기 위해서 사용, 키와 값으로 구성, & 로 구분)
# #### - query는 검색어에 해당됨
# #### - 파이썬에서 사용자에게 검색어를 입력받은 뒤 query값에 적용하면 검색어 변경 가능

# %%
# 파이썬 기본 내장함수 input으로 사용자로부터 검색어 입력 받음
keyword = input("insert keyword, 검색어를 입력하세요.")

# 뉴스의 url로 부터 응답요청
#query의 값으로 사용자로부터 입력받은 keyword가 대입
response = requests.get('https://search.naver.com/search.naver?where=news&sm=tab_jum&query='+keyword)
# 웹 사이트의 html 소스 코드를 가져옴
html = response.text
# HTML 텍스트를 가져오기 쉽게 soup적용
# html.parser (html 번역기로 해석)
soup = BeautifulSoup(html, 'html.parser')

# select는 여러개의 태그를 가져옴, select_one으로 원하는 태그 하나를 가져옴
# select로 뉴스 기사 10개 가져옴
# soup.select_one(".news_tit")
links = soup.select(".news_tit") # 결과가 리스트 형태

# 리스트의 값을 하나씩 for로 출력
for link in links:
    title = link.attrs['title'] # 태그 내 텍스트 요소 가져옴
    url  = link.attrs['href'] # 속성 href의 값을 가져옴
    print(title + '\n' +  url)
# Out:
# insert keyword, 검색어를 입력하세요.네네
# 가평군 조종면, 네네치킨 현리점에서 치킨세트 기탁
# http://www.breaknews.com/862158
# 네네치킨, 2022년 1월에도 자사앱 4,000원 할인 이벤트는 계속
# http://moneys.mt.co.kr/news/mwView.php?no=2022010409398016156
# SG골프, 네네치킨과 함께하는 행운존 이벤트 진행
# http://www.segyebiz.com/newsView/20220105504804?OutUrl=naver
# 네네치킨, 2022년 시작은 '카카오톡선물하기'에서 6천원 할인으로
# http://moneys.mt.co.kr/news/mwView.php?no=2021123016478015244
# SG골프, 네네치킨과 함께하는 행운존 이벤트 진행
# http://www.sentv.co.kr/news/view/608557
# 네네치킨, 요기요에서 전 메뉴 5,000원 할인 쏜다
# http://moneys.mt.co.kr/news/mwView.php?no=2021122715508040322
# "나아갈 때와 물러설 때를 아는 '중도'" 대장 호랑이의 자질
# https://www.ytn.co.kr/_ln/0106_202201031225328885
# 허은아 "김종인 위원장 '연기' 발언, 윤석열 후보가 오해했을 수 있어"
# https://news.bbsi.co.kr/news/articleView.html?idxno=3055066
# 네네치킨, 사이드 신메뉴 ‘네네초코볼·네네맥앤치즈볼·네네삼색볼’ 색다른 볼시리즈 3종 출시
# http://moneys.mt.co.kr/news/mwView.php?no=2021122313068039303
# 네네치킨, 네네크리스마스 행운경품 이벤트 12월 31일까지 진행
# http://moneys.mt.co.kr/news/mwView.php?no=2021122014148031290
