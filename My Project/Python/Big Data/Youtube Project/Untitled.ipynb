# %%
import argparse

from apiclient.discovery import build
from apiclient.errors import HttpError
from oauth2client.tools import argparser

# %%
DEVELOPER_KEY = "AIzaSyA8fyABQcjCxj9RtS6fPfS4_4ZCu8HqJGY"
YOUTUBE_API_SERVICE_NAME="youtube"
YOUTUBE_API_VERSION="v3"
youtube = build(YOUTUBE_API_SERVICE_NAME,YOUTUBE_API_VERSION,developerKey=DEVELOPER_KEY)

# %%
search_response = youtube.search().list(
    part="snippet",
    maxResults=50,
    publishedAfter ='2022-01-01T00:00:00Z',
    regionCode = 'KR',
    type = 'video',
    order = 'viewCount'
    ,safeSearch = 'strict'#  제한된 콘텐츠를 모두 제외
  ).execute()

# %%
video_ids = []
for item in search_response['items']:
    video_ids.append(item['id']['videoId'])

# %%
video_ids # 조회수가 많은 아이디 순
# Out:
# ['ZKQ-u9vEPTs',
#  'aYr4SlRjZf0',
#  'crUnaCpci2U',
#  '0IBSemQmno8',
#  'osmHArcf_aE',
#  'vsmkpS6z4gg',
#  '4gXmClk8rKI',
#  'xeAxDgfat0M',
#  'y9kkXTucnLU',
#  'RP4lbSymeZ4',
#  'GaF3pH1bPg4',
#  '2Jdpwb_0F5w',
#  '2ykQRba4kM4',
#  'gTwHmYhVAQE',
#  '-lw_iBFQWqQ',
#  'AbZH7XWDW_k',
#  'RccDIpx4ZMM',
#  '3GWscde8rM8',
#  'UAQT5Hgrm1Q',
#  'l-fZh5Maq0k',
#  'KpTBm_fg-Wk',
#  'VbIf3z2SqHg',
#  'PM39oZDPzOs',
#  'Eq1_WPnzvKw',
#  'Zzl9eAcI1lk',
#  'IPFHcQSpu1g',
#  '2x-MeMy_02U',
#  'SfOogcQIFBc',
#  'nvwIVPtD5fI',
#  'oV_2853N4n4',
#  'xbLbHjeOvMo',
#  'KBEZm2xQjtk',
#  'wHvpwSxCOyQ',
#  'KLF85_qHujQ',
#  'N4wA8ApO-PI',
#  'OZdK1czhuv8',
#  'hJdy6aOrWs8',
#  'iME8rIDpXsE',
#  'WvVs1vgxxes',
#  '36vANFBwSks',
#  'qot8a4TnD0c',
#  'M1EhTNvPspQ',
#  'zXTseLR9plQ',
#  'iTXEJQlMjMI',
#  'ie8MjYfm-I4',
#  'dFR0-anGs00',
#  'NX_s-sRNr2E',
#  'uvsDQ5BLcdo',
#  'gnEOsAwDsRo',
#  'J9fq35mmBYc']

# %%
# 카테고리 번호,영상 길이, 조회수, 좋아요 수 , 댓글 수 ,주제 카테고리, 제목
video_categorys = []
video_durations = []
video_viewCounts = []
video_likes = []
video_comments = []
video_titles = []
video_commentAndComentLieks = []

def viedo_list(part, prop):
    lists = []
    for video_id in video_ids:
        video_responce = youtube.videos().list(part = part,id = video_id).execute()
        for video in video_responce.get('items'):
            viedo_prop = video.get(part)
            if viedo_prop != None and prop in viedo_prop:
                lists.append(viedo_prop[prop])
            else :
                lists.append('None')
    return lists

video_categorys = viedo_list('snippet','categoryId') # 카테고리 번호 추출

viedo_categoryId_path = 'viedo-categoryId.txt'

def category_text(msg): # 카테고리 번호 TEXT로 전환
    with open(viedo_categoryId_path,encoding = 'utf8') as f: 
        categorys = f.readlines()
        for category in categorys:
            category = category.strip().split('-')
            if int(msg) == int(category[0]):
                text = category[1]
            
    return text

for index in range(len(video_categorys)):
    video_categorys[index] = category_text(video_categorys[index])

print(video_categorys) # 카테고리 추출
# Out:
# [' Science & Technology', ' Cars & Vehicles', ' Entertainment', ' Music', ' Music', ' Music', ' Music', ' Science & Technology', ' Music', ' Entertainment', ' Science & Technology', ' Science & Technology', ' Science & Technology', ' Science & Technology', ' Science & Technology', ' Music', ' Music', ' Music', ' Entertainment', ' Music', ' Science & Technology', ' Music', ' Entertainment', ' Entertainment', ' Entertainment', ' Science & Technology', ' Film & Animation', ' Travel & Events', ' Music', ' Music', ' Entertainment', ' People & Blogs', ' Entertainment', ' Entertainment', ' Music', ' Music', ' Science & Technology', ' Entertainment', ' Music', ' Music', ' Music', ' Cars & Vehicles', ' Music', ' Science & Technology', ' Film & Animation', ' Entertainment', ' People & Blogs', ' Science & Technology', ' Entertainment', ' Music']

# %%
# long – 20분보다 긴 동영상
# medium – 4분 이상 20분 이하인 동영상
# short – 4분 미만인 동영상

video_durations = viedo_list('contentDetails','duration')

print(video_durations) # 동영상 길이 추출
# Out:
# ['PT29M10S', 'PT1M33S', 'PT3M29S', 'PT3M9S', 'PT3M9S', 'PT1M36S', 'PT3M27S', 'PT1M', 'PT4M14S', 'PT3M38S', 'PT36S', 'PT3M27S', 'PT30S', 'PT39S', 'PT2M59S', 'PT3M38S', 'PT3M26S', 'PT3M34S', 'PT4M32S', 'PT4M2S', 'PT1H4M45S', 'PT3M38S', 'PT3M29S', 'PT4M58S', 'PT4M16S', 'PT1M13S', 'PT10M36S', 'PT13M57S', 'PT1M41S', 'PT2M45S', 'PT4M56S', 'PT16S', 'PT3M41S', 'PT3M45S', 'PT4M3S', 'PT31S', 'PT31S', 'PT12M43S', 'PT1M27S', 'PT2M15S', 'PT10M31S', 'PT31S', 'PT1M35S', 'PT1M35S', 'PT2M12S', 'PT3M19S', 'PT16S', 'PT16S', 'PT3M10S', 'PT47S']

# %%
def duration_check(viedo):
    copy = ''.join( x for x in viedo if x not in "PT")
    if "H" in copy:
        text  = 'Long'
    elif "M" in copy:
        copy = copy.split('M')
        if int(copy[0]) > 20:
            text  = 'Long'
        elif int(copy[0]) >= 4:
            text = 'Medium'
        else:
            text = 'Short'
    else:
        text = 'Short'
    return text

texts = []
for index in range(len(video_durations)):
    video_durations[index] = duration_check(video_durations[index])

print(video_durations)
# Out:
# ['Long', 'Short', 'Short', 'Short', 'Short', 'Short', 'Short', 'Short', 'Medium', 'Short', 'Short', 'Short', 'Short', 'Short', 'Short', 'Short', 'Short', 'Short', 'Medium', 'Medium', 'Long', 'Short', 'Short', 'Medium', 'Medium', 'Short', 'Medium', 'Medium', 'Short', 'Short', 'Medium', 'Short', 'Short', 'Short', 'Medium', 'Short', 'Short', 'Medium', 'Short', 'Short', 'Medium', 'Short', 'Short', 'Short', 'Short', 'Short', 'Short', 'Short', 'Short', 'Short']

# %%
def isNumber(lists):
    lists_copy = lists
    for i in range(len(lists)):
        if lists[i] == 'None':
            lists_copy[i] = 0
        else:
            lists_copy[i] = int(lists[i])
    return lists_copy

video_likes = isNumber(viedo_list('statistics','likeCount'))

print(video_likes) # 좋아요 수 추출
# Out:
# [776, 276, 650307, 1270071, 1833710, 587453, 326044, 15295, 421621, 188938, 26634, 51630, 17567, 16347, 5050, 720122, 534491, 512564, 376881, 278879, 0, 1064665, 181380, 405780, 282206, 9437, 27545, 64883, 483840, 532680, 223727, 14, 115023, 316633, 0, 720104, 2666, 283143, 764171, 695951, 633616, 199, 624275, 20335, 10497, 97080, 20, 304, 113729, 272838]

# %%
video_viewCounts = isNumber(viedo_list('statistics','viewCount'))

print(video_viewCounts) # 조회수 추출
# Out:
# [36527447, 32689766, 31383735, 28315837, 25803542, 23447292, 23190077, 21790968, 18546187, 16188674, 16076638, 15628715, 15553133, 15390583, 12883591, 10897948, 10394199, 10287316, 9945567, 9228483, 9070942, 8970130, 7258099, 7265561, 6164059, 7167459, 6119980, 5969095, 5925859, 5673761, 5493835, 5382082, 5280984, 5259509, 4608366, 4326342, 4223872, 3997931, 3784434, 3816836, 3645232, 3527801, 3417638, 3386542, 3176967, 3128185, 3127658, 3170380, 2881190, 2853268]

# %%
video_comments = isNumber(viedo_list('statistics','commentCount'))
        
print(video_comments) # 댓글수 추출
# Out:
# [75, 42, 55406, 24054, 148715, 12892, 20175, 1551, 19702, 19227, 1346, 2793, 1180, 1132, 369, 35146, 20345, 81185, 16089, 25424, 0, 73791, 23257, 12141, 4594, 392, 0, 1281, 41952, 28990, 8232, 10, 2306, 22176, 6883, 33633, 135, 5803, 48687, 20717, 17956, 54, 12214, 1091, 0, 1720, 0, 7, 10755, 15772]

# %%
video_titles = viedo_list('snippet','title')

print(video_titles) # 제목 추출
# Out:
# ['[CES 2022] The Better Life You Deserve : Main | LG', 'Hyundai N | “Ready for 2022 WRC Hybrid”', "MOMOLAND X NATTI NATASHA 'Yummy Yummy Love' M/V", "TAEYONG, JENO, HENDERY, YANGYANG, GISELLE 'ZOO' Stage Video", "ENHYPEN (엔하이픈) 'Blessed-Cursed' Official MV", 'Encanto OST (acapella)', "fromis_9 (프로미스나인) 'DM' Official MV", 'Exynos 2200: Playtime is over | Samsung', 'YENA (최예나) - SMILEY (Feat. BIBI) MV', "Apink 에이핑크 'Dilemma' MV", 'Galaxy S22 Ultra Official film: The epic standard | Samsung', 'Galaxy S22 Ultra: Official Introduction Film | Samsung', 'Samsung Galaxy Unpacked February 2022: Official Trailer', 'Samsung Galaxy Unpacked February 2022: Tiger in the city', 'We are behind every wish | Samsung', "TAEYEON 태연 'INVU' MV", "TAEYEON 태연 'Can't Control Myself' MV", 'NMIXX "O.O" M/V', "[입덕직캠] 갓 더 비트 윈터 직캠 4K 'Step Back' (GOT the beat WINTER FanCam) | @MCOUNTDOWN_2022.1.27", '[MV] 문별 (Moon Byul) - LUNATIC', 'Galaxy Unpacked February 2022: Official Replay l Samsung', "[STATION : NCT LAB] MARK 마크 'Child' MV", 'ASTRO 아스트로 진진&라키 - 숨 좀 쉬자(Just Breath) M/V', '[GOT the beat - Step Back] Special Stage | #엠카운트다운 EP.737 | Mnet 220127 방송', '[최초공개] Kep1er(케플러) - WA DA DA (4K) | Kep1er DEBUT SHOW | Mnet 220103 방송', 'The Freestyle: Official Launch Film | Samsung', '미니팡 교육동요 | 알록달록 동요 모아보기 | 과일 | 음식자판기 | 공룡달걀 | 주유 | 색깔놀이 | 미니팡 3D동요!', '파스타 장인! 25년 경력 셰프의 토마토, 크림, 오일 파스타 만들기 / pasta making skill! tomato, cream, oil pasta making', '[NMIXX] Debut Trailer', "WOOZI 'Ruby' Official MV", "'SPECIAL STAGE' '신'인 걸그룹 'GOT the beat'의 'Step Back' 무대", '[트라하인피니티] I am Traha. I am Infinity_Pre-Order (15s)', "[단독샷캠] 에스파 'Dreams Come True' 단독샷 별도녹화│aespa ONE TAKE STAGE│@SBS Inkigayo_2022.01.09.", '[MV] VIVIZ _ BOP BOP!', 'Jamie Miller - Wishes (설강화 OST) [Music Video]', 'BLACKPINK 2022 WELCOMING COLLECTION PREVIEW', 'Galaxy Tab S8 Ultra: Official Launch Film | Samsung', "[ITZY VLOG] YUNA's Graduation VLOG", 'Stray Kids "ODDINARY" Trailer', '[BANGTAN BOMB] BTS’s Chaotic Break Time - BTS (방탄소년단)', '[EPISODE] BTS (방탄소년단) @ 2021 iHeartRadio Jingle Ball', '[광고] 현대자동차 자율주행 "모두의 자율주행이 될 때까지" - 본편', '[BANGTAN BOMB] Jin and Jung Kook Play with a Camera - BTS (방탄소년단)', 'Galaxy Tab S8 Ultra: Official Introduction | Samsung', '미니팡 교육동요 | 알록달록 미끄럼틀 | 토끼 | 오리 | 염소 | 돼지 | 색깔놀이 | 미니팡 3D동요!', 'Kep1er(케플러) - WA DA DA @인기가요 inkigayo 20220123', '[에버콜라겐] TVCF 엄마 선물편🎀', '존슨앤드존슨 비젼: [보다] 캠페인(Short Ver.)', 'ASTRO 아스트로 문빈&산하 - Ghost Town M/V', 'NMIXX "O.O" M/V Teaser']

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 크롤링된 데이터를 저장할 데이터 프레임 
columns = ['제목','분류','동영상 길이','조회수','좋아요 수','댓글 수']
df = pd.DataFrame(columns = columns)

for index in range(len(video_ids)):
    row = [video_titles[index], video_categorys[index], video_durations[index], video_viewCounts[index], video_likes[index], video_comments[index]]
    series = pd.Series(row, index=df.columns)
    df = df.append(series, ignore_index=True)

# %%
df
# Out:
#                                                    제목                     분류  \
# 0   [CES 2022] The Better Life You Deserve : Main ...   Science & Technology
# 1             Hyundai N | “Ready for 2022 WRC Hybrid”        Cars & Vehicles
# 2     MOMOLAND X NATTI NATASHA 'Yummy Yummy Love' M/V          Entertainment
# 3   TAEYONG, JENO, HENDERY, YANGYANG, GISELLE 'ZOO...                  Music
# 4         ENHYPEN (엔하이픈) 'Blessed-Cursed' Official MV                  Music
# 5                              Encanto OST (acapella)                  Music
# 6                  fromis_9 (프로미스나인) 'DM' Official MV                  Music
# 7             Exynos 2200: Playtime is over | Samsung   Science & Technology
# 8                 YENA (최예나) - SMILEY (Feat. BIBI) MV                  Music
# 9                             Apink 에이핑크 'Dilemma' MV          Entertainment
# 10  Galaxy S22 Ultra Official film: The epic stand...   Science & Technology
# 11  Galaxy S22 Ultra: Official Introduction Film |...   Science & Technology
# 12  Samsung Galaxy Unpacked February 2022: Officia...   Science & Technology
# 13  Samsung Galaxy Unpacked February 2022: Tiger i...   Science & Technology
# 14                 We are behind every wish | Samsung   Science & Technology
# 15                               TAEYEON 태연 'INVU' MV                  Music
# 16               TAEYEON 태연 'Can't Control Myself' MV                  Music
# 17                                    NMIXX "O.O" M/V                  Music
# 18  [입덕직캠] 갓 더 비트 윈터 직캠 4K 'Step Back' (GOT the be...          Entertainment
# 19                      [MV] 문별 (Moon Byul) - LUNATIC                  Music
# 20  Galaxy Unpacked February 2022: Official Replay...   Science & Technology
# 21             [STATION : NCT LAB] MARK 마크 'Child' MV                  Music
# 22         ASTRO 아스트로 진진&라키 - 숨 좀 쉬자(Just Breath) M/V          Entertainment
# 23  [GOT the beat - Step Back] Special Stage | #엠카...          Entertainment
# 24  [최초공개] Kep1er(케플러) - WA DA DA (4K) | Kep1er DE...          Entertainment
# 25      The Freestyle: Official Launch Film | Samsung   Science & Technology
# 26  미니팡 교육동요 | 알록달록 동요 모아보기 | 과일 | 음식자판기 | 공룡달걀 | ...       Film & Animation
# 27  파스타 장인! 25년 경력 셰프의 토마토, 크림, 오일 파스타 만들기 / pasta...        Travel & Events
# 28                              [NMIXX] Debut Trailer                  Music
# 29                           WOOZI 'Ruby' Official MV                  Music
# 30  'SPECIAL STAGE' '신'인 걸그룹 'GOT the beat'의 'Step...          Entertainment
# 31  [트라하인피니티] I am Traha. I am Infinity_Pre-Order ...         People & Blogs
# 32  [단독샷캠] 에스파 'Dreams Come True' 단독샷 별도녹화│aespa O...          Entertainment
# 33                              [MV] VIVIZ _ BOP BOP!          Entertainment
# 34      Jamie Miller - Wishes (설강화 OST) [Music Video]                  Music
# 35        BLACKPINK 2022 WELCOMING COLLECTION PREVIEW                  Music
# 36  Galaxy Tab S8 Ultra: Official Launch Film | Sa...   Science & Technology
# 37                 [ITZY VLOG] YUNA's Graduation VLOG          Entertainment
# 38                      Stray Kids "ODDINARY" Trailer                  Music
# 39  [BANGTAN BOMB] BTS’s Chaotic Break Time - BTS ...                  Music
# 40  [EPISODE] BTS (방탄소년단) @ 2021 iHeartRadio Jingl...                  Music
# 41             [광고] 현대자동차 자율주행 "모두의 자율주행이 될 때까지" - 본편        Cars & Vehicles
# 42  [BANGTAN BOMB] Jin and Jung Kook Play with a C...                  Music
# 43  Galaxy Tab S8 Ultra: Official Introduction | S...   Science & Technology
# 44  미니팡 교육동요 | 알록달록 미끄럼틀 | 토끼 | 오리 | 염소 | 돼지 | 색깔놀...       Film & Animation
# 45     Kep1er(케플러) - WA DA DA @인기가요 inkigayo 20220123          Entertainment
# 46                               [에버콜라겐] TVCF 엄마 선물편🎀         People & Blogs
# 47                    존슨앤드존슨 비젼: [보다] 캠페인(Short Ver.)   Science & Technology
# 48                  ASTRO 아스트로 문빈&산하 - Ghost Town M/V          Entertainment
# 49                             NMIXX "O.O" M/V Teaser                  Music
#
#     동영상 길이       조회수    좋아요 수    댓글 수
# 0     Long  36527447      776      75
# 1    Short  32689766      276      42
# 2    Short  31383735   650307   55406
# 3    Short  28315837  1270071   24054
# 4    Short  25803542  1833710  148715
# 5    Short  23447292   587453   12892
# 6    Short  23190077   326044   20175
# 7    Short  21790968    15295    1551
# 8   Medium  18546187   421621   19702
# 9    Short  16188674   188938   19227
# 10   Short  16076638    26634    1346
# 11   Short  15628715    51630    2793
# 12   Short  15553133    17567    1180
# 13   Short  15390583    16347    1132
# 14   Short  12883591     5050     369
# 15   Short  10897948   720122   35146
# 16   Short  10394199   534491   20345
# 17   Short  10287316   512564   81185
# 18  Medium   9945567   376881   16089
# 19  Medium   9228483   278879   25424
# 20    Long   9070942        0       0
# 21   Short   8970130  1064665   73791
# 22   Short   7258099   181380   23257
# 23  Medium   7265561   405780   12141
# 24  Medium   6164059   282206    4594
# 25   Short   7167459     9437     392
# 26  Medium   6119980    27545       0
# 27  Medium   5969095    64883    1281
# 28   Short   5925859   483840   41952
# 29   Short   5673761   532680   28990
# 30  Medium   5493835   223727    8232
# 31   Short   5382082       14      10
# 32   Short   5280984   115023    2306
# 33   Short   5259509   316633   22176
# 34  Medium   4608366        0    6883
# 35   Short   4326342   720104   33633
# 36   Short   4223872     2666     135
# 37  Medium   3997931   283143    5803
# 38   Short   3784434   764171   48687
# 39   Short   3816836   695951   20717
# 40  Medium   3645232   633616   17956
# 41   Short   3527801      199      54
# 42   Short   3417638   624275   12214
# 43   Short   3386542    20335    1091
# 44   Short   3176967    10497       0
# 45   Short   3128185    97080    1720
# 46   Short   3127658       20       0
# 47   Short   3170380      304       7
# 48   Short   2881190   113729   10755
# 49   Short   2853268   272838   15772

# %%
df['분류'].value_counts().head(3)
# Out:
#  Music                   19
#  Science & Technology    12
#  Entertainment           12
# Name: 분류, dtype: int64

# %% [markdown]
# def viedo_comment_and_coment_liek(part):
#     lists = []
#     num = 0
#     for video_id in video_ids:
#         try:
#             video_responce = youtube.commentThreads().list(part = part,videoId = video_id,
#             textFormat = 'plainText',
#             maxResults = 50
#             ).execute()
#             comments = []
#             commentsLikes = []
#             for video in video_responce.get('items'):
#                 viedo_prop = video[part]['topLevelComment'][part]
#                 comments.append(viedo_prop['textDisplay'])
#                 commentsLikes.append(viedo_prop['likeCount'])
#             lists.append([{'comments':comments},{'commentsLikes':commentsLikes}])
#             print(num)
#             num += 1
#         except HttpError as e:
#             lists.append([{'comments':'Disabled'},{'commentsLikes':'Disabled'}])
#             print(str(num) +' 비활성화')
#             num += 1
#     return lists
#
# video_commentAndComentLieks = viedo_comment_and_coment_liek('snippet')
#
# # 비디오 별 댓글과 댓글 좋아요 추출

# %% [markdown]
# video_commentAndComentLieks[21][0]['comments']

# %% [markdown]
# len(video_commentAndComentLieks[21][0]['comments'])

# %% [markdown]
# import os
# import sys
# import urllib.request
#
# client_id = "p6BFvxDN9NQbc3KDOC9d"
# client_secret = "Smi8sEXvu3"
#
# def check_lange(str):
#     if(str != 'Disabled'):
#         encQuery = urllib.parse.quote(str)
#         data = "query=" + encQuery
#         url = "https://openapi.naver.com/v1/papago/detectLangs"
#         request = urllib.request.Request(url)
#         request.add_header("X-Naver-Client-Id",client_id)
#         request.add_header("X-Naver-Client-Secret",client_secret)
#         response = urllib.request.urlopen(request, data=data.encode("utf-8"))
#         rescode = response.getcode()
#         if(rescode==200):
#             response_body = response.read()
#             print(response_body.decode('utf-8'))
#         else:
#             print("Error Code:" + rescode)
#     else:
#         print("댓글 비활성화")
#
# for video_main in video_commentAndComentLieks:
#     print(len(video_main[0]['comments']))
#     print()
#     if type(video_main[0]['comments']) is list:
#         for commtent in video_main[0]['comments']:
#             check_lange(commtent)
#     else:
#         check_lange(video_main[0]['comments'])
