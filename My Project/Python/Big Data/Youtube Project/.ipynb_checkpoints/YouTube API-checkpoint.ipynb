# %%
import argparse

from apiclient.discovery import build
from apiclient.errors import HttpError
from oauth2client.tools import argparser

# %%
DEVELOPER_KEY = "AIzaSyAHWG9XMYIuApl78zAb6F9ozDlTvp3lbFs"
YOUTUBE_API_SERVICE_NAME="youtube"
YOUTUBE_API_VERSION="v3"
youtube = build(YOUTUBE_API_SERVICE_NAME,YOUTUBE_API_VERSION,developerKey=DEVELOPER_KEY)

# %%
search_response = youtube.search().list(
    part="snippet",
    maxResults=50,
    publishedAfter ='2022-01-01T00:00:00Z',
    regionCode = 'KR',
    type = 'video',
    order = 'viewCount',
    safeSearch = 'strict'#  제한된 콘텐츠를 모두 제외
  ).execute()

# %%
video_ids = []
for item in search_response['items']:
    video_ids.append(item['id']['videoId'])

# %%
print(video_ids) # 조회수가 많은 아이디 순
# Out:
# ['ZKQ-u9vEPTs', 'crUnaCpci2U', '0IBSemQmno8', '3GWscde8rM8', 'osmHArcf_aE', 'vsmkpS6z4gg', '4gXmClk8rKI', 'xeAxDgfat0M', 'y9kkXTucnLU', 'RP4lbSymeZ4', 'GaF3pH1bPg4', '2Jdpwb_0F5w', 'gTwHmYhVAQE', 'XVwi2VF7_R4', 'AvM16Vy1byc', 'AbZH7XWDW_k', '63fgP_RJFN4', 'RccDIpx4ZMM', 'UAQT5Hgrm1Q', 'KpTBm_fg-Wk', 'VbIf3z2SqHg', 'Eq1_WPnzvKw', 'PM39oZDPzOs', 'IPFHcQSpu1g', '2x-MeMy_02U', 'SfOogcQIFBc', 'Zzl9eAcI1lk', 'nvwIVPtD5fI', 'oV_2853N4n4', 'xbLbHjeOvMo', 'KLF85_qHujQ', 'wHvpwSxCOyQ', '5ch94AaPZRQ', '7EWZI9LkAes', 'N4wA8ApO-PI', 'OZdK1czhuv8', 'zCyM_7PuYbo', 'hJdy6aOrWs8', 'iME8rIDpXsE', 'WvVs1vgxxes', 'uBGufCcQaQ4', 'M1EhTNvPspQ', 'iTXEJQlMjMI', 'ie8MjYfm-I4', 'dFR0-anGs00', 'a8STFD0lxTk', '7BmDoOmLGDs', 'J9fq35mmBYc', 'H2Tu7BdYDfo', 'gnEOsAwDsRo']

# %%
# 카테고리 번호,영상 길이, 조회수, 좋아요 수 , 댓글 수 ,주제 카테고리, 제목
video_categorys = []
video_durations = []
video_viewCounts = []
video_likes = []
video_comments = []
video_titles = []
video_commentAndComentLieks = []


def viedo_list(part, prop):
    lists = []
    for video_id in video_ids:
        video_responce = youtube.videos().list(part = part,id = video_id).execute()
        for video in video_responce.get('items'):
            viedo_prop = video.get(part)
            if viedo_prop != None and prop in viedo_prop:
                lists.append(viedo_prop[prop])
            else :
                lists.append('None')
    return lists

video_categorys = viedo_list('snippet','categoryId') # 카테고리 번호 추출

viedo_categoryId_path = 'video-categoryId.txt'

def category_text(msg): # 카테고리 번호 TEXT로 전환
    with open(viedo_categoryId_path,encoding = 'utf8') as f: 
        categorys = f.readlines()
        for category in categorys:
            category = category.strip().split('-')
            if int(msg) == int(category[0]):
                text = category[1]
            
    return text

for index in range(len(video_categorys)):
    video_categorys[index] = category_text(video_categorys[index])

print(video_categorys) # 카테고리 추출
# Out:
# [' Science & Technology', ' Entertainment', ' Music', ' Music', ' Music', ' Music', ' Music', ' Science & Technology', ' Music', ' Entertainment', ' Science & Technology', ' Science & Technology', ' Science & Technology', ' Music', ' Music', ' Music', ' Entertainment', ' Music', ' Entertainment', ' Science & Technology', ' Music', ' Entertainment', ' Entertainment', ' Science & Technology', ' Film & Animation', ' Travel & Events', ' Entertainment', ' Music', ' Music', ' Entertainment', ' Entertainment', ' Entertainment', ' Music', ' Entertainment', ' Music', ' Music', ' Entertainment', ' Science & Technology', ' Entertainment', ' Music', ' People & Blogs', ' Cars & Vehicles', ' Science & Technology', ' Film & Animation', ' Entertainment', ' Cars & Vehicles', ' Music', ' Music', ' Entertainment', ' Entertainment']

# %%
# long – 20분보다 긴 동영상
# medium – 4분 이상 20분 이하인 동영상
# short – 4분 미만인 동영상

video_durations = viedo_list('contentDetails','duration')

print(video_durations) # 동영상 길이 추출
# Out:
# ['PT29M10S', 'PT3M29S', 'PT3M9S', 'PT3M34S', 'PT3M9S', 'PT1M36S', 'PT3M27S', 'PT1M', 'PT4M14S', 'PT3M38S', 'PT36S', 'PT3M27S', 'PT39S', 'PT4M1S', 'PT4M16S', 'PT3M38S', 'PT3M25S', 'PT3M26S', 'PT4M32S', 'PT1H4M45S', 'PT3M38S', 'PT4M58S', 'PT3M29S', 'PT1M13S', 'PT10M36S', 'PT13M57S', 'PT4M16S', 'PT1M41S', 'PT2M45S', 'PT4M56S', 'PT3M45S', 'PT3M41S', 'PT23M7S', 'PT52S', 'PT4M3S', 'PT31S', 'PT4M26S', 'PT31S', 'PT12M43S', 'PT1M27S', 'PT22S', 'PT31S', 'PT1M35S', 'PT2M12S', 'PT3M19S', 'PT15S', 'PT31S', 'PT47S', 'PT9M', 'PT3M10S']

# %%
def duration_check(viedo):
    copy = ''.join( x for x in viedo if x not in "PT")
    if "H" in copy:
        text  = 'Long'
    elif "M" in copy:
        copy = copy.split('M')
        if int(copy[0]) > 20:
            text  = 'Long'
        elif int(copy[0]) >= 4:
            text = 'Medium'
        else:
            text = 'Short'
    else:
        text = 'Short'
    return text

texts = []
for index in range(len(video_durations)):
    video_durations[index] = duration_check(video_durations[index])

print(video_durations)
# Out:
# ['Long', 'Short', 'Short', 'Short', 'Short', 'Short', 'Short', 'Short', 'Medium', 'Short', 'Short', 'Short', 'Short', 'Medium', 'Medium', 'Short', 'Short', 'Short', 'Medium', 'Long', 'Short', 'Medium', 'Short', 'Short', 'Medium', 'Medium', 'Medium', 'Short', 'Short', 'Medium', 'Short', 'Short', 'Long', 'Short', 'Medium', 'Short', 'Medium', 'Short', 'Medium', 'Short', 'Short', 'Short', 'Short', 'Short', 'Short', 'Short', 'Short', 'Short', 'Medium', 'Short']

# %%
def isNumber(lists):
    lists_copy = lists
    for i in range(len(lists)):
        if lists[i] == 'None':
            lists_copy[i] = 0
        else:
            lists_copy[i] = int(lists[i])
    return lists_copy

video_likes = isNumber(viedo_list('statistics','likeCount'))

print(video_likes) # 좋아요 수 추출
# Out:
# [777, 655426, 1295095, 723275, 1843669, 595581, 329472, 15311, 426488, 199591, 28474, 52501, 16368, 101567, 156461, 748478, 51807, 537133, 384448, 0, 1073077, 409412, 182435, 9442, 28409, 70236, 283251, 487397, 533733, 224933, 321247, 116297, 382521, 252487, 0, 738455, 195142, 2694, 287939, 785649, 0, 205, 21165, 11224, 97964, 62, 737127, 276693, 34516, 115652]

# %%
video_viewCounts = isNumber(viedo_list('statistics','viewCount'))

print(video_viewCounts) # 조회수 추출
# Out:
# [36527695, 31626183, 29759105, 31730285, 26365905, 23928804, 23382309, 21792771, 18757875, 16520484, 16265890, 16265288, 15391791, 13233948, 16213102, 12273173, 11470315, 10593646, 10246753, 9360084, 9338419, 7481510, 7304221, 7169737, 6377890, 6514576, 6227097, 6055084, 5720165, 5581773, 5470034, 5414702, 6167870, 4905828, 4754299, 4606671, 4405001, 4234123, 4099067, 3994579, 3883318, 3714079, 3437848, 3386762, 3188163, 3213983, 3084011, 2955066, 2960655, 2927165]

# %%
video_comments = isNumber(viedo_list('statistics','commentCount'))
        
print(video_comments) # 댓글수 추출
# Out:
# [75, 55869, 24349, 139012, 149203, 13087, 20307, 1559, 19841, 20099, 1433, 2836, 1131, 5970, 27413, 36474, 6046, 20389, 20234, 0, 74086, 12166, 23346, 392, 0, 1407, 4622, 42090, 29030, 8282, 22245, 2329, 28659, 46, 6895, 34161, 4944, 136, 5861, 49370, 26, 54, 1113, 0, 1732, 0, 20765, 15836, 3736, 10895]

# %%
video_titles = viedo_list('snippet','title')

print(video_titles) # 제목 추출
# Out:
# ['[CES 2022] The Better Life You Deserve : Main | LG', "MOMOLAND X NATTI NATASHA 'Yummy Yummy Love' M/V", "TAEYONG, JENO, HENDERY, YANGYANG, GISELLE 'ZOO' Stage Video", 'NMIXX "O.O" M/V', "ENHYPEN (엔하이픈) 'Blessed-Cursed' Official MV", 'Encanto OST (acapella)', "fromis_9 (프로미스나인) 'DM' Official MV", 'Exynos 2200: Playtime is over | Samsung', 'YENA (최예나) - SMILEY (Feat. BIBI) MV', "Apink 에이핑크 'Dilemma' MV", 'Galaxy S22 Ultra Official film: The epic standard | Samsung', 'Galaxy S22 Ultra: Official Introduction Film | Samsung', 'Samsung Galaxy Unpacked February 2022: Tiger in the city', "MAX CHANGMIN 최강창민 'Devil' MV", "비투비 (BTOB) - '노래 (The Song)' Official Music Video", "TAEYEON 태연 'INVU' MV", 'DRIPPIN(드리핀) ‘Villain’ MV', "TAEYEON 태연 'Can't Control Myself' MV", "[입덕직캠] 갓 더 비트 윈터 직캠 4K 'Step Back' (GOT the beat WINTER FanCam) | @MCOUNTDOWN_2022.1.27", 'Galaxy Unpacked February 2022: Official Replay l Samsung', "[STATION : NCT LAB] MARK 마크 'Child' MV", '[GOT the beat - Step Back] Special Stage | #엠카운트다운 EP.737 | Mnet 220127 방송', 'ASTRO 아스트로 진진&라키 - 숨 좀 쉬자(Just Breath) M/V', 'The Freestyle: Official Launch Film | Samsung', '미니팡 교육동요 | 알록달록 동요 모아보기 | 과일 | 음식자판기 | 공룡달걀 | 주유 | 색깔놀이 | 미니팡 3D동요!', '파스타 장인! 25년 경력 셰프의 토마토, 크림, 오일 파스타 만들기 / pasta making skill! tomato, cream, oil pasta making', '[최초공개] Kep1er(케플러) - WA DA DA (4K) | Kep1er DEBUT SHOW | Mnet 220103 방송', '[NMIXX] Debut Trailer', "WOOZI 'Ruby' Official MV", "'SPECIAL STAGE' '신'인 걸그룹 'GOT the beat'의 'Step Back' 무대", '[MV] VIVIZ _ BOP BOP!', "[단독샷캠] 에스파 'Dreams Come True' 단독샷 별도녹화│aespa ONE TAKE STAGE│@SBS Inkigayo_2022.01.09.", '태연(TAEYEON)의 킬링보이스를 라이브로! - I,그대라는 시,만약에,11:11,Blue,Time Lapse,Weekend,불티,사계,Gravity,INVU,너를 그리는 시간', 'Ice Pacman vs Lava Monster | Arcade Game Stop Motion #Shorts', 'Jamie Miller - Wishes (설강화 OST) [Music Video]', 'BLACKPINK 2022 WELCOMING COLLECTION PREVIEW', '[최초공개] Kep1er(케플러) - Shine (Kep1er Ver.) (4K) | Kep1er DEBUT SHOW | Mnet 220103 방송', 'Galaxy Tab S8 Ultra: Official Launch Film | Samsung', "[ITZY VLOG] YUNA's Graduation VLOG", 'Stray Kids "ODDINARY" Trailer', '콜라에 멘토스 넣어 먹기 mentos & cocacola #shorts', '[광고] 현대자동차 자율주행 "모두의 자율주행이 될 때까지" - 본편', 'Galaxy Tab S8 Ultra: Official Introduction | Samsung', '미니팡 교육동요 | 알록달록 미끄럼틀 | 토끼 | 오리 | 염소 | 돼지 | 색깔놀이 | 미니팡 3D동요!', 'Kep1er(케플러) - WA DA DA @인기가요 inkigayo 20220123', 'ซื้อวันนี้ไฮลักซ์ รีโว่ ทุกรุ่น วันนี้ รับข้อเสนอพิเศษ', 'BTS (방탄소년단) PTD ON STAGE - SEOUL: LIVE VIEWING SPOT', 'NMIXX "O.O" M/V Teaser', "♨핫클립♨ ＂원곡으로 착각할 정도..＂ 공감과 상상을 자극하는 목소리 33호 가수 '제발'｜싱어게인2｜JTBC 220124 방송", 'ASTRO 아스트로 문빈&산하 - Ghost Town M/V']

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/HMKMRHD.ttf"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
# 크롤링된 데이터를 저장할 데이터 프레임 (원본)
columns = ['제목','분류','동영상 길이','조회수','좋아요 수','댓글 수']
df = pd.DataFrame(columns = columns)

for index in range(len(video_ids)):
    row = [video_titles[index], video_categorys[index], video_durations[index], video_viewCounts[index], video_likes[index], video_comments[index]]
    series = pd.Series(row, index=df.columns)
    df = df.append(series, ignore_index=True)

# %%
# 크롤링된 데이터를 저장할 데이터 프레임 (수정본) (ID추가)
columns = ['제목','분류','IDS','동영상 길이','조회수','좋아요 수','댓글 수']
df = pd.DataFrame(columns = columns)

for index in range(len(video_ids)):
    row = [video_titles[index], video_categorys[index],video_ids[index], video_durations[index], video_viewCounts[index], video_likes[index], video_comments[index]]
    series = pd.Series(row, index=df.columns)
    df = df.append(series, ignore_index=True)

# %%
# 크롤링된 데이터를 저장할 데이터 프레임 (수정본) (ID추가)
columns = ['제목','분류','IDS','동영상 길이','조회수','좋아요 수','댓글 수']
df = pd.DataFrame(columns = columns)

for index in range(len(video_ids)):
    row = [video_titles[index], video_categorys[index],video_ids[index], video_durations[index], video_viewCounts[index], video_likes[index], video_comments[index]]
    series = pd.Series(row, index=df.columns)
    df = df.append(series, ignore_index=True)

# %%
df
# Out:
#                                                    제목                     분류  \
# 0   [CES 2022] The Better Life You Deserve : Main ...   Science & Technology
# 1     MOMOLAND X NATTI NATASHA 'Yummy Yummy Love' M/V          Entertainment
# 2   TAEYONG, JENO, HENDERY, YANGYANG, GISELLE 'ZOO...                  Music
# 3                                     NMIXX "O.O" M/V                  Music
# 4         ENHYPEN (엔하이픈) 'Blessed-Cursed' Official MV                  Music
# 5                              Encanto OST (acapella)                  Music
# 6                  fromis_9 (프로미스나인) 'DM' Official MV                  Music
# 7             Exynos 2200: Playtime is over | Samsung   Science & Technology
# 8                 YENA (최예나) - SMILEY (Feat. BIBI) MV                  Music
# 9                             Apink 에이핑크 'Dilemma' MV          Entertainment
# 10  Galaxy S22 Ultra Official film: The epic stand...   Science & Technology
# 11  Galaxy S22 Ultra: Official Introduction Film |...   Science & Technology
# 12  Samsung Galaxy Unpacked February 2022: Tiger i...   Science & Technology
# 13                       MAX CHANGMIN 최강창민 'Devil' MV                  Music
# 14  비투비 (BTOB) - '노래 (The Song)' Official Music Video                  Music
# 15                               TAEYEON 태연 'INVU' MV                  Music
# 16                          DRIPPIN(드리핀) ‘Villain’ MV          Entertainment
# 17               TAEYEON 태연 'Can't Control Myself' MV                  Music
# 18  [입덕직캠] 갓 더 비트 윈터 직캠 4K 'Step Back' (GOT the be...          Entertainment
# 19  Galaxy Unpacked February 2022: Official Replay...   Science & Technology
# 20             [STATION : NCT LAB] MARK 마크 'Child' MV                  Music
# 21  [GOT the beat - Step Back] Special Stage | #엠카...          Entertainment
# 22         ASTRO 아스트로 진진&라키 - 숨 좀 쉬자(Just Breath) M/V          Entertainment
# 23      The Freestyle: Official Launch Film | Samsung   Science & Technology
# 24  미니팡 교육동요 | 알록달록 동요 모아보기 | 과일 | 음식자판기 | 공룡달걀 | ...       Film & Animation
# 25  파스타 장인! 25년 경력 셰프의 토마토, 크림, 오일 파스타 만들기 / pasta...        Travel & Events
# 26  [최초공개] Kep1er(케플러) - WA DA DA (4K) | Kep1er DE...          Entertainment
# 27                              [NMIXX] Debut Trailer                  Music
# 28                           WOOZI 'Ruby' Official MV                  Music
# 29  'SPECIAL STAGE' '신'인 걸그룹 'GOT the beat'의 'Step...          Entertainment
# 30                              [MV] VIVIZ _ BOP BOP!          Entertainment
# 31  [단독샷캠] 에스파 'Dreams Come True' 단독샷 별도녹화│aespa O...          Entertainment
# 32  태연(TAEYEON)의 킬링보이스를 라이브로! - I,그대라는 시,만약에,11:11...                  Music
# 33  Ice Pacman vs Lava Monster | Arcade Game Stop ...          Entertainment
# 34      Jamie Miller - Wishes (설강화 OST) [Music Video]                  Music
# 35        BLACKPINK 2022 WELCOMING COLLECTION PREVIEW                  Music
# 36  [최초공개] Kep1er(케플러) - Shine (Kep1er Ver.) (4K) ...          Entertainment
# 37  Galaxy Tab S8 Ultra: Official Launch Film | Sa...   Science & Technology
# 38                 [ITZY VLOG] YUNA's Graduation VLOG          Entertainment
# 39                      Stray Kids "ODDINARY" Trailer                  Music
# 40            콜라에 멘토스 넣어 먹기 mentos & cocacola #shorts         People & Blogs
# 41             [광고] 현대자동차 자율주행 "모두의 자율주행이 될 때까지" - 본편        Cars & Vehicles
# 42  Galaxy Tab S8 Ultra: Official Introduction | S...   Science & Technology
# 43  미니팡 교육동요 | 알록달록 미끄럼틀 | 토끼 | 오리 | 염소 | 돼지 | 색깔놀...       Film & Animation
# 44     Kep1er(케플러) - WA DA DA @인기가요 inkigayo 20220123          Entertainment
# 45  ซื้อวันนี้ไฮลักซ์ รีโว่ ทุกรุ่น วันนี้ รับข้อเ...        Cars & Vehicles
# 46  BTS (방탄소년단) PTD ON STAGE - SEOUL: LIVE VIEWING...                  Music
# 47                             NMIXX "O.O" M/V Teaser                  Music
# 48  ♨핫클립♨ ＂원곡으로 착각할 정도..＂ 공감과 상상을 자극하는 목소리 33호 가수 ...          Entertainment
# 49                  ASTRO 아스트로 문빈&산하 - Ghost Town M/V          Entertainment
#
#             IDS  동영상 길이       조회수    좋아요 수    댓글 수
# 0   ZKQ-u9vEPTs    Long  36527695      777      75
# 1   crUnaCpci2U   Short  31626183   655426   55869
# 2   0IBSemQmno8   Short  29759105  1295095   24349
# 3   3GWscde8rM8   Short  31730285   723275  139012
# 4   osmHArcf_aE   Short  26365905  1843669  149203
# 5   vsmkpS6z4gg   Short  23928804   595581   13087
# 6   4gXmClk8rKI   Short  23382309   329472   20307
# 7   xeAxDgfat0M   Short  21792771    15311    1559
# 8   y9kkXTucnLU  Medium  18757875   426488   19841
# 9   RP4lbSymeZ4   Short  16520484   199591   20099
# 10  GaF3pH1bPg4   Short  16265890    28474    1433
# 11  2Jdpwb_0F5w   Short  16265288    52501    2836
# 12  gTwHmYhVAQE   Short  15391791    16368    1131
# 13  XVwi2VF7_R4  Medium  13233948   101567    5970
# 14  AvM16Vy1byc  Medium  16213102   156461   27413
# 15  AbZH7XWDW_k   Short  12273173   748478   36474
# 16  63fgP_RJFN4   Short  11470315    51807    6046
# 17  RccDIpx4ZMM   Short  10593646   537133   20389
# 18  UAQT5Hgrm1Q  Medium  10246753   384448   20234
# 19  KpTBm_fg-Wk    Long   9360084        0       0
# 20  VbIf3z2SqHg   Short   9338419  1073077   74086
# 21  Eq1_WPnzvKw  Medium   7481510   409412   12166
# 22  PM39oZDPzOs   Short   7304221   182435   23346
# 23  IPFHcQSpu1g   Short   7169737     9442     392
# 24  2x-MeMy_02U  Medium   6377890    28409       0
# 25  SfOogcQIFBc  Medium   6514576    70236    1407
# 26  Zzl9eAcI1lk  Medium   6227097   283251    4622
# 27  nvwIVPtD5fI   Short   6055084   487397   42090
# 28  oV_2853N4n4   Short   5720165   533733   29030
# 29  xbLbHjeOvMo  Medium   5581773   224933    8282
# 30  KLF85_qHujQ   Short   5470034   321247   22245
# 31  wHvpwSxCOyQ   Short   5414702   116297    2329
# 32  5ch94AaPZRQ    Long   6167870   382521   28659
# 33  7EWZI9LkAes   Short   4905828   252487      46
# 34  N4wA8ApO-PI  Medium   4754299        0    6895
# 35  OZdK1czhuv8   Short   4606671   738455   34161
# 36  zCyM_7PuYbo  Medium   4405001   195142    4944
# 37  hJdy6aOrWs8   Short   4234123     2694     136
# 38  iME8rIDpXsE  Medium   4099067   287939    5861
# 39  WvVs1vgxxes   Short   3994579   785649   49370
# 40  uBGufCcQaQ4   Short   3883318        0      26
# 41  M1EhTNvPspQ   Short   3714079      205      54
# 42  iTXEJQlMjMI   Short   3437848    21165    1113
# 43  ie8MjYfm-I4   Short   3386762    11224       0
# 44  dFR0-anGs00   Short   3188163    97964    1732
# 45  a8STFD0lxTk   Short   3213983       62       0
# 46  7BmDoOmLGDs   Short   3084011   737127   20765
# 47  J9fq35mmBYc   Short   2955066   276693   15836
# 48  H2Tu7BdYDfo  Medium   2960655    34516    3736
# 49  gnEOsAwDsRo   Short   2927165   115652   10895

# %%
df['분류'].value_counts().head(3)
# Out:
#  Music                   19
#  Entertainment           16
#  Science & Technology     9
# Name: 분류, dtype: int64

# %%
df['동영상 길이'].value_counts()
# Out:
# Short     34
# Medium    13
# Long       3
# Name: 동영상 길이, dtype: int64

# %%
df.dtypes
# Out:
# 제목        object
# 분류        object
# IDS       object
# 동영상 길이    object
# 조회수       object
# 좋아요 수     object
# 댓글 수      object
# dtype: object

# %%
# 시리즈 형태의 ojbect를 숫자형태로 변환
a = pd.to_numeric(df['조회수'])
b = pd.to_numeric(df["좋아요 수"])
x = video_viewCounts
y = video_likes
y
# Out:
# [777,
#  655426,
#  1295095,
#  723275,
#  1843669,
#  595581,
#  329472,
#  15311,
#  426488,
#  199591,
#  28474,
#  52501,
#  16368,
#  101567,
#  156461,
#  748478,
#  51807,
#  537133,
#  384448,
#  0,
#  1073077,
#  409412,
#  182435,
#  9442,
#  28409,
#  70236,
#  283251,
#  487397,
#  533733,
#  224933,
#  321247,
#  116297,
#  382521,
#  252487,
#  0,
#  738455,
#  195142,
#  2694,
#  287939,
#  785649,
#  0,
#  205,
#  21165,
#  11224,
#  97964,
#  62,
#  737127,
#  276693,
#  34516,
#  115652]

# %%
plt.figure(figsize = (10, 10))

colors = np.random.rand(50)
plt.title("조회수 와 {}의 관계".format(df.describe().columns[i]))
plt.xlabel("조회수")
plt.ylabel("좋아요 수")

plt.scatter(x = x,
           y = y,
          marker = "*",
          vmax = 500,
          linewidth=3,
          c=colors)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8732/3419527265.py in <module>
#       2
#       3 colors = np.random.rand(50)
# ----> 4 plt.title("조회수 와 {}의 관계".format(df.describe().columns[i]))
#       5 plt.xlabel("조회수")
#       6 plt.ylabel("좋아요 수")
#
# NameError: name 'i' is not defined

# %%
sns.displot(x=video_viewCounts, y=video_likes,
            data=df)
plt.show()

# %%
sns.displot(x=video_viewCounts, y=video_categorys,
            data=df)
plt.show()

# %%
sns.displot(x=video_durations, y=video_categorys,
        data=df,
        linewidth = 5,
        cmap = 'YlGnBu',
        cbar = True)
plt.show()

# %%
sns.displot(x=video_durations, y=video_categorys,
        data=df,
        linewidth = 5)
plt.show()

# %%
#video_categorys = []
#video_durations = []
#video_viewCounts = []
#video_likes = []
#video_comments = []
#video_titles = []

# %%
cols_view = [df['조회수'],df['좋아요 수']]
cols_view
# Out:
# [0     36527695
#  1     31626183
#  2     29759105
#  3     31730285
#  4     26365905
#  5     23928804
#  6     23382309
#  7     21792771
#  8     18757875
#  9     16520484
#  10    16265890
#  11    16265288
#  12    15391791
#  13    13233948
#  14    16213102
#  15    12273173
#  16    11470315
#  17    10593646
#  18    10246753
#  19     9360084
#  20     9338419
#  21     7481510
#  22     7304221
#  23     7169737
#  24     6377890
#  25     6514576
#  26     6227097
#  27     6055084
#  28     5720165
#  29     5581773
#  30     5470034
#  31     5414702
#  32     6167870
#  33     4905828
#  34     4754299
#  35     4606671
#  36     4405001
#  37     4234123
#  38     4099067
#  39     3994579
#  40     3883318
#  41     3714079
#  42     3437848
#  43     3386762
#  44     3188163
#  45     3213983
#  46     3084011
#  47     2955066
#  48     2960655
#  49     2927165
#  Name: 조회수, dtype: object,
#  0         777
#  1      655426
#  2     1295095
#  3      723275
#  4     1843669
#  5      595581
#  6      329472
#  7       15311
#  8      426488
#  9      199591
#  10      28474
#  11      52501
#  12      16368
#  13     101567
#  14     156461
#  15     748478
#  16      51807
#  17     537133
#  18     384448
#  19          0
#  20    1073077
#  21     409412
#  22     182435
#  23       9442
#  24      28409
#  25      70236
#  26     283251
#  27     487397
#  28     533733
#  29     224933
#  30     321247
#  31     116297
#  32     382521
#  33     252487
#  34          0
#  35     738455
#  36     195142
#  37       2694
#  38     287939
#  39     785649
#  40          0
#  41        205
#  42      21165
#  43      11224
#  44      97964
#  45         62
#  46     737127
#  47     276693
#  48      34516
#  49     115652
#  Name: 좋아요 수, dtype: object]

# %%
df.to_csv("YouTube_List.csv")

# %%
df['동영상 길이'].value_counts().plot(
    kind = "pie",
    title = "인기동영상 시간별 분류",
    label = " ",
    autopct= "%.0f%%",
    figsize = (6, 6));

# %%
df['분류'].value_counts().plot(
    kind = "pie",
    title = "카테고리별 카운트",
    label = " ",
    autopct= "%.0f%%",
    figsize = (6, 6));

# %%
Type0 = pd.read_csv('./Data/videoType_dfs0.csv', engine= "python") # type lone
Type1 = pd.read_csv('./Data/videoType_dfs1.csv', engine= "python") # type medium
Type2 = pd.read_csv('./Data/videoType_dfs2.csv', engine= "python") # type shory
Cate0 = pd.read_csv('./Data/category_dfs0.csv', engine= "python")
Cate1 = pd.read_csv('./Data/category_dfs1.csv', engine= "python")
Cate2 = pd.read_csv('./Data/category_dfs2.csv', engine= "python")

# %%
Type2
# Out:
#     Unnamed: 0                                                 제목  \
# 0            0            Hyundai N | “Ready for 2022 WRC Hybrid”
# 1            1    MOMOLAND X NATTI NATASHA 'Yummy Yummy Love' M/V
# 2            2  TAEYONG, JENO, HENDERY, YANGYANG, GISELLE 'ZOO...
# 3            3  펜타곤(PENTAGON) - 'Feelin' Like' Official Music ...
# 4            4                                    NMIXX "O.O" M/V
# 5            5        ENHYPEN (엔하이픈) 'Blessed-Cursed' Official MV
# 6            6                             Encanto OST (acapella)
# 7            7                 fromis_9 (프로미스나인) 'DM' Official MV
# 8            8            Exynos 2200: Playtime is over | Samsung
# 9            9  Galaxy S21 FE 5G: Official Introduction Film |...
# 10          10                                 Ohaa çok korkunç😱🤯
# 11          11                         VICTON 빅톤 'Chronograph' MV
# 12          12                            Apink 에이핑크 'Dilemma' MV
# 13          13  Galaxy S22 Ultra: Official Introduction Film |...
# 14          14  Galaxy S22 Ultra Official film: The epic stand...
# 15          15  Samsung Galaxy Unpacked February 2022: Officia...
# 16          16  Samsung Galaxy Unpacked February 2022: Tiger i...
# 17          17                 We are behind every wish | Samsung
# 18          18  Robo Dog :30 | Live Fully Charged | The All-El...
# 19          19                               TAEYEON 태연 'INVU' MV
# 20          20                          DRIPPIN(드리핀) ‘Villain’ MV
# 21          21  Raktanchal Season 2 | Official Trailer | MX Or...
# 22          22               TAEYEON 태연 'Can't Control Myself' MV
# 23          23             [STATION : NCT LAB] MARK 마크 'Child' MV
# 24          24         ASTRO 아스트로 진진&라키 - 숨 좀 쉬자(Just Breath) M/V
# 25          25      The Freestyle: Official Launch Film | Samsung
# 26          26                              [NMIXX] Debut Trailer
# 27          27  [최초공개] Kep1er(케플러) - MVSK (4K) | Kep1er DEBUT ...
# 28          28                           WOOZI 'Ruby' Official MV
# 29          29                              [MV] VIVIZ _ BOP BOP!
# 30          30  [단독샷캠] 에스파 'Dreams Come True' 단독샷 별도녹화│aespa O...
# 31          31        BLACKPINK 2022 WELCOMING COLLECTION PREVIEW
# 32          32                [릴레이댄스] Kep1er(케플러) - WA DA DA (4K)
# 33          33  Galaxy Tab S8 Ultra: Official Launch Film | Sa...
# 34          34                      Stray Kids "ODDINARY" Trailer
# 35          35  [BANGTAN BOMB] BTS’s Chaotic Break Time - BTS ...
# 36          36                            코로나19 자가검사키트 사용법 및 행동요령
# 37          37                          헤이마마X몽키매직｜JTBC봐야지 #shorts
# 38          38             [광고] 현대자동차 자율주행 "모두의 자율주행이 될 때까지" - 본편
# 39          39  Galaxy Tab S8 Ultra: Official Introduction | S...
# 40          40  미니팡 교육동요 | 알록달록 미끄럼틀 | 토끼 | 오리 | 염소 | 돼지 | 색깔놀...
# 41          41  IVE(아이브 アイヴ) - ELEVEN(일레븐) (Music Bank) | KBS ...
# 42          42             SpongeBob SquarePants theme (acapella)
# 43          43                              이재명 후보는 개척력, 생명력이 강해요
# 44          44     Kep1er(케플러) - WA DA DA @인기가요 inkigayo 20220123
# 45          45  Ee Raathale Video Song [4k] | Radhe Shyam | Pr...
# 46          46  ซื้อวันนี้ไฮลักซ์ รีโว่ ทุกรุ่น วันนี้ รับข้อเ...
# 47          47  BTS (방탄소년단) PTD ON STAGE - SEOUL: LIVE VIEWING...
# 48          48  #AsianQualifiers - Group B | Vietnam 3 - 1 Chi...
# 49          49       [NCSOFT] Work in Progress 가능성을 플레이하다 | 엔씨소프트
#
#                        분류  동영상 길이 동영상 타입       조회수    좋아요 수    댓글 수
# 0         Cars & Vehicles      93  short  36527694      277      42
# 1           Entertainment     209  short  31625855   655433   55869
# 2                   Music     189  short  29757760  1295112   24349
# 3                   Music     172  short  31730285   233188   35260
# 4                   Music     214  short  26365319   723342  139005
# 5                   Music     189  short  23928804  1843673  149204
# 6                   Music      96  short  23382309   595584   13087
# 7                   Music     207  short  21792771   329475   20307
# 8    Science & Technology      60  short  18757875    15311    1559
# 9    Science & Technology      60  short  16520484    29904    1722
# 10                    Non      15  short  16265288   850948    1584
# 11          Entertainment     177  short  16265832    92879    7872
# 12          Entertainment     218  short  15391789   199602   20099
# 13   Science & Technology     207  short  13233936    52501    2836
# 14   Science & Technology      36  short  16213102    28474    1433
# 15   Science & Technology      30  short  12272167    17601    1184
# 16   Science & Technology      39  short  11470301    16368    1131
# 17   Science & Technology     179  short  10593646     5054     368
# 18        Cars & Vehicles      31  short  10246753      290      20
# 19                  Music     218  short   9360084   748497   36474
# 20          Entertainment     205  short   9298338    51807    6046
# 21          Entertainment     134  short   9338250    31736     960
# 22                  Music     206  short   7481510   537135   20389
# 23                  Music     218  short   7304171  1073080   74086
# 24          Entertainment     209  short   7169737   182435   23346
# 25   Science & Technology      73  short   6513731     9442     392
# 26                  Music     101  short   6377743   487397   42090
# 27          Entertainment     211  short   6227054   280094    8995
# 28                  Music     165  short   6055008   533733   29030
# 29          Entertainment     225  short   5720124   321247   22245
# 30          Entertainment     221  short   5581717   116300    2329
# 31                  Music      31  short   5469945   738464   34161
# 32          Entertainment     204  short   5414634   288454    5762
# 33   Science & Technology      31  short   5409945     2694     136
# 34                  Music      87  short   6166062   785669   49369
# 35                  Music     135  short   4754226   702512   20756
# 36        News & Politics      40  short   4606671      408      36
# 37          Entertainment      31  short   4405001    82607     882
# 38        Cars & Vehicles      31  short   4234120      205      54
# 39   Science & Technology      95  short   4098987    21165    1113
# 40       Film & Animation     132  short   3994368    11224       0
# 41                  Music     195  short   3713996   105646    2467
# 42                  Music      67  short   3437819   109161    2326
# 43        News & Politics      32  short   3443137    39562     962
# 44          Entertainment     199  short   3386633    97966    1732
# 45                  Music     139  short   3178637   262959    6391
# 46        Cars & Vehicles      15  short   3188128       62       0
# 47                  Music      31  short   3213802   737137   20765
# 48                  Sport     172  short   3084011    34683    6242
# 49                 Gaming      70  short   2955066      722     215

# %% [markdown]
# def viedo_comment_and_coment_liek(part):
#     lists = []
#     num = 0
#     for video_id in video_ids:
#         try:
#             video_responce = youtube.commentThreads().list(part = part,videoId = video_id,
#             textFormat = 'plainText',
#             maxResults = 50
#             ).execute()
#             comments = []
#             commentsLikes = []
#             for video in video_responce.get('items'):
#                 viedo_prop = video[part]['topLevelComment'][part]
#                 comments.append(viedo_prop['textDisplay'])
#                 commentsLikes.append(viedo_prop['likeCount'])
#             lists.append([{'comments':comments},{'commentsLikes':commentsLikes}])
#             print(num)
#             num += 1
#         except HttpError as e:
#             lists.append([{'comments':'Disabled'},{'commentsLikes':'Disabled'}])
#             print(str(num) +' 비활성화')
#             num += 1
#     return lists
#
# video_commentAndComentLieks = viedo_comment_and_coment_liek('snippet')
#
# # 비디오 별 댓글과 댓글 좋아요 추출

# %% [markdown]
# video_commentAndComentLieks[21][0]['comments']

# %% [markdown]
# len(video_commentAndComentLieks[21][0]['comments'])

# %% [markdown]
# import os
# import sys
# import urllib.request
#
# client_id = "p6BFvxDN9NQbc3KDOC9d"
# client_secret = "Smi8sEXvu3"
#
# def check_lange(str):
#     if(str != 'Disabled'):
#         encQuery = urllib.parse.quote(str)
#         data = "query=" + encQuery
#         url = "https://openapi.naver.com/v1/papago/detectLangs"
#         request = urllib.request.Request(url)
#         request.add_header("X-Naver-Client-Id",client_id)
#         request.add_header("X-Naver-Client-Secret",client_secret)
#         response = urllib.request.urlopen(request, data=data.encode("utf-8"))
#         rescode = response.getcode()
#         if(rescode==200):
#             response_body = response.read()
#             print(response_body.decode('utf-8'))
#         else:
#             print("Error Code:" + rescode)
#     else:
#         print("댓글 비활성화")
#
# for video_main in video_commentAndComentLieks:
#     print(len(video_main[0]['comments']))
#     print()
#     if type(video_main[0]['comments']) is list:
#         for commtent in video_main[0]['comments']:
#             check_lange(commtent)
#     else:
#         check_lange(video_main[0]['comments'])
