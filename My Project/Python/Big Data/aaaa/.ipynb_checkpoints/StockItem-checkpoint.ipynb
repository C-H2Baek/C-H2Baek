# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re
import requests
from urllib.request import urlopen
import lxml.html
import time
import json
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import csv
from PIL import Image
import random

base_url = 'https://finance.naver.com/item/board.nhn?code='

# %%
def naver_crawler(acode, page):
    headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3)'}
    total_dt = pd.DataFrame([])
    
    n_ = 0
    for page in range(1, page):
        
        n_ += 1
        if (n_ % 10 == 0):
            print('================== Page ' + str(page) + ' is done ==================')
        url = "https://finance.naver.com/item/board.nhn?code=%s&page=%s" % (str(acode), str(page))

        result = requests.get(url, headers = headers)
        bs_obj = BeautifulSoup(result.content, "html.parser")
        table = bs_obj.find('table', {'class' : 'type2'})
        tt = table.select('tbody > tr')

        for i in range(2, len(tt)):
            if len(tt[i].select('td > span')) > 0:
              # print(i)
              
              title = tt[i].select('td.title > a')[0]['title']
              writer = tt[i].select('td.p11')[0].text.replace('\t', '').replace('\n', '')
              date = tt[i].select('td > span')[0].text
              
              table = pd.DataFrame({ 
                                    
                                    '제목' : [title],
                                    '글쓴이' : [writer],
                                    '날짜' : [date]
                                    })
              total_dt = total_dt.append(table)
    
    return total_dt

# %%
data = naver_crawler('038460', 10)
data
# Out:
#                       제목       글쓴이                날짜
# 0            프로그램 엄청 누르네  ywna****  2022.02.10 11:30
# 0   휴마 상가겠다 수급 어마하게 들어온다  pops****  2022.02.10 11:25
# 0   그래.. 이제 코꾸뇽 고마 찌르고..  aita****  2022.02.10 11:19
# 0                타액진단키트   pops****  2022.02.10 11:05
# 0                 타액 대장주  dnld****  2022.02.10 11:01
# ..                   ...       ...               ...
# 0                    이넘은  spit****  2022.02.08 14:14
# 0   ■■ << 이런애있으면 100% 떨굼  park****  2022.02.08 14:14
# 0        눈 아프다,  상치고 닫아라  hoom****  2022.02.08 14:13
# 0            오르는 이유가 뭐임?  subw****  2022.02.08 14:12
# 0             뭔일이냐 기사 떳냐  clau****  2022.02.08 14:12
#
# [180 rows x 3 columns]

# %%
text =  ' '.join(data['제목'].tolist())
text
# Out:
# '프로그램 엄청 누르네 휴마 상가겠다 수급 어마하게 들어온다 그래.. 이제 코꾸뇽 고마 찌르고.. 타액진단키트  타액 대장주 피씨엘.바디텍메드 에스디바이오센스--대장주네 뭐라도하겠지 여주시는 자체예산으로 여주시민이면 현장PCR무료 입니다. ●●●속지 마세요●●● 오늘 6000원 깨지면서 원래 잡주가 시작했다하면 위드 오미크론 ㅋ  ㅋ  코로나 아니 나올물량도 없잖아 거래량 말라가는거 봐라 또시작이네 이 개잡주 ㅋㅋㅋㅋㅋㅋ 얘는 오늘도 휴마시스....오늘 급등할 것 같으네요 실적발표 적자 공시 나올때가 최저점 오겠다 4천대 어휴, 바보야...  영업이익이....어닝서프라이즈...이다 와! 차트보니 주포 존나 악질이네 바이오스마트 다 시끄릅고 오늘 5만명...진단키트 부족사태...점점 심해져 실적발표 언제나와요 겁나서 못사겠다. 바이오스마트 시간외 글싸지르지 말고 진드하니 궁디무겁게 어 국민신문고 신청접수 완료 바이오스마트 결국은 뭔가 되것지. 방역패스 바스야 Gosu 매일 글올리는 찐 주주는 튀었냐? 안보이네 6400깨고 공포조성할라하네 6740까지 1억 5천 매도
잡주는 만날 이런 식 너 머하냐 북치고 장구치고 쇼하고있네 개잡주 외인들 프로그램 다 털었다 주린이분석)세력손바뀜 시세끝 세력런 다시말아올려라   설거지 다팔고 튀었내 얘 오늘 g 랄을 하네요 지랄 눼? ■■캬캬캬 제대로 개미털기■■ xxxx쪼다 세끼 음봉처맞았네 지옥행 열차에 기름붓는거보소 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 아캬캬캬캬 5분만에 나락 참 대단한 김치주식 신속 pcr  상한가 내일가자 뭐냐 ㅋㅋ 또 퍽규나 ㅋㅋ 끝 7천넘었을때 뉴스없으면 뭐다? 많이먹었다,튀자 ㅎㅎ ■■ 15연상간다 꽉잡아라 쿄쿄 ■■ 뭔가 공시내기전인디?? 아는사람만 사네 ■■7200원 돌파하면 쩜상 캬캬캬■■ 상달리자 이고 털렸네ㅋ 디지게 흔들더니가네 키트주 꼴찌네 ㅋㅋㅋ 가주아~ 대충 예상 상이다 오전 내내 빌빌 거리다 한방이네 패대기쳐라 똥침 똥침 ㅎㅎ ■■상마는데 1분이라혔다 캬캬캬■■ 뉴스없으면 ㅋㅋㅋㅋ ㅋㅋㅋㅋ ㅇㅈㅎ 겁나웃기네ㅋㅋㄲ 난 다 털었다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ ㅋㅋㅋㅋㅋㅋ 종가-2프로 뻥카  매도 준비 완료 광고 엄청 하더니.. 키트주 다 오를때혼자못가더니 이넘은 ■■ << 이런애있으면 100% 떨굼 눈 아프다,  상치고 닫아라 오르는 이유가 뭐임? 뭔일이냐 기사 떳냐'

# %%
from konlpy.tag import Okt
from collections import Counter

korean_stopwords_path = "./Library/korean_stopwords.txt"
nouns_tagger = Okt()
with open(korean_stopwords_path, encoding='utf-8') as f: # 불용어 텍스트 파일을 열어 f로 치환
    stopwords = f.readlines() # 파일로부터 불용어를 한 줄씩 read
stopwords = [x.strip() for x in stopwords] # 리스트 생성
financial_stopwords = ['주식','ㅋㅋ']
for stopword in financial_stopwords:
    stopwords.append(stopword)

# %%
nouns = nouns_tagger.nouns(text)
text_t = Counter(nouns) # 구문분석기

text_t_remove = Counter({x: text_t[x] for x in text_t if len(x) > 1}) # 한글자 제거
text_t_remove = Counter({x: text_t_remove[x] for x in text_t if x not in stopwords}) # 불용어 제거
print(text_t_remove)
# Out:
# Counter({'오늘': 12, '키트': 6, '바이오': 5, '스마트': 5, '세력': 5, '오미크론': 4, '실적': 4, '바스': 4, '예상': 4, '내일': 4, '종가': 4, '프로그램': 3, '진단': 3, '안티': 3, '똥침': 3, '시외': 3, '캬캬캬': 3, '상가': 2, '타액': 2, '대장': 2, '시작': 2, '코로나': 2, '발표': 2, '차트': 2, '완료': 2, '뭔가': 2, '매도': 2, '징글': 2, '설거지': 2, '진자': 2, '눌릴때': 2, '사라': 2, '지금': 2, '양봉': 2, '정리': 2, '폭락': 2, '기주': 2, '거지': 2, '삭제': 2, '게시': 2, '물의': 2, '답글': 2, '기사': 2, '출현': 2, '상승': 2, '간다': 2, '뉴스': 2, '수급': 1, '어마': 1, '이제': 1, '코꾸뇽': 1, '고마': 1, '장주': 1, '피씨': 1, '바디': 1, '�
# %%
textwords = WordCloud().generate(text)
textwords.words_
# Out:
# {'오늘': 1.0,
#  'ㅋㅋㅋㅋ': 0.75,
#  '이': 0.625,
#  '바이오스마트': 0.625,
#  '다': 0.625,
#  '오미크론': 0.5,
#  '프로그램': 0.375,
#  '얘는': 0.375,
#  '오늘도': 0.375,
#  '바스': 0.375,
#  '주식하지마라': 0.375,
#  '또': 0.375,
#  'ㅋㅋㅋ': 0.375,
#  'ㅋㅋ': 0.375,
#  '왜': 0.375,
#  '종가': 0.375,
#  '캬캬캬': 0.375,
#  '엄청': 0.25,
#  'ㅋ': 0.25,
#  '개잡주': 0.25,
#  'ㅋㅋㅋㅋㅋㅋ': 0.25,
#  '실적발표': 0.25,
#  '와': 0.25,
#  '5만명': 0.25,
#  '말고': 0.25,
#  '완료': 0.25,
#  '뭔가': 0.25,
#  '확진자': 0.25,
#  '눌릴때': 0.25,
#  '확': 0.25,
#  '안티들': 0.25,
#  '지금': 0.25,
#  '내': 0.25,
#  '머하냐': 0.25,
#  'pcr': 0.25,
#  '죄다': 0.25,
#  '폭락했는데': 0.25,
#  '사기주만': 0.25,
#  '오른거지': 0.25,
#  '보니': 0.25,
#  '내일': 0.25,
#  '삭제된': 0.25,
#  '게시물의': 0.25,
#  '답글': 0.25,
#  '기사': 0.25,
#  '물린': 0.25,
#  '분들': 0.25,
#  '손': 0.25,
#  '시외': 0.25,
#  '예상': 0.25,
#  '털었다': 0.25,
#  '뉴스없으면': 0.25,
#  'ㅎㅎ': 0.25,
#  '키트주': 0.25,
#  '똥침': 0.25,
#  '누르네': 0.125,
#  '휴마': 0.125,
#  '상가겠다': 0.125,
#  '수급': 0.125,
#  '어마하게': 0.125,
#  '들어온다': 0.125,
#  '그래': 0.125,
#  '이제': 0.125,
#  '코꾸뇽': 0.125,
#  '고마': 0.125,
#  '찌르고': 0.125,
#  '타액진단키트': 0.125,
#  '타액': 0.125,
#  '대장주': 0.125,
#  '피씨엘': 0.125,
#  '바디텍메드': 0.125,
#  '에스디바이오센스': 0.125,
#  '대장주네': 0.125,
#  '뭐라도하겠지': 0.125,
#  '여주시는': 0.125,
#  '자체예산으로': 0.125,
#  '여주시민이면': 0.125,
#  '현장PCR무료': 0.125,
#  '입니다': 0.125,
#  '속지': 0.125,
#  '마세요': 0.125,
#  '6000원': 0.125,
#  '깨지면서': 0.125,
#  '원래': 0.125,
#  '잡주가': 0.125,
#  '시작했다하면': 0.125,
#  '위드': 0.125,
#  '코로나': 0.125,
#  '아니': 0.125,
#  '나올물량도': 0.125,
#  '없잖아': 0.125,
#  '거래량': 0.125,
#  '말라가는거': 0.125,
#  '봐라': 0.125,
#  '또시작이네': 0.125,
#  '휴마시스': 0.125,
#  '급등할': 0.125,
#  '것': 0.125,
#  '같으네요': 0.125,
#  '적자': 0.125,
#  '공시': 0.125,
#  '나올때가': 0.125,
#  '최저점': 0.125,
#  '오겠다': 0.125,
#  '4천대': 0.125,
#  '어휴': 0.125,
#  '바보야': 0.125,
#  '영업이익이': 0.125,
#  '어닝서프라이즈': 0.125,
#  '이다': 0.125,
#  '차트보니': 0.125,
#  '주포': 0.125,
#  '존나': 0.125,
#  '악질이네': 0.125,
#  '시끄릅고': 0.125,
#  '진단키트': 0.125,
#  '부족사태': 0.125,
#  '점점': 0.125,
#  '심해져': 0.125,
#  '언제나와요': 0.125,
#  '겁나서': 0.125,
#  '못사겠다': 0.125,
#  '시간외': 0.125,
#  '글싸지르지': 0.125,
#  '진드하니': 0.125,
#  '궁디무겁게': 0.125,
#  '어': 0.125,
#  '국민신문고': 0.125,
#  '신청접수': 0.125,
#  '결국은': 0.125,
#  '되것지': 0.125,
#  '방역패스': 0.125,
#  '바스야': 0.125,
#  'Gosu': 0.125,
#  '매일': 0.125,
#  '글올리는': 0.125,
#  '찐': 0.125,
#  '주주는': 0.125,
#  '튀었냐': 0.125,
#  '안보이네': 0.125,
#  '6400깨고': 0.125,
#  '공포조성할라하네': 0.125,
#  '6740까지': 0.125,
#  '1억': 0.125,
#  '5천': 0.125,
#  '매도자다': 0.125,
#  '실적': 0.125,
#  '언제나오나요': 0.125,
#  '팍': 0.125,
#  '약발': 0.125,
#  '좀더': 0.125,
#  '받자': 0.125,
#  '5만키트': 0.125,
#  '끝났네': 0.125,
#  '끝났어': 0.125,
#  '보기좋게': 0.125,
#  '10일선': 0.125,
#  '찍고': 0.125,
#  '다니네요ㅎㅎ': 0.125,
#  'Nh에서': 0.125,
#  '내라뿌네': 0.125,
#  'ㅆ': 0.125,
#  'ㅣ': 0.125,
#  'ㅂ': 0.125,
#  'ㅏㄹ': 0.125,
#  '징글': 0.125,
#  '징글하다': 0.125,
#  '한달남았네': 0.125,
#  '설거지야': 0.125,
#  '발광': 0.125,
#  '타임': 0.125,
#  '가는거냐': 0.125,
#  '코로나19': 0.125,
#  '미치게': 0.125,
#  '늘고있다': 0.125,
#  '특히': 0.125,
#  '외인': 0.125,
#  '요놈들': 0.125,
#  '기회': 0.125,
#  '줘도': 0.125,
#  '탈출': 0.125,
#  '못하면': 0.125,
#  '지능': 0.125,
#  '인정이지': 0.125,
#  '모간': 0.125,
#  '들어': 0.125,
#  '왔네요': 0.125,
#  '7690원': 0.125,
#  '그립네': 0.125,
#  '한국주식하지마라': 0.125,
#  '뉴비입니다': 0.125,
#  '강성주주님들': 0.125,
#  '혜린씨': 0.125,
#  '오늘은': 0.125,
#  'ㅡ': 0.125,
#  '어머': 0.125,
#  '안티': 0.125,
#  '구데기들': 0.125,
#  '바글바글하네': 0.125,
#  '지들끼리': 0.125}

# %%
text
# Out:
��ㅋㅋ 후행일뿐이고 차트는 선행 패턴은 거들뿐이다 뮤ㅓㄴ가 있어~~ [삭제된 게시물의 답글]실적이개차반이다 안티들 출현한걸보니~^ 바이오스마트 내일부터 본격적으로 상승해서, 9400원까지 평소 조회수 30~40개인데  오늘 물린 분들 손 ~~~ 오늘 물린 분들 손 ~~~ 흑우 주린이들은 종가 배팅 한답시고 올리기만 하면 시외 올라가는줄 안다 ㅋㅋㅋㅋ 내일 장 예상 바스 3대 대장 출현했네 ㅋㅋㅋ 양봉치는거 보니 오늘 부턴가? 시외에 사라 종가 상승박으면 시외 떡락 간다 무조건이다 개물렸네 낼 확진자 10만명이상 수익 주신 세력님께.. 오늘 종가는 6600원! 딱보니 녹엠은 상가겠고 지금 사요 형들 역시 바스 녹십자처럼 이 개잡주는 만날 이런 식 너 머하냐 북치고 장구치고 쇼하고있네 개잡주 외인들 프로그램 다 털었다 주린이분석)세력손바뀜 시세끝 세력런 다시말아올려라   설거지 다팔고 튀었내 얘 오늘 g 랄을 하네요 지랄 눼? ■■캬캬캬 제대로 개미털기■■ xxxx쪼다 세끼 음봉처맞았네 지옥행 열차에 기름붓는거보소 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 아캬캬캬캬 5분만에 나락 참 대단한 김치주식 신속 pcr  상한가 내일가자 뭐냐 ㅋㅋ 또 퍽규나 ㅋㅋ 끝 7천넘었을때 뉴스없으면 뭐다? 많이먹었다,튀자 ㅎㅎ ■■ 15연상간다 꽉잡아라 쿄쿄 ■■ 뭔가 공시내기전인디?? 아는사람만 사네 ■■7200원 돌파하면 쩜상 캬캬캬■■ 상달리자 이고 털렸네ㅋ 디지게 흔들더니가네 키트주 꼴찌네 ㅋㅋㅋ 가주아~ 대충 예상 상이다 오전 내내 빌빌 거리다 한방이네 패대기쳐라 똥침 똥침 ㅎㅎ ■■상마는데 1분이라혔다 캬캬캬■■ 뉴스없으면 ㅋㅋㅋㅋ ㅋㅋㅋㅋ ㅇㅈㅎ 겁나웃기네ㅋㅋㄲ 난 다 털었다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ ㅋㅋㅋㅋㅋㅋ 종가-2프로 뻥카  매도 준비 완료 광고 엄청 하더니.. 키트주 다 오를때혼자못가더니 이넘은 ■■ << 이런애있으면 100% 떨굼 눈 아프다,  상치고 닫아라 오르는 이유가 뭐임? 뭔일이냐 기사 떳냐'

# %%
image_mask = np.array(Image.open("./Library/007.jpg"))
wc = WordCloud(mask=image_mask,
               font_path='./Library/EliceDigitalBaeum_Bold.ttf', 
               #background_color = 'white', 
               max_words = 1500, max_font_size = 300)
gen = wc.generate_from_frequencies(text_t_remove)

plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation = 'bilinear')
plt.axis("off")
plt.savefig('../220127/StockItem.jpg')
#plt.show()

# %%
image_mask = np.array(Image.open("./Library/007.jpg"))
wc = WordCloud(mask=image_mask,
               font_path='./Library/EliceDigitalBaeum_Bold.ttf', 
               background_color = 'white', 
               max_words = 1500, max_font_size = 300).generate(text) # 불용어 제거 안한 것

plt.figure(figsize=(10,10))
plt.imshow(wc, interpolation = 'bilinear')
plt.axis("off")
plt.show()
